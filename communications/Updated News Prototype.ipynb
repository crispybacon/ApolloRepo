# %%
from folium.plugins import MarkerCluster
import datetime
import wikipedia
import folium
import requests

# %%
NYTRoot = 'https://api.nytimes.com/svc/'

# %%
def newsWire(returnURI=False, default=True, source=False, section=False, timePeriod=False, limit=False, offset=False, printHeadlines=False, debug=False, report=False):
    date = datetime.datetime.strftime(datetime.datetime.today(), '%A %D %H:%m %p')
    if limit!=False:
        if limit > 20:
            limit = 20
    else:
        limit = 20
    if source != False:
        default=False
    if default==True:
        source = 'all'
        section = 'all'
    if source!=False:
        if section==False:
            section = 'all'
    URI = NYTRoot+'news/v3/content/'+source+'/'+section
    if timePeriod !=False:
        assert type(int(limit))==int,'timePeriod must be a number'
        URI+='/{}'.format(timePeriod)
    URI +='.json?'
    if limit!= False:
        assert type(int(limit))==int,'limit must be a number'
        URI+= '&limit={}'.format(limit)
    if offset!=False:
        URI+='&offset={}'.format(offset)
    URI += '&api-key='+NYTkeys['newsWire']
    if debug == True:
        print(URI)
    if returnURI == True:
        return(URI)
    results = requests.get(URI)
    assert results.ok==True, "Could not complete request.  Possibly no results. Enable debug and check URI."
    results = results.json()
    total = results['num_results']
    if report == True:
        print('New York Times News Wire Query')
        print('Date: {}'.format(date))
        print('Status: {}'.format(results['status']))
        print('Number of results: {}'.format(total))
        if offset==False:
            print('Results: 0 - {}'.format(total))
        else:
            if offset+limit < total:
                print('Results: {} - {}'.format(offset, offset+limit))
            else:
                print('Results: {} - {}'.format(offset, total))
        if printHeadlines == True:
            for article in results['results']:
                print(article['title'])
    return results

def followURLSMap(urls, report=False):
    report = {}
    x=0
    targets = [x['url'] for x in urls if 'url' in x.keys()]
    for i in range(len(targets)):
        #print(targets[i])
        try:
            rArticle = specificArticle(targets[i])
            results = rArticle['results'][0]
            report[x] = results
            x += 1
        except Exception as e:
            #print(targets[i], 'download failed')
            pass
    return report

def fetchAllNewsWireresults(isource='all', isection='all', itimePeriod=120):
    idx = 20
    results = newsWire(source=isource, section=isection, timePeriod=itimePeriod, report=False)
    total = int(results['num_results'])
    paper = results['results']
    while idx <= total:
        chunk = newsWire(source=isource, section=isection, timePeriod=itimePeriod, report=False, offset=idx)
        for article in chunk['results']:
            paper.append(article)
        idx+=20
    print('Total Records Retrieved: {}'.format(total))
    return paper

def topStories(section, report=True, debug=False, returnURI=False, printHeadlines=True):
    '''
    sections are: home, arts, automobiles, books, business, fashion,
    food, health, insider, magazine, movies, national, nyregion,
    obituaries, opinion, politics, realestate, science, sports,
    sundayreview, technology, theater, tmagazine, travel, upshot,
    and world.
    '''
    date = datetime.datetime.strftime(datetime.datetime.today(), '%A %D %H:%m %p')
    URI = NYTRoot+'topstories/v1/'+section+'.json?api-key='+NYTkeys['topStories']
    if debug == True:
        print(URI)
    if returnURI == True:
        return(URI)
    results = requests.get(URI)
    assert results.ok==True, "Could not complete request. Possibly no results. Enable debug and check URI."
    results = results.json()
    total = results['num_results']
    if report == True:
        print('New York Times Top Stories Query')
        print('Date: {}'.format(date))
        print('Status: {}'.format(results['status']))
        print('Number of results: {}'.format(total))
        if printHeadlines == True:
            for article in results['results']:
                print(article['title'])
    return results

def mostPopular(section, pType, pTypeTarget='facebook;twitter', timePeriod=1, report=True, debug=False, returnURI=False, printHeadlines=True):
    '''
    sections are: home, arts, automobiles, books, business, fashion,
    food, health, insider, magazine, movies, national, nyregion,
    obituaries, opinion, politics, realestate, science, sports,
    sundayreview, technology, theater, tmagazine, travel, upshot,
    and world.
    supported time periods are 1,7 and 30
    '''
    date = datetime.datetime.strftime(datetime.datetime.today(), '%A %D %H:%m %p')
    if pType != 'mostshared':
        URI = NYTRoot+'mostpopular/v2/'+pType+'/'+section
    else:
        URI = NYTRoot+'mostpopular/v2/'+pType+'/'+section+'/'+pTypeTarget
    URI+= '/{}'.format(timePeriod)
    URI +='.json?apikey='+NYTkeys['mostPopular']
    if debug == True:
        print(URI)
    if returnURI == True:
        return(URI)
    results = requests.get(URI)
    assert results.ok==True, "Could not complete request. Possibly no results. Enable debug and check URI."
    results = results.json()
    total = results['num_results']
    if report == True:
        print('New York Times Most Popular Stories Query')
        print('Date: {}'.format(date))
        print('Status: {}'.format(results['status']))
        print('Number of results: {}'.format(total))
        if printHeadlines == True:
            for article in results['results']:
                print(article['title'])
    return results

def semanticSearchbyType(concept, specific_concept_name, report=True, debug=False, returnURI=False, printHeadlines=True):
    '''
    concept Types =  {
        'Location':'nytd_geo',
        'Person':'nytd_per',
        'Organization':'nytd_org',
        'Descriptor':'nytd_des',
        }
    '''
    date = datetime.datetime.strftime(datetime.datetime.today(), '%A %D %H:%m %p')
    URI = NYTRoot+'semantic/v2/concept/name/'+concept + '/' + specific_concept_name +'.json?fields=all&api-key='+NYTkeys['topStories']
    if debug == True:
        print(URI)
    if returnURI == True:
        return(URI)
    results = requests.get(URI)
    assert results.ok==True, "Could not complete request. Possibly no results. Enable debug and check URI."
    results = results.json()
    total = results['num_results']
    if report == True:
        print('New York Times Semantics Query')
        print('Date: {}'.format(date))
        print('Status: {}'.format(results['status']))
        print('Number of results: {}'.format(total))
        '''if printHeadlines == True:
            for article in results['results']:
                print(article['title'])'''
    return results

def specificArticle(url, debug=False, returnURI=False):
    date = datetime.datetime.strftime(datetime.datetime.today(), '%A %D %H:%m %p')
    URI = NYTRoot+'news/v3/content.json?url={}'.format(url)
    URI += '&api-key='+NYTkeys['topStories']
    if debug == True:
        print(URI)
    if returnURI == True:
        return(URI)
    results = requests.get(URI)
    assert results.ok==True, "Could not complete request. Possibly no results. Enable debug and check URI."
    results = results.json()
    #total = results['num_results']
    return results

def layer3Relations(layer1_relations, layer2):
    i=0
    layer1_urls = []
    targets = [x['url'] for x in layer1_relations if 'url' in x.keys()]
    new_urls = []
    for x in layer2:
        try:
            urls = layer2[x]['related_urls']
            for x in range(1,len(urls), 2):
                #print(urls[x]['url'])
                if urls[x]['url'] not in targets:
                    if urls[x] not in new_urls:
                        new_urls.append(urls[x])
        except:pass
    return new_urls

def dataLayerFromRelated(urls):
    layer_report = {}
    x = 0
    urls = [x['url'] for x in urls if 'url' in x.keys()]
    for article in urls:
        try:
            #print(article)
            layer_report[x] = specificArticle(article)['results'][0]
            x+=1
        except Exception as e:
            #print(e)
            pass
    return layer_report

def makePopUp(results):
    summary = results['abstract']
    article_template = """<b>Title: </b>{}</br>
    <b>Byline:</b> {}</br>
    <b>Abstract</b>: {}</br>
    <b>link:</b> {}""".format(results['title'],
                                   results['byline'],
                                   results['abstract'],
                                   results['url'])
    if 'multimedia' in results and results['multimedia'] != '':
        media = [x for x in results['multimedia'] if x['type'] == 'image'][-1]
        article_template+="""</br>
         <img src="{}" alt={}></br>
         <b>Caption: </b>{}</br>
         """.format(media['url'], media['copyright'],media['caption'])
    return article_template

def addCluster(layer, cluster, color):
    for article in layer:
        for place in layer[article]['geo_facet']:
            try:
                coordinate = wikipedia.page(place).coordinates
            except:
                continue
            sub_article_template = makePopUp(layer[article])
            secondaryPopUp = folium.Html(sub_article_template, script=True)
            articlePopup = folium.Popup(secondaryPopUp, max_width=450,)
            Marker = folium.Marker(location=coordinate,
                                   popup=articlePopup,
                                   icon = folium.Icon(color = color)
                                  ).add_to(cluster)

def relatedURLS(article, report=False):
    if 'related_urls' in article:
        #print(article)
        try:
            related = article['related_urls']
            facets = {}
            urls = []
            for record in related:
                for item in record:
                    urls.append({item:record[item]})
            for record in article:
                if 'facet' in record:
                    facets[record] = article[record]
        except:
            print('No related URLS, use facets instead')
        return urls, facets

def mapArticleRelations(article):
    center = (39, 34)
    primaryPost = (40.45, -73.59)
    layer1 = specificArticle(article)
    if layer1['results'][0]['geo_facet'] != 0:
        try:
            primaryPost = wikipedia.page(layer1['results'][0]['geo_facet']).coordinates
        except:
            pass
    newsMap = folium.Map(location=primaryPost,tiles='Stamen Watercolor', zoom_start=2)
    layer2Cluster = MarkerCluster(name='Layer 2 Links').add_to(newsMap)
    layer3Cluster = MarkerCluster(name='Layer 3 Links').add_to(newsMap)
    print(layer1['results'][0]['title'])
    print('Primary: Blue')
    print('Layer 2 Relations: Red')
    print('Layer 3 Relations: Green')
    layer1 = layer1['results'][0]
    article_template = makePopUp(layer1)
    primaryPopUp = folium.Html(article_template, script=True)
    popup = folium.Popup(primaryPopUp, max_width=450)
    folium.Marker(primaryPost, popup=popup).add_to(newsMap)
    layer1_relations, layer1_facets = relatedURLS(layer1)
    layer2 = followURLSMap(layer1_relations, report=False)
    print('layer2  {}'.format(len(layer2)))
    layer3_urls = layer3Relations(layer1_relations, layer2)
    layer3 = dataLayerFromRelated(layer3_urls)
    print('layer3 {}'.format(len(layer3)))
    addCluster(layer2, layer2Cluster, color='red')
    addCluster(layer3, layer3Cluster, color='green')
    layer2Cluster.add_to(newsMap)
    layer3Cluster.add_to(newsMap)
    folium.TileLayer('openstreetmap').add_to(newsMap)
    folium.TileLayer('Stamen Toner').add_to(newsMap)
    folium.TileLayer('cartodbpositron').add_to(newsMap)
    folium.LayerControl().add_to(newsMap)
    return newsMap

# %% [markdown]
# # 1. Pull News for Topic and TimeFrame
# Form -> Topic Selector
# Form -> Time Range
# Form -> News Source Selector(all, iht, nyt)

# %%
report = newsWire(source='all', section='World', timePeriod=120, report=False)

# %%
report.keys()
# Out:
# dict_keys(['status', 'copyright', 'num_results', 'results'])

# %%
report['num_results']
# Out:
# 73

# %% [markdown]
# # Restrict Results to articles with a Geo Facet

# %%
report = [x for x in report['results'] if x['geo_facet'] != '' ]

# %%
report = [x for x in report if x['related_urls'] != None]

# %%
len(report)
# Out:
# 15

# %%
report[1]
# Out:
# {'slug_name': '10Mali',
#  'section': 'World',
#  'subsection': 'Africa',
#  'title': 'Massacre in Mali Leaves at Least 95 Dead, Government Says',
#  'abstract': 'An attack on a village of the Dogon ethnic group in central Mali is the latest in violence that has displaced tens of thousands of civilians.',
#  'url': 'https://www.nytimes.com/2019/06/10/world/africa/mali-terrorism-dogon-fulani.html',
#  'byline': 'By THE ASSOCIATED PRESS',
#  'thumbnail_standard': '',
#  'item_type': 'Article',
#  'source': 'The New York Times',
#  'updated_date': '2019-06-10T16:02:25-04:00',
#  'created_date': '2019-06-10T15:31:32-04:00',
#  'published_date': '2019-06-09T20:00:00-04:00',
#  'first_published_date': '2019-06-10T15:30:02-04:00',
#  'material_type_facet': 'News',
#  'kicker': None,
#  'subheadline': None,
#  'des_facet': ['Terrorism'],
#  'org_facet': ['Dan Na Ambassagou'],
#  'per_facet': '',
#  'geo_facet': ['Mali'],
#  'related_urls': [{'suggested_link_text': 'Confronting Mali’s New Jihadist Threat',
#    'url': 'https://www.nytimes.com/2016/05/10/opinion/confronting-malis-new-jihadist-threat.html'},
#   {'suggested_link_text': 'Insecurity Shadows Mali’s President. It May Also Help Him Get Re-Elected.',
#    'url': 'https://www.nytimes.com/2018/07/27/world/africa/insecurity-shadows-malis-president-it-may-also-help-him-get-re-elected.html'},
#   {'suggested_link_text': 'As Refugees Flee Islamists in Mali, Solutions Are Elusive',
#    'url': 'https://www.nytimes.com/2012/07/16/world/africa/local-militia-bolsters-islamist-militants-in-mali.html'}],
#  'multimedia': ''}

# %% [markdown]
# # Check for Related Articles
# Check report entries and store as Map Target if found

# %%
mapTargets = []
for article in report:
    if article['related_urls'] not in ['', None, False, "None"]:
        #print(article['slug_name'])
        #print(article['related_urls'])
        mapTargets.append(article)

# %%
len(mapTargets)
# Out:
# 15

# %% [markdown]
# # Pull Layer One Relations and Facets for Map Targets

# %%
mapTargets[3]['title']
# Out:
# 'Looking for Free Speech in Russia? Try YouTube'

# %%
layer1_relations, layer1_facets = relatedURLS(mapTargets[3])

# %%
layer1_facets
# Out:
# {'material_type_facet': 'News',
#  'des_facet': '',
#  'org_facet': ['YouTube.com',
#   'News and News Media',
#   'Propaganda',
#   'Censorship'],
#  'per_facet': ['Putin, Vladimir V',
#   'Navalny, Aleksei A',
#   'Medvedev, Dmitri A',
#   'Tolokonnikova, Nadezhda'],
#  'geo_facet': ['Russia']}

# %%
layer1_relations
# Out:
# [{'suggested_link_text': 'In Russia, Political Criticism Is a 4-Letter Word (and a $470 Fine)'},
#  {'url': 'https://www.nytimes.com/2019/04/24/world/europe/russia-putin-criticism-law.html'},
#  {'suggested_link_text': 'Kremlin Moves Toward Control of Internet, Raising Censorship Fears'},
#  {'url': 'https://www.nytimes.com/2019/04/11/world/europe/russia-internet-censorship.html'},
#  {'suggested_link_text': 'Punk Riffs Take on God and Putin'},
#  {'url': 'https://www.nytimes.com/2012/03/21/world/europe/21iht-letter21.html'}]

# %%
layer1 = []
for article in mapTargets:
    layer1.append(relatedURLS(article))

# %% [markdown]
# # Collect Layer Two Data

# %%
layer2_data = []

# %% [markdown]
# #### TODO - Fix broken URL Downloads

# %%
for article_group in layer1:
    layer2_data.append(followURLSMap(article_group[0], report=False))
# Out:
# https://www.nytimes.com/interactive/2018/06/27/world/europe/europe-migrant-crisis-change.html download failed
# https://www.nytimes.com/2018/06/29/world/europe/us-migrant-crisis.html download failed
# https://www.nytimes.com/2016/02/03/world/middleeast/saudi-court-spares-poets-life-but-gives-him-8-years-and-800-lashes.html download failed
# https://www.nytimes.com/2016/12/06/world/middleeast/saudi-arabia-iran-spying-trial.html download failed
# https://www.nytimes.com/2016/01/05/world/middleeast/fewer-countries-use-death-penalty-but-death-sentences-surge.html download failed
# https://www.nytimes.com/2019/04/11/world/europe/russia-internet-censorship.html download failed
# https://www.nytimes.com/2012/03/21/world/europe/21iht-letter21.html download failed
# https://www.nytimes.com/2015/05/22/world/europe/moldova-eyes-russias-embrace-as-flirtation-with-europe-fades.html download failed
# https://www.nytimes.com/2016/01/26/world/europe/oppositions-groups-in-moldova-unite-to-protest-new-government.html download failed
# https://www.nytimes.com/2015/06/05/world/europe/moldova-bank-theft.html download failed
# https://www.nytimes.com/2013/12/05/world/europe/kerry-vows-to-help-moldova-hew-to-the-west.html download failed
# https://www.nytimes.com/2013/03/06/world/europe/moldovas-pro-western-government-falls.html download failed
# https://www.nytimes.com/2013/10/23/world/europe/russia-putting-a-strong-arm-on-neighbors.html download failed
# https://www.nytimes.com/2019/03/19/world/asia/kazakhstan-nazarbayev-resigns.html download failed
# https://www.nytimes.com/2019/03/20/world/asia/rise-of-first-daughter-in-kazakhstan-fuels-talk-of-succession.html download failed
# https://www.nytimes.com/2019/05/09/world/asia/kazakhstan-protests-blank-sign.html download failed
# https://www.nytimes.com/2017/03/07/world/asia/kazakh-capital-a-post-soviet-creation-is-growing-real-roots.html download failed
# https://www.nytimes.com/2019/03/18/world/asia/afghan-womens-soccer-sex-abuse.html download failed
# https://www.nytimes.com/2019/06/08/sports/soccer/afghanistan-soccer-sexual-abuse.html download failed
# https://www.nytimes.com/2019/06/07/sports/metoo-soccer-sexual-harassment.html download failed
# https://www.nytimes.com/2015/12/03/sports/fifa-scandal-arrests-in-switzerland.html download failed
# https://www.nytimes.com/2017/02/26/world/europe/as-albania-reckons-with-its-communist-past-critics-say-its-too-late.html download failed
# https://www.nytimes.com/2018/05/29/world/asia/iraq-mosul.html download failed
# https://www.nytimes.com/2019/06/08/business/trump-economy-national-security.html download failed
# https://www.nytimes.com/2019/06/07/us/politics/trump-tariffs-mexico.html download failed
# https://www.nytimes.com/2019/05/11/world/middleeast/syria-torture-prisons.html download failed
# https://www.nytimes.com/2019/06/05/world/middleeast/american-isis-syria-detain.html download failed
# https://www.nytimes.com/2019/05/05/world/europe/pope-francis-bulgaria.html download failed
# https://www.nytimes.com/2019/02/11/world/europe/bulgaria-poisoning-russia-skripal.html download failed
# https://www.nytimes.com/2018/10/10/world/europe/viktoria-marinova-arrest-germany-bulgaria.html download failed
# https://www.nytimes.com/2019/06/07/world/asia/philippines-killings-un.html download failed
# https://www.nytimes.com/2017/05/05/world/asia/philippines-agnes-callamard-duterte.html download failed
# https://www.nytimes.com/2016/10/01/world/asia/philippines-rodrigo-duterte-hitler-drugs.html download failed
# https://www.nytimes.com/2017/05/08/world/asia/rodrigo-duterte-extrajudicial-killings.html download failed
# https://www.nytimes.com/2018/07/23/world/europe/mesut-ozil-germany-soccer.html download failed
# https://www.nytimes.com/2018/09/17/sports/germany-soccer.html download failed
# https://www.nytimes.com/2018/06/27/sports/world-cup/germany-vs-south-korea.html download failed

# %%
layer1[1][0]
# Out:
# [{'suggested_link_text': 'Saudi Court Spares Poet’s Life but Gives Him 8 Years and 800 Lashes'},
#  {'url': 'https://www.nytimes.com/2016/02/03/world/middleeast/saudi-court-spares-poets-life-but-gives-him-8-years-and-800-lashes.html'},
#  {'suggested_link_text': 'Saudi Arabia Executes 37 in One Day for Terrorism'},
#  {'url': 'https://www.nytimes.com/2019/04/23/world/middleeast/saudi-arabia-executions.html'},
#  {'suggested_link_text': 'Saudi Court Orders Executions for 15 Accused of Spying for Iran'},
#  {'url': 'https://www.nytimes.com/2016/12/06/world/middleeast/saudi-arabia-iran-spying-trial.html'},
#  {'suggested_link_text': 'Death Sentences Surge, Even as More Countries Drop Capital Punishment'},
#  {'url': 'https://www.nytimes.com/2016/01/05/world/middleeast/fewer-countries-use-death-penalty-but-death-sentences-surge.html'}]

# %%
len(layer2_data[0])
# Out:
# 2

# %%
layer2_data
# Out:
# [{0: {'slug_name': '30central-america',
#    'section': 'World',
#    'subsection': 'Americas',
#    'title': 'Trump Turns U.S. Policy in Central America on Its Head',
#    'abstract': 'His plan to cut aid to Guatemala, Honduras and El Salvador is “shooting yourself in the foot,” said one human rights worker. Mexico has urged more funding for development.',
#    'url': 'https://www.nytimes.com/2019/03/30/world/americas/trump-turns-us-policy-in-central-america-on-its-head.html',
#    'byline': 'By ELISABETH MALKIN',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-24T16:43:44-04:00',
#    'created_date': '2019-03-30T20:35:18-04:00',
#    'published_date': '2019-03-29T20:00:00-04:00',
#    'first_published_date': '2019-03-30T20:33:48-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['United States Politics and Government',
#     'Humanitarian Aid',
#     'Gangs',
#     'Immigration and Emigration'],
#    'org_facet': ['United States International Relations', 'Foreign Aid'],
#    'per_facet': ['Trump, Donald J', 'Lopez Obrador, Andres Manuel'],
#    'geo_facet': ['Central America',
#     'El Salvador',
#     'Guatemala',
#     'Honduras',
#     'Mexico'],
#    'related_urls': None,
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/03/30/world/30central-america/30central-america-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Thousands of migrants, part of a caravan from Honduras, wave the Honduran, Guatemalan, and Mexican flags as they enter the Mexican state of Oaxaca in October. President Trump announced a plan to cut off aid to three Central American countries for failing to stop the flow of migrants toward the United States.',
#      'copyright': 'Todd Heisler/The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/03/30/world/30central-america/merlin_146054526_f116e707-cb4b-44a6-ba8b-9c707cd47b4f-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Thousands of migrants, part of a caravan from Honduras, wave the Honduran, Guatemalan, and Mexican flags as they enter the Mexican state of Oaxaca in October. President Trump announced a plan to cut off aid to three Central American countries for failing to stop the flow of migrants toward the United States.',
#      'copyright': 'Todd Heisler/The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/03/30/world/30central-america/merlin_146054526_f116e707-cb4b-44a6-ba8b-9c707cd47b4f-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Thousands of migrants, part of a caravan from Honduras, wave the Honduran, Guatemalan, and Mexican flags as they enter the Mexican state of Oaxaca in October. President Trump announced a plan to cut off aid to three Central American countries for failing to stop the flow of migrants toward the United States.',
#      'copyright': 'Todd Heisler/The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/03/30/world/30central-america/merlin_146054526_f116e707-cb4b-44a6-ba8b-9c707cd47b4f-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Thousands of migrants, part of a caravan from Honduras, wave the Honduran, Guatemalan, and Mexican flags as they enter the Mexican state of Oaxaca in October. President Trump announced a plan to cut off aid to three Central American countries for failing to stop the flow of migrants toward the United States.',
#      'copyright': 'Todd Heisler/The New York Times'}]},
#   1: {'slug_name': '01mexico-border',
#    'section': 'World',
#    'subsection': 'Americas',
#    'title': 'Migration Surge From Central America Was Spurred, in Part, by Mexican Policies',
#    'abstract': 'The López Obrador administration’s migrant-friendly policies appear to have encouraged more migrants to move north. Border cities are straining to shelter them.',
#    'url': 'https://www.nytimes.com/2019/04/01/world/americas/mexico-migration-border.html',
#    'byline': 'By KIRK SEMPLE',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-02T21:23:29-04:00',
#    'created_date': '2019-04-01T17:28:35-04:00',
#    'published_date': '2019-03-31T20:00:00-04:00',
#    'first_published_date': '2019-04-01T17:27:05-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Immigration and Emigration',
#     'Asylum, Right of',
#     'Illegal Immigration'],
#    'org_facet': ['Visas'],
#    'per_facet': ['Lopez Obrador, Andres Manuel', 'Trump, Donald J'],
#    'geo_facet': ['Ciudad Juarez (Mexico)', 'Mexico', 'United States'],
#    'related_urls': [{'suggested_link_text': 'Trump Turns U.S. Policy in Central America on Its Head',
#      'url': 'https://www.nytimes.com/2019/03/30/world/americas/trump-turns-us-policy-in-central-america-on-its-head.html'},
#     {'suggested_link_text': 'Spring Brings Surge of Migrants, Stretching Border Facilities Far Beyond Capacity',
#      'url': 'https://www.nytimes.com/2019/03/30/us/border-migrants-el-paso-bridge-spring-surge.html'},
#     {'suggested_link_text': 'Migrants Are Detained Under a Bridge in El Paso. What Happened?',
#      'url': 'https://www.nytimes.com/2019/03/29/us/el-paso-immigration-photo.html'},
#     {'suggested_link_text': 'Trump’s Surprising New Ally in Mexico? The Government',
#      'url': 'https://www.nytimes.com/2019/03/01/world/americas/mexico-migration-trump.html'}],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/02/world/01mexico-border/merlin_152929269_ae125977-963c-412d-be6c-0acd65fa8043-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A Cuban migrant resting in a temporary shelter set up by a church in Ciudad Ju&aacute;rez.',
#      'copyright': 'Brett Gundlock for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/02/world/01mexico-border/merlin_152929269_ae125977-963c-412d-be6c-0acd65fa8043-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A Cuban migrant resting in a temporary shelter set up by a church in Ciudad Ju&aacute;rez.',
#      'copyright': 'Brett Gundlock for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/02/world/01mexico-border/merlin_152929269_ae125977-963c-412d-be6c-0acd65fa8043-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A Cuban migrant resting in a temporary shelter set up by a church in Ciudad Ju&aacute;rez.',
#      'copyright': 'Brett Gundlock for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/02/world/01mexico-border/merlin_152929269_ae125977-963c-412d-be6c-0acd65fa8043-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A Cuban migrant resting in a temporary shelter set up by a church in Ciudad Ju&aacute;rez.',
#      'copyright': 'Brett Gundlock for The New York Times'}]}},
#  {0: {'slug_name': '23saudi',
#    'section': 'World',
#    'subsection': 'Middle East',
#    'title': 'Saudi Arabia Executes 37 in One Day for Terrorism',
#    'abstract': 'The men were put to death for extremist activities, the state-run news agency said, but rights groups questioned the fairness of their trials.',
#    'url': 'https://www.nytimes.com/2019/04/23/world/middleeast/saudi-arabia-executions.html',
#    'byline': 'By BEN HUBBARD',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-23T23:52:05-04:00',
#    'created_date': '2019-04-23T12:16:59-04:00',
#    'published_date': '2019-04-22T20:00:00-04:00',
#    'first_published_date': '2019-04-23T12:15:29-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Terrorism', 'Capital Punishment'],
#    'org_facet': '',
#    'per_facet': ['Nimr, Nimr al-'],
#    'geo_facet': ['Saudi Arabia'],
#    'related_urls': [{'suggested_link_text': 'Saudi Arabia Cuts Ties With Iran Amid Fallout From Cleric’s Execution',
#      'url': 'https://www.nytimes.com/2016/01/04/world/middleeast/iran-saudi-arabia-execution-sheikh-nimr.html'},
#     {'suggested_link_text': 'Iranian Protesters Ransack Saudi Embassy After Execution of Shiite Cleric',
#      'url': 'https://www.nytimes.com/2016/01/03/world/middleeast/saudi-arabia-executes-47-sheikh-nimr-shiite-cleric.html'},
#     {'suggested_link_text': 'Saudi Justice, Harsh but Able to Spare the Sword',
#      'url': 'https://www.nytimes.com/2015/03/23/world/middleeast/a-murder-a-death-sentence-and-the-unpredictable-nature-of-saudi-justice.html'}],
#    'multimedia': ''}},
#  {0: {'slug_name': '09hongkong',
#    'section': 'World',
#    'subsection': 'Asia Pacific',
#    'title': 'Hong Kong March: Vast Protest of Extradition Bill Shows Fear of Eroding Freedoms',
#    'abstract': 'The demonstration was one of the largest in the territory’s history and showed deep worries about ever-tightening Chinese rule.',
#    'url': 'https://www.nytimes.com/2019/06/09/world/asia/hong-kong-extradition-protest.html',
#    'byline': 'By AUSTIN RAMZY',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-06-09T19:43:05-04:00',
#    'created_date': '2019-06-09T02:15:14-04:00',
#    'published_date': '2019-06-08T20:00:00-04:00',
#    'first_published_date': '2019-06-09T02:13:44-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Extradition',
#     'Law and Legislation',
#     'Politics and Government'],
#    'org_facet': '',
#    'per_facet': '',
#    'geo_facet': ['Hong Kong', 'China'],
#    'related_urls': [{'suggested_link_text': 'Fearing China’s Rule, Hong Kong Residents Resist Extradition Plan',
#      'url': 'https://www.nytimes.com/2019/06/07/world/asia/hong-kong-china-extradition-protest.html'},
#     {'suggested_link_text': 'Havoc in Hong Kong Legislature Over Extradition Bill',
#      'url': 'https://www.nytimes.com/2019/05/11/world/asia/hong-kong-extradition-law.html'},
#     {'suggested_link_text': 'Despite Fears About China, Hong Kong Pushes Ahead on Extradition Bill',
#      'url': 'https://www.nytimes.com/2019/04/03/world/asia/hong-kong-extradition-law-china.html'}],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/06/09/world/09Hongkong5/09Hongkong5-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Protesters marched in Hong Kong on Sunday in opposition to legislation that would allow extraditions to mainland China and broader concerns about Chinese sovereignty.',
#      'copyright': 'Lam Yik Fei for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/06/09/world/09Hongkong5/merlin_156179673_cfc7b1a4-ef6c-44fd-8446-423c55e4c1b0-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Protesters marched in Hong Kong on Sunday in opposition to legislation that would allow extraditions to mainland China and broader concerns about Chinese sovereignty.',
#      'copyright': 'Lam Yik Fei for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/06/09/world/09Hongkong5/merlin_156179673_cfc7b1a4-ef6c-44fd-8446-423c55e4c1b0-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Protesters marched in Hong Kong on Sunday in opposition to legislation that would allow extraditions to mainland China and broader concerns about Chinese sovereignty.',
#      'copyright': 'Lam Yik Fei for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/06/09/world/09Hongkong5/merlin_156179673_cfc7b1a4-ef6c-44fd-8446-423c55e4c1b0-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Protesters marched in Hong Kong on Sunday in opposition to legislation that would allow extraditions to mainland China and broader concerns about Chinese sovereignty.',
#      'copyright': 'Lam Yik Fei for The New York Times'}]}},
#  {0: {'slug_name': '24russia',
#    'section': 'World',
#    'subsection': 'Europe',
#    'title': 'In Russia, Political Criticism Is a 4-Letter Word (and a $470 Fine)',
#    'abstract': 'A Russian court fined a man $470 for calling President Vladimir Putin a vulgar form of the word dimwit, under a new law against obscene criticism. The man, using obscenities, said he was unrepentant.',
#    'url': 'https://www.nytimes.com/2019/04/24/world/europe/russia-putin-criticism-law.html',
#    'byline': 'By ANDREW E. KRAMER',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-25T13:11:35-04:00',
#    'created_date': '2019-04-24T17:46:10-04:00',
#    'published_date': '2019-04-23T20:00:00-04:00',
#    'first_published_date': '2019-04-24T17:44:39-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Politics and Government',
#     'Indecency, Obscenity and Profanity',
#     'Censorship'],
#    'org_facet': ['Fines (Penalties)', 'Social Media'],
#    'per_facet': ['Kartyzhev, Yuri D', 'Putin, Vladimir V'],
#    'geo_facet': ['Russia'],
#    'related_urls': [{'suggested_link_text': 'Russia Prepares to Block LinkedIn After Court Ruling',
#      'url': 'https://www.nytimes.com/2016/11/11/technology/russia-linkedin-data-court-blocked.html'},
#     {'suggested_link_text': 'New Prison Rule in Russia: No Swearing',
#      'url': 'https://www.nytimes.com/2016/01/15/world/europe/russia-bans-foul-language-in-some-prisons-no-word-on-enforcement.html'}],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/24/world/24insult/24insult-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Vladimir Putin of Russia leaving an event in St. Petersburg this month. A man was fined $470 for calling Mr. Putin a vulgar form of the Russian word for dimwit.',
#      'copyright': 'Olga Maltseva/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/04/24/world/24insult/merlin_153270126_52221389-779a-4a94-9640-7e9aaee9e9f4-articleInline.jpg',
#      'format': 'Normal',
#      'height': 132,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Vladimir Putin of Russia leaving an event in St. Petersburg this month. A man was fined $470 for calling Mr. Putin a vulgar form of the Russian word for dimwit.',
#      'copyright': 'Olga Maltseva/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/04/24/world/24insult/24insult-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Vladimir Putin of Russia leaving an event in St. Petersburg this month. A man was fined $470 for calling Mr. Putin a vulgar form of the Russian word for dimwit.',
#      'copyright': 'Olga Maltseva/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/04/24/world/24insult/24insult-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Vladimir Putin of Russia leaving an event in St. Petersburg this month. A man was fined $470 for calling Mr. Putin a vulgar form of the Russian word for dimwit.',
#      'copyright': 'Olga Maltseva/Agence France-Presse — Getty Images'}]}},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {0: {'slug_name': '30central-america',
#    'section': 'World',
#    'subsection': 'Americas',
#    'title': 'Trump Turns U.S. Policy in Central America on Its Head',
#    'abstract': 'His plan to cut aid to Guatemala, Honduras and El Salvador is “shooting yourself in the foot,” said one human rights worker. Mexico has urged more funding for development.',
#    'url': 'https://www.nytimes.com/2019/03/30/world/americas/trump-turns-us-policy-in-central-america-on-its-head.html',
#    'byline': 'By ELISABETH MALKIN',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-24T16:43:44-04:00',
#    'created_date': '2019-03-30T20:35:18-04:00',
#    'published_date': '2019-03-29T20:00:00-04:00',
#    'first_published_date': '2019-03-30T20:33:48-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['United States Politics and Government',
#     'Humanitarian Aid',
#     'Gangs',
#     'Immigration and Emigration'],
#    'org_facet': ['United States International Relations', 'Foreign Aid'],
#    'per_facet': ['Trump, Donald J', 'Lopez Obrador, Andres Manuel'],
#    'geo_facet': ['Central America',
#     'El Salvador',
#     'Guatemala',
#     'Honduras',
#     'Mexico'],
#    'related_urls': None,
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/03/30/world/30central-america/30central-america-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Thousands of migrants, part of a caravan from Honduras, wave the Honduran, Guatemalan, and Mexican flags as they enter the Mexican state of Oaxaca in October. President Trump announced a plan to cut off aid to three Central American countries for failing to stop the flow of migrants toward the United States.',
#      'copyright': 'Todd Heisler/The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/03/30/world/30central-america/merlin_146054526_f116e707-cb4b-44a6-ba8b-9c707cd47b4f-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Thousands of migrants, part of a caravan from Honduras, wave the Honduran, Guatemalan, and Mexican flags as they enter the Mexican state of Oaxaca in October. President Trump announced a plan to cut off aid to three Central American countries for failing to stop the flow of migrants toward the United States.',
#      'copyright': 'Todd Heisler/The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/03/30/world/30central-america/merlin_146054526_f116e707-cb4b-44a6-ba8b-9c707cd47b4f-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Thousands of migrants, part of a caravan from Honduras, wave the Honduran, Guatemalan, and Mexican flags as they enter the Mexican state of Oaxaca in October. President Trump announced a plan to cut off aid to three Central American countries for failing to stop the flow of migrants toward the United States.',
#      'copyright': 'Todd Heisler/The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/03/30/world/30central-america/merlin_146054526_f116e707-cb4b-44a6-ba8b-9c707cd47b4f-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Thousands of migrants, part of a caravan from Honduras, wave the Honduran, Guatemalan, and Mexican flags as they enter the Mexican state of Oaxaca in October. President Trump announced a plan to cut off aid to three Central American countries for failing to stop the flow of migrants toward the United States.',
#      'copyright': 'Todd Heisler/The New York Times'}]},
#   1: {'slug_name': '01mexico-border',
#    'section': 'World',
#    'subsection': 'Americas',
#    'title': 'Migration Surge From Central America Was Spurred, in Part, by Mexican Policies',
#    'abstract': 'The López Obrador administration’s migrant-friendly policies appear to have encouraged more migrants to move north. Border cities are straining to shelter them.',
#    'url': 'https://www.nytimes.com/2019/04/01/world/americas/mexico-migration-border.html',
#    'byline': 'By KIRK SEMPLE',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-02T21:23:29-04:00',
#    'created_date': '2019-04-01T17:28:35-04:00',
#    'published_date': '2019-03-31T20:00:00-04:00',
#    'first_published_date': '2019-04-01T17:27:05-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Immigration and Emigration',
#     'Asylum, Right of',
#     'Illegal Immigration'],
#    'org_facet': ['Visas'],
#    'per_facet': ['Lopez Obrador, Andres Manuel', 'Trump, Donald J'],
#    'geo_facet': ['Ciudad Juarez (Mexico)', 'Mexico', 'United States'],
#    'related_urls': [{'suggested_link_text': 'Trump Turns U.S. Policy in Central America on Its Head',
#      'url': 'https://www.nytimes.com/2019/03/30/world/americas/trump-turns-us-policy-in-central-america-on-its-head.html'},
#     {'suggested_link_text': 'Spring Brings Surge of Migrants, Stretching Border Facilities Far Beyond Capacity',
#      'url': 'https://www.nytimes.com/2019/03/30/us/border-migrants-el-paso-bridge-spring-surge.html'},
#     {'suggested_link_text': 'Migrants Are Detained Under a Bridge in El Paso. What Happened?',
#      'url': 'https://www.nytimes.com/2019/03/29/us/el-paso-immigration-photo.html'},
#     {'suggested_link_text': 'Trump’s Surprising New Ally in Mexico? The Government',
#      'url': 'https://www.nytimes.com/2019/03/01/world/americas/mexico-migration-trump.html'}],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/02/world/01mexico-border/merlin_152929269_ae125977-963c-412d-be6c-0acd65fa8043-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A Cuban migrant resting in a temporary shelter set up by a church in Ciudad Ju&aacute;rez.',
#      'copyright': 'Brett Gundlock for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/02/world/01mexico-border/merlin_152929269_ae125977-963c-412d-be6c-0acd65fa8043-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A Cuban migrant resting in a temporary shelter set up by a church in Ciudad Ju&aacute;rez.',
#      'copyright': 'Brett Gundlock for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/02/world/01mexico-border/merlin_152929269_ae125977-963c-412d-be6c-0acd65fa8043-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A Cuban migrant resting in a temporary shelter set up by a church in Ciudad Ju&aacute;rez.',
#      'copyright': 'Brett Gundlock for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/04/02/world/01mexico-border/merlin_152929269_ae125977-963c-412d-be6c-0acd65fa8043-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A Cuban migrant resting in a temporary shelter set up by a church in Ciudad Ju&aacute;rez.',
#      'copyright': 'Brett Gundlock for The New York Times'}]}},
#  {0: {'slug_name': '23saudi',
#    'section': 'World',
#    'subsection': 'Middle East',
#    'title': 'Saudi Arabia Executes 37 in One Day for Terrorism',
#    'abstract': 'The men were put to death for extremist activities, the state-run news agency said, but rights groups questioned the fairness of their trials.',
#    'url': 'https://www.nytimes.com/2019/04/23/world/middleeast/saudi-arabia-executions.html',
#    'byline': 'By BEN HUBBARD',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-23T23:52:05-04:00',
#    'created_date': '2019-04-23T12:16:59-04:00',
#    'published_date': '2019-04-22T20:00:00-04:00',
#    'first_published_date': '2019-04-23T12:15:29-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Terrorism', 'Capital Punishment'],
#    'org_facet': '',
#    'per_facet': ['Nimr, Nimr al-'],
#    'geo_facet': ['Saudi Arabia'],
#    'related_urls': [{'suggested_link_text': 'Saudi Arabia Cuts Ties With Iran Amid Fallout From Cleric’s Execution',
#      'url': 'https://www.nytimes.com/2016/01/04/world/middleeast/iran-saudi-arabia-execution-sheikh-nimr.html'},
#     {'suggested_link_text': 'Iranian Protesters Ransack Saudi Embassy After Execution of Shiite Cleric',
#      'url': 'https://www.nytimes.com/2016/01/03/world/middleeast/saudi-arabia-executes-47-sheikh-nimr-shiite-cleric.html'},
#     {'suggested_link_text': 'Saudi Justice, Harsh but Able to Spare the Sword',
#      'url': 'https://www.nytimes.com/2015/03/23/world/middleeast/a-murder-a-death-sentence-and-the-unpredictable-nature-of-saudi-justice.html'}],
#    'multimedia': ''}},
#  {0: {'slug_name': '09hongkong',
#    'section': 'World',
#    'subsection': 'Asia Pacific',
#    'title': 'Hong Kong March: Vast Protest of Extradition Bill Shows Fear of Eroding Freedoms',
#    'abstract': 'The demonstration was one of the largest in the territory’s history and showed deep worries about ever-tightening Chinese rule.',
#    'url': 'https://www.nytimes.com/2019/06/09/world/asia/hong-kong-extradition-protest.html',
#    'byline': 'By AUSTIN RAMZY',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-06-09T19:43:05-04:00',
#    'created_date': '2019-06-09T02:15:14-04:00',
#    'published_date': '2019-06-08T20:00:00-04:00',
#    'first_published_date': '2019-06-09T02:13:44-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Extradition',
#     'Law and Legislation',
#     'Politics and Government'],
#    'org_facet': '',
#    'per_facet': '',
#    'geo_facet': ['Hong Kong', 'China'],
#    'related_urls': [{'suggested_link_text': 'Fearing China’s Rule, Hong Kong Residents Resist Extradition Plan',
#      'url': 'https://www.nytimes.com/2019/06/07/world/asia/hong-kong-china-extradition-protest.html'},
#     {'suggested_link_text': 'Havoc in Hong Kong Legislature Over Extradition Bill',
#      'url': 'https://www.nytimes.com/2019/05/11/world/asia/hong-kong-extradition-law.html'},
#     {'suggested_link_text': 'Despite Fears About China, Hong Kong Pushes Ahead on Extradition Bill',
#      'url': 'https://www.nytimes.com/2019/04/03/world/asia/hong-kong-extradition-law-china.html'}],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/06/09/world/09Hongkong5/09Hongkong5-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Protesters marched in Hong Kong on Sunday in opposition to legislation that would allow extraditions to mainland China and broader concerns about Chinese sovereignty.',
#      'copyright': 'Lam Yik Fei for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/06/09/world/09Hongkong5/merlin_156179673_cfc7b1a4-ef6c-44fd-8446-423c55e4c1b0-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Protesters marched in Hong Kong on Sunday in opposition to legislation that would allow extraditions to mainland China and broader concerns about Chinese sovereignty.',
#      'copyright': 'Lam Yik Fei for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/06/09/world/09Hongkong5/merlin_156179673_cfc7b1a4-ef6c-44fd-8446-423c55e4c1b0-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Protesters marched in Hong Kong on Sunday in opposition to legislation that would allow extraditions to mainland China and broader concerns about Chinese sovereignty.',
#      'copyright': 'Lam Yik Fei for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/06/09/world/09Hongkong5/merlin_156179673_cfc7b1a4-ef6c-44fd-8446-423c55e4c1b0-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Protesters marched in Hong Kong on Sunday in opposition to legislation that would allow extraditions to mainland China and broader concerns about Chinese sovereignty.',
#      'copyright': 'Lam Yik Fei for The New York Times'}]}},
#  {0: {'slug_name': '24russia',
#    'section': 'World',
#    'subsection': 'Europe',
#    'title': 'In Russia, Political Criticism Is a 4-Letter Word (and a $470 Fine)',
#    'abstract': 'A Russian court fined a man $470 for calling President Vladimir Putin a vulgar form of the word dimwit, under a new law against obscene criticism. The man, using obscenities, said he was unrepentant.',
#    'url': 'https://www.nytimes.com/2019/04/24/world/europe/russia-putin-criticism-law.html',
#    'byline': 'By ANDREW E. KRAMER',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-25T13:11:35-04:00',
#    'created_date': '2019-04-24T17:46:10-04:00',
#    'published_date': '2019-04-23T20:00:00-04:00',
#    'first_published_date': '2019-04-24T17:44:39-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Politics and Government',
#     'Indecency, Obscenity and Profanity',
#     'Censorship'],
#    'org_facet': ['Fines (Penalties)', 'Social Media'],
#    'per_facet': ['Kartyzhev, Yuri D', 'Putin, Vladimir V'],
#    'geo_facet': ['Russia'],
#    'related_urls': [{'suggested_link_text': 'Russia Prepares to Block LinkedIn After Court Ruling',
#      'url': 'https://www.nytimes.com/2016/11/11/technology/russia-linkedin-data-court-blocked.html'},
#     {'suggested_link_text': 'New Prison Rule in Russia: No Swearing',
#      'url': 'https://www.nytimes.com/2016/01/15/world/europe/russia-bans-foul-language-in-some-prisons-no-word-on-enforcement.html'}],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/24/world/24insult/24insult-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Vladimir Putin of Russia leaving an event in St. Petersburg this month. A man was fined $470 for calling Mr. Putin a vulgar form of the Russian word for dimwit.',
#      'copyright': 'Olga Maltseva/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/04/24/world/24insult/merlin_153270126_52221389-779a-4a94-9640-7e9aaee9e9f4-articleInline.jpg',
#      'format': 'Normal',
#      'height': 132,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Vladimir Putin of Russia leaving an event in St. Petersburg this month. A man was fined $470 for calling Mr. Putin a vulgar form of the Russian word for dimwit.',
#      'copyright': 'Olga Maltseva/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/04/24/world/24insult/24insult-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Vladimir Putin of Russia leaving an event in St. Petersburg this month. A man was fined $470 for calling Mr. Putin a vulgar form of the Russian word for dimwit.',
#      'copyright': 'Olga Maltseva/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/04/24/world/24insult/24insult-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Vladimir Putin of Russia leaving an event in St. Petersburg this month. A man was fined $470 for calling Mr. Putin a vulgar form of the Russian word for dimwit.',
#      'copyright': 'Olga Maltseva/Agence France-Presse — Getty Images'}]}},
#  {},
#  {},
#  {},
#  {0: {'slug_name': '01Balkan-Spring',
#    'section': 'World',
#    'subsection': 'Europe',
#    'title': '‘Balkan Spring’ Turns to Summer, and Hopes for Change Dim',
#    'abstract': 'From Serbia to Montenegro and Albania, thousands have taken to the streets for months to protest corrupt, autocratic leaders. Yet nothing has budged.',
#    'url': 'https://www.nytimes.com/2019/06/01/world/europe/balkans-protests-montenegro-serbia-bosnia-albania.html',
#    'byline': 'By MARC SANTORA',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-06-02T15:28:27-04:00',
#    'created_date': '2019-06-01T03:18:29-04:00',
#    'published_date': '2019-05-31T20:00:00-04:00',
#    'first_published_date': '2019-06-01T03:16:58-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Politics and Government',
#     'Corruption (Institutional)',
#     'Foreign Investments',
#     'Travel and Vacations'],
#    'org_facet': ['Demonstrations, Protests and Riots'],
#    'per_facet': ['Djukanovic, Milo'],
#    'geo_facet': ['Montenegro', 'Albania', 'Serbia', 'Balkan States'],
#    'related_urls': [{'suggested_link_text': 'Serbia Protests Shine Light on a Nation Tugged Between East and West',
#      'url': 'https://www.nytimes.com/2019/01/31/world/europe/serbia-protests.html'},
#     {'suggested_link_text': 'Putin Gets Red Carpet Treatment in Serbia, a Fulcrum Once More',
#      'url': 'https://www.nytimes.com/2019/01/17/world/europe/serbia-putin-russia-belgrade-vucic.html'},
#     {'suggested_link_text': 'In Eastern Europe, U.S. Officials Talk Deals, Not Erosion of Democracy',
#      'url': 'https://www.nytimes.com/2019/02/15/world/europe/pence-pompeo-eastern-europe.html'}],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/06/02/world/02balkan-spring/merlin_152845929_df58ae34-1208-4029-92e5-68e2673c96c7-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'An anti-government protest in Podgorica, Montenegro, in March.',
#      'copyright': 'Stevo Vasiljevic/Reuters'},
#     {'url': 'https://static01.nyt.com/images/2019/06/02/world/02balkan-spring/merlin_152845929_df58ae34-1208-4029-92e5-68e2673c96c7-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'An anti-government protest in Podgorica, Montenegro, in March.',
#      'copyright': 'Stevo Vasiljevic/Reuters'},
#     {'url': 'https://static01.nyt.com/images/2019/06/02/world/02balkan-spring/02balkan-spring-mediumThreeByTwo210-v2.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'An anti-government protest in Podgorica, Montenegro, in March.',
#      'copyright': 'Stevo Vasiljevic/Reuters'},
#     {'url': 'https://static01.nyt.com/images/2019/06/02/world/02balkan-spring/02balkan-spring-mediumThreeByTwo440-v2.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'An anti-government protest in Podgorica, Montenegro, in March.',
#      'copyright': 'Stevo Vasiljevic/Reuters'}]}},
#  {0: {'slug_name': '03japan-mothers',
#    'section': 'World',
#    'subsection': 'Asia Pacific',
#    'title': 'Japan’s Working Mothers: Record Responsibilities, Little Help From Dads',
#    'abstract': 'Men in Japan do fewer hours of housework and child care than in any of the world’s richest nations. That keeps women from getting better jobs and holds back the economy.',
#    'url': 'https://www.nytimes.com/2019/02/02/world/asia/japan-working-mothers.html',
#    'byline': 'By MOTOKO RICH',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-02-15T17:32:56-05:00',
#    'created_date': '2019-02-02T05:00:34-05:00',
#    'published_date': '2019-02-01T19:00:00-05:00',
#    'first_published_date': '2019-02-02T05:00:11-05:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Women and Girls',
#     'Working Hours',
#     'Discrimination',
#     'Economic Conditions and Trends'],
#    'org_facet': ['Parenting', 'Labor and Jobs'],
#    'per_facet': '',
#    'geo_facet': ['Japan'],
#    'related_urls': [{'suggested_link_text': 'Our Tokyo Bureau Chief on Where She Finds ‘Bolts of Insight’ (Hint: It’s Outside the Office)',
#      'url': 'https://www.nytimes.com/2019/02/01/reader-center/motoko-rich-behind-the-byline.html'}],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/02/06/world/xxworkingmothers-ss-slide-2TSX/xxworkingmothers-ss-slide-2TSX-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Kazuko Yoshida doing the family’s laundry after dinner.',
#      'copyright': 'Andrea DiCenzo for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/02/06/world/xxworkingmothers-ss-slide-2TSX/xxworkingmothers-ss-slide-2TSX-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Kazuko Yoshida doing the family’s laundry after dinner.',
#      'copyright': 'Andrea DiCenzo for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/02/06/world/xxworkingmothers-ss-slide-2TSX/xxworkingmothers-ss-slide-2TSX-mediumThreeByTwo210-v5.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Kazuko Yoshida doing the family’s laundry after dinner.',
#      'copyright': 'Andrea DiCenzo for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/02/06/world/xxworkingmothers-ss-slide-2TSX/xxworkingmothers-ss-slide-2TSX-mediumThreeByTwo440-v5.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Kazuko Yoshida doing the family’s laundry after dinner.',
#      'copyright': 'Andrea DiCenzo for The New York Times'}]},
#   1: {'slug_name': '11readers-japan',
#    'section': 'Reader Center',
#    'subsection': '',
#    'title': 'Japan Is Among the Hardest Countries for Working Mothers. These Families Want to Change That.',
#    'abstract': 'Men in Japan do fewer hours of domestic work than in any other wealthy nation. Mothers and fathers there told us how they’ve managed to buck the norm.',
#    'url': 'https://www.nytimes.com/2019/04/11/reader-center/japan-women-parenting-work.html',
#    'byline': 'By LARA TAKENAGA',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-11T10:23:19-04:00',
#    'created_date': '2019-04-11T08:34:14-04:00',
#    'published_date': '2019-04-10T20:00:00-04:00',
#    'first_published_date': '2019-04-11T08:32:44-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Families and Family Life',
#     'Work-Life Balance',
#     'Part-Time Employment',
#     'Politics and Government'],
#    'org_facet': ['Children and Childhood',
#     'Parenting',
#     'Labor and Jobs',
#     'Child Care',
#     'Workplace Environment'],
#    'per_facet': '',
#    'geo_facet': ['Japan'],
#    'related_urls': None,
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/02/12/fashion/00readers-japan-eri/00readers-japan-eri-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Eri Gustke at home with her infant son and daughter.',
#      'copyright': 'Eri Gustke'},
#     {'url': 'https://static01.nyt.com/images/2019/02/12/fashion/00readers-japan-eri/00readers-japan-eri-articleInline.jpg',
#      'format': 'Normal',
#      'height': 143,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Eri Gustke at home with her infant son and daughter.',
#      'copyright': 'Eri Gustke'},
#     {'url': 'https://static01.nyt.com/images/2019/02/12/fashion/00readers-japan-eri/00readers-japan-eri-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Eri Gustke at home with her infant son and daughter.',
#      'copyright': 'Eri Gustke'},
#     {'url': 'https://static01.nyt.com/images/2019/02/12/fashion/00readers-japan-eri/00readers-japan-eri-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Eri Gustke at home with her infant son and daughter.',
#      'copyright': 'Eri Gustke'}]}},
#  {},
#  {0: {'slug_name': '07hongkong-extradition',
#    'section': 'World',
#    'subsection': 'Asia Pacific',
#    'title': 'Fearing China’s Rule, Hong Kong Residents Resist Extradition Plan',
#    'abstract': 'The fight against the proposal has become the most serious showdown between the public and the authorities since the Umbrella protests in 2014 demanding free elections.',
#    'url': 'https://www.nytimes.com/2019/06/07/world/asia/hong-kong-china-extradition-protest.html',
#    'byline': 'By AUSTIN RAMZY and KATHERINE LI',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-06-09T01:36:07-04:00',
#    'created_date': '2019-06-07T11:19:32-04:00',
#    'published_date': '2019-06-06T20:00:00-04:00',
#    'first_published_date': '2019-06-07T11:18:02-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Politics and Government',
#     'Extradition',
#     'Political Prisoners',
#     'Demonstrations, Protests and Riots'],
#    'org_facet': ['Human Rights and Human Rights Violations'],
#    'per_facet': '',
#    'geo_facet': ['China', 'Hong Kong'],
#    'related_urls': [{'suggested_link_text': 'Havoc in Hong Kong Legislature Over Extradition Bill',
#      'url': 'https://www.nytimes.com/2019/05/11/world/asia/hong-kong-extradition-law.html'},
#     {'suggested_link_text': 'Hong Kong Umbrella Movement Leaders Are Sentenced to Prison',
#      'url': 'https://www.nytimes.com/2019/04/23/world/asia/hong-kong-umbrella-movement.html'},
#     {'suggested_link_text': 'Despite Fears About China, Hong Kong Pushes Ahead on Extradition Bill',
#      'url': 'https://www.nytimes.com/2019/04/03/world/asia/hong-kong-extradition-law-china.html'},
#     {'suggested_link_text': 'Murder Case Poses Dilemma for Hong Kong on Sending Suspects to China',
#      'url': 'https://www.nytimes.com/2019/03/04/world/asia/hong-kong-china-extradition.html'}],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/06/08/world/08hongkong-extradition-1/08hongkong-extradition-1-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Prominent lawyers in Hong Kong marched on Thursday to protest a bill that would allow extraditions to mainland China.',
#      'copyright': 'Isaac Lawrence/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/06/08/world/08hongkong-extradition-1/merlin_156026817_1a2a1936-7c25-46d2-97db-454fa7f31f07-articleInline.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Prominent lawyers in Hong Kong marched on Thursday to protest a bill that would allow extraditions to mainland China.',
#      'copyright': 'Isaac Lawrence/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/06/08/world/08hongkong-extradition-1/merlin_156026817_1a2a1936-7c25-46d2-97db-454fa7f31f07-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Prominent lawyers in Hong Kong marched on Thursday to protest a bill that would allow extraditions to mainland China.',
#      'copyright': 'Isaac Lawrence/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/06/08/world/08hongkong-extradition-1/merlin_156026817_1a2a1936-7c25-46d2-97db-454fa7f31f07-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Prominent lawyers in Hong Kong marched on Thursday to protest a bill that would allow extraditions to mainland China.',
#      'copyright': 'Isaac Lawrence/Agence France-Presse — Getty Images'}]},
#   1: {'slug_name': '11hongkong',
#    'section': 'World',
#    'subsection': 'Asia Pacific',
#    'title': 'Havoc in Hong Kong Legislature Over Extradition Bill',
#    'abstract': 'Lawmakers scuffled Saturday over legislation that would let the city send people suspected of crimes to mainland China, among other places.',
#    'url': 'https://www.nytimes.com/2019/05/11/world/asia/hong-kong-extradition-law.html',
#    'byline': 'By AUSTIN RAMZY',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-05-13T01:28:38-04:00',
#    'created_date': '2019-05-11T04:21:24-04:00',
#    'published_date': '2019-05-10T20:00:00-04:00',
#    'first_published_date': '2019-05-11T04:19:53-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Politics and Government', 'Legislatures and Parliaments'],
#    'org_facet': ['Extradition'],
#    'per_facet': '',
#    'geo_facet': ['Hong Kong', 'China'],
#    'related_urls': [{'suggested_link_text': 'Murder Case Poses Dilemma for Hong Kong on Sending Suspects to China',
#      'url': 'https://www.nytimes.com/2019/03/04/world/asia/hong-kong-china-extradition.html'},
#     {'suggested_link_text': 'Despite Fears About China, Hong Kong Pushes Ahead on Extradition Bill',
#      'url': 'https://www.nytimes.com/2019/04/03/world/asia/hong-kong-extradition-law-china.html'},
#     {'suggested_link_text': 'Journalist’s Expulsion Casts Shadow on Hong Kong’s Future',
#      'url': 'https://www.nytimes.com/2018/11/02/world/asia/hong-kong-journalist-financial-times.html'}],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/05/11/world/11hongkong4/11hongkong4-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Wu Chi-wai, a pro-democracy lawmaker, struggled with security guards.',
#      'copyright': 'Vincent Yu/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2019/05/11/world/11hongkong4/merlin_154682670_a79c586f-1f1a-4d31-832e-c26dd1b84b4b-articleInline.jpg',
#      'format': 'Normal',
#      'height': 137,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Wu Chi-wai, a pro-democracy lawmaker, struggled with security guards.',
#      'copyright': 'Vincent Yu/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2019/05/11/world/11hongkong4/11hongkong4-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Wu Chi-wai, a pro-democracy lawmaker, struggled with security guards.',
#      'copyright': 'Vincent Yu/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2019/05/11/world/11hongkong4/11hongkong4-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Wu Chi-wai, a pro-democracy lawmaker, struggled with security guards.',
#      'copyright': 'Vincent Yu/Associated Press'}]},
#   2: {'slug_name': '03hongkong',
#    'section': 'World',
#    'subsection': 'Asia Pacific',
#    'title': 'Despite Fears About China, Hong Kong Pushes Ahead on Extradition Bill',
#    'abstract': 'Rules meant to allow the authorities to send a murder suspect to Taiwan have stirred fears that residents would be left without protection from mainland China’s legal system.',
#    'url': 'https://www.nytimes.com/2019/04/03/world/asia/hong-kong-extradition-law-china.html',
#    'byline': 'By AUSTIN RAMZY',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-04-03T23:43:19-04:00',
#    'created_date': '2019-04-03T08:13:09-04:00',
#    'published_date': '2019-04-02T20:00:00-04:00',
#    'first_published_date': '2019-04-03T08:11:38-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Politics and Government',
#     'Extradition',
#     'Law and Legislation',
#     'Fugitives'],
#    'org_facet': ['Human Rights and Human Rights Violations'],
#    'per_facet': '',
#    'geo_facet': ['China', 'Hong Kong'],
#    'related_urls': [{'suggested_link_text': 'Hong Kong’s Courts Have Defended Its Freedoms. Is Beijing Changing That?',
#      'url': 'https://www.nytimes.com/2018/02/05/world/asia/china-hong-kong-courts.html'},
#     {'suggested_link_text': 'Murder Case Poses Dilemma for Hong Kong on Sending Suspects to China',
#      'url': 'https://www.nytimes.com/2019/03/04/world/asia/hong-kong-china-extradition.html'}],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/03/world/03hongkong1/03hongkong1-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Thousands of protesters marched in Hong Kong on Sunday to express opposition to a proposed overhaul of extradition laws.',
#      'copyright': 'Dale De La Rey/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/04/03/world/03hongkong1/03hongkong1-articleInline.jpg',
#      'format': 'Normal',
#      'height': 131,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Thousands of protesters marched in Hong Kong on Sunday to express opposition to a proposed overhaul of extradition laws.',
#      'copyright': 'Dale De La Rey/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/04/03/world/03hongkong1/03hongkong1-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Thousands of protesters marched in Hong Kong on Sunday to express opposition to a proposed overhaul of extradition laws.',
#      'copyright': 'Dale De La Rey/Agence France-Presse — Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/04/03/world/03hongkong1/03hongkong1-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Thousands of protesters marched in Hong Kong on Sunday to express opposition to a proposed overhaul of extradition laws.',
#      'copyright': 'Dale De La Rey/Agence France-Presse — Getty Images'}]}},
#  {0: {'slug_name': '08dc-immig',
#    'section': 'U.S.',
#    'subsection': 'Politics',
#    'title': 'Mexico Agreed to Take Border Actions Months Before Trump Announced Tariff Deal',
#    'abstract': 'President Trump announced an agreement just before punishing tariffs went into effect, but it was unclear whether he saw it as truly new concessions or a face-saving way to defuse his tariff threat.',
#    'url': 'https://www.nytimes.com/2019/06/08/us/politics/trump-mexico-deal-tariffs.html',
#    'byline': 'By MICHAEL D. SHEAR and MAGGIE HABERMAN',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-06-09T14:42:18-04:00',
#    'created_date': '2019-06-08T16:04:13-04:00',
#    'published_date': '2019-06-07T20:00:00-04:00',
#    'first_published_date': '2019-06-08T16:02:43-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Illegal Immigration', 'Immigration and Emigration'],
#    'org_facet': ['United States International Relations',
#     'International Trade and World Market',
#     'Customs (Tariff)',
#     'Asylum, Right of',
#     'Border Barriers',
#     'United States Politics and Government'],
#    'per_facet': ['Trump, Donald J', 'McAleenan, Kevin K', 'Nielsen, Kirstjen'],
#    'geo_facet': ['Mexico'],
#    'related_urls': [{'suggested_link_text': 'Heroes of the Great Patriotic Trade War',
#      'url': 'https://www.nytimes.com/2019/06/09/opinion/heroes-of-the-great-patriotic-trade-war.html'},
#     {'suggested_link_text': 'Mexico Sets Domestic Priorities Aside to Meet Terms of U.S. Trade Deal',
#      'url': 'https://www.nytimes.com/2019/06/08/world/americas/mexico-tariffs-migration.html'},
#     {'suggested_link_text': 'Trump Is More Vulnerable to Democratic Attacks on Trade Than You Might Think',
#      'url': 'https://www.nytimes.com/2019/06/08/upshot/trump-is-more-vulnerable-to-democratic-attacks-on-trade-than-you-might-think.html'},
#     {'suggested_link_text': 'A Drama of Trump’s Own Making Ends With a Familiar Hero',
#      'url': 'https://www.nytimes.com/2019/06/09/us/politics/a-drama-of-trumps-own-making-ends-with-a-familiar-hero.html'},
#     {'suggested_link_text': 'Death on the Rio Grande: A Look at a Perilous Migrant Route',
#      'url': 'https://www.nytimes.com/2019/06/08/us/politics/migrants-drown-rio-grande.html'},
#     {'suggested_link_text': 'As Trade War Spreads to Mexico, Companies Lose a Safe Harbor',
#      'url': 'https://www.nytimes.com/2019/06/01/business/economy/trump-trade-tariffs-mexico-cost.html'},
#     {'suggested_link_text': 'U.S. and Mexico Issue Joint Declaration on Migration and Tariffs',
#      'url': 'https://www.nytimes.com/2019/06/07/us/state-department-mexico-trump.html'},
#     {'suggested_link_text': 'Trump Says U.S. Will Hit Mexico With 5% Tariffs on All Goods',
#      'url': 'https://www.nytimes.com/2019/05/30/us/politics/trump-mexico-tariffs.html'}],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/06/08/us/08dc-immig-03-promo/08dc-immig-03-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Migrants passing through the Rio Grande from Mexico into the United States last month.',
#      'copyright': 'Mario Tama/Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/06/08/us/08dc-immig-03-promo/merlin_155173698_098d8789-ad3b-42e5-b3d1-ed79f84b6e86-articleInline.jpg',
#      'format': 'Normal',
#      'height': 129,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Migrants passing through the Rio Grande from Mexico into the United States last month.',
#      'copyright': 'Mario Tama/Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/06/08/us/08dc-immig-03-promo/08dc-immig-03-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Migrants passing through the Rio Grande from Mexico into the United States last month.',
#      'copyright': 'Mario Tama/Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2019/06/08/us/08dc-immig-03-promo/08dc-immig-03-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Migrants passing through the Rio Grande from Mexico into the United States last month.',
#      'copyright': 'Mario Tama/Getty Images'}]}},
#  {},
#  {},
#  {},
#  {}]

# %% [markdown]
# # 3 Collect Layer 3 urls
# ##### TODO Troubleshoot layer 3 urls to map are not working correctly

# %%
layer3_urls = []
for x in range(len(layer1)):
    layer3_urls.append(layer3Relations(layer1[x][0], layer2_data[x]))

# %%
layer3_urls
# Out:
# [[{'suggested_link_text': 'Spring Brings Surge of Migrants, Stretching Border Facilities Far Beyond Capacity',
#    'url': 'https://www.nytimes.com/2019/03/30/us/border-migrants-el-paso-bridge-spring-surge.html'},
#   {'suggested_link_text': 'Trump’s Surprising New Ally in Mexico? The Government',
#    'url': 'https://www.nytimes.com/2019/03/01/world/americas/mexico-migration-trump.html'}],
#  [{'suggested_link_text': 'Iranian Protesters Ransack Saudi Embassy After Execution of Shiite Cleric',
#    'url': 'https://www.nytimes.com/2016/01/03/world/middleeast/saudi-arabia-executes-47-sheikh-nimr-shiite-cleric.html'}],
#  [{'suggested_link_text': 'Havoc in Hong Kong Legislature Over Extradition Bill',
#    'url': 'https://www.nytimes.com/2019/05/11/world/asia/hong-kong-extradition-law.html'}],
#  [{'suggested_link_text': 'New Prison Rule in Russia: No Swearing',
#    'url': 'https://www.nytimes.com/2016/01/15/world/europe/russia-bans-foul-language-in-some-prisons-no-word-on-enforcement.html'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %% [markdown]
# # Collect Layer 3 Data

# %%
layer3_data = []
for article_group in range(len(layer3_urls)):
    layer3_data.append(dataLayerFromRelated(layer3_urls[article_group]))
# Out:
# https://www.nytimes.com/2019/03/30/us/border-migrants-el-paso-bridge-spring-surge.html
# https://www.nytimes.com/2019/03/01/world/americas/mexico-migration-trump.html
# https://www.nytimes.com/2016/01/03/world/middleeast/saudi-arabia-executes-47-sheikh-nimr-shiite-cleric.html
# https://www.nytimes.com/2019/05/11/world/asia/hong-kong-extradition-law.html
# https://www.nytimes.com/2016/01/15/world/europe/russia-bans-foul-language-in-some-prisons-no-word-on-enforcement.html

# %%
layer3_data[0]
# Out:
# {0: {'slug_name': '30SPRINGSURGE',
#   'section': 'U.S.',
#   'subsection': '',
#   'title': 'Spring Brings Surge of Migrants, Stretching Border Facilities Far Beyond Capacity',
#   'abstract': 'Migration along the southern border typically increases in the spring, but authorities said the current numbers have reached “unmanageable” levels.',
#   'url': 'https://www.nytimes.com/2019/03/30/us/border-migrants-el-paso-bridge-spring-surge.html',
#   'byline': 'By MIRIAM JORDAN and SIMON ROMERO',
#   'item_type': 'Article',
#   'source': 'The New York Times',
#   'updated_date': '2019-03-31T12:59:26-04:00',
#   'created_date': '2019-03-30T11:51:32-04:00',
#   'published_date': '2019-03-29T20:00:00-04:00',
#   'first_published_date': '2019-03-30T11:50:02-04:00',
#   'material_type_facet': 'News',
#   'kicker': None,
#   'subheadline': None,
#   'des_facet': ['Illegal Immigration',
#    'Immigration and Emigration',
#    'Immigration Detention'],
#   'org_facet': ['Border Patrol (US)',
#    'Customs and Border Protection (US)',
#    'Homeland Security Department',
#    'United States Politics and Government'],
#   'per_facet': ['McAleenan, Kevin K', 'Nielsen, Kirstjen', 'Trump, Donald J'],
#   'geo_facet': ['El Paso (Tex)', 'Texas'],
#   'related_urls': [{'suggested_link_text': 'Border Patrol Facilities Put Detainees With Medical Conditions at Risk',
#     'url': 'https://www.nytimes.com/2019/03/05/us/border-patrol-deaths-migrant-children.html'},
#    {'suggested_link_text': 'Migrants Are Detained Under a Bridge in El Paso. What Happened?',
#     'url': 'https://www.nytimes.com/2019/03/29/us/el-paso-immigration-photo.html'},
#    {'suggested_link_text': 'Former Trump Family Driver Has Been in ICE Custody for 8 Months',
#     'url': 'https://www.nytimes.com/2019/03/29/us/trump-driver-chauffeur-ice-romania.html'},
#    {'suggested_link_text': 'Border Officer’s Secret in Arizona: He Was Undocumented',
#     'url': 'https://www.nytimes.com/2019/03/28/us/border-patrol-agent-undocumented-immigrant.html'}],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/03/31/arts/31SPRINGSURGE-print2/31SPRINGSURGE-print2-thumbStandard-v2.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Migrants under the Paso del Norte bridge in El Paso, Tex., on Friday. The makeshift encampment was set up after the main border processing center reached up to 400 percent of its capacity.',
#     'copyright': 'Tamir Kalifa for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/03/31/arts/31SPRINGSURGE-print2/31SPRINGSURGE-print2-articleInline-v2.jpg',
#     'format': 'Normal',
#     'height': 137,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Migrants under the Paso del Norte bridge in El Paso, Tex., on Friday. The makeshift encampment was set up after the main border processing center reached up to 400 percent of its capacity.',
#     'copyright': 'Tamir Kalifa for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/03/31/arts/31SPRINGSURGE-print2/31SPRINGSURGE-print2-mediumThreeByTwo210-v2.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Migrants under the Paso del Norte bridge in El Paso, Tex., on Friday. The makeshift encampment was set up after the main border processing center reached up to 400 percent of its capacity.',
#     'copyright': 'Tamir Kalifa for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/03/31/arts/31SPRINGSURGE-print2/31SPRINGSURGE-print2-mediumThreeByTwo440-v2.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Migrants under the Paso del Norte bridge in El Paso, Tex., on Friday. The makeshift encampment was set up after the main border processing center reached up to 400 percent of its capacity.',
#     'copyright': 'Tamir Kalifa for The New York Times'}]},
#  1: {'slug_name': '02amlo',
#   'section': 'World',
#   'subsection': 'Americas',
#   'title': 'Trump’s Surprising New Ally in Mexico? The Government',
#   'abstract': 'Mexican officials say this prevents a fight with Trump and costs little, politically, at home. But it defies López Obrador’s promises to defend migrants.',
#   'url': 'https://www.nytimes.com/2019/03/01/world/americas/mexico-migration-trump.html',
#   'byline': 'By AZAM AHMED and KIRK SEMPLE',
#   'item_type': 'Article',
#   'source': 'The New York Times',
#   'updated_date': '2019-03-02T19:46:40-05:00',
#   'created_date': '2019-03-01T11:42:18-05:00',
#   'published_date': '2019-02-28T19:00:00-05:00',
#   'first_published_date': '2019-03-01T11:40:47-05:00',
#   'material_type_facet': 'News',
#   'kicker': None,
#   'subheadline': None,
#   'des_facet': ['Politics and Government',
#    'Immigration and Emigration',
#    'Asylum, Right of',
#    'United States International Relations'],
#   'org_facet': '',
#   'per_facet': ['Lopez Obrador, Andres Manuel', 'Trump, Donald J'],
#   'geo_facet': ['Mexico'],
#   'related_urls': None,
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/02/26/world/xxamlo2-promo/xxamlo2-promo-thumbStandard-v2.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Asylum seekers who have been waiting weeks for their turn to cross from Nuevo Laredo, Mexico, into Laredo, in the United States, camp out on the border crossing bridge in January.',
#     'copyright': 'Meridith Kohut for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/02/26/world/xxamlo2-promo/xxamlo2-promo-articleInline-v2.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Asylum seekers who have been waiting weeks for their turn to cross from Nuevo Laredo, Mexico, into Laredo, in the United States, camp out on the border crossing bridge in January.',
#     'copyright': 'Meridith Kohut for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/02/26/world/xxamlo2-promo/xxamlo2-promo-mediumThreeByTwo210-v2.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Asylum seekers who have been waiting weeks for their turn to cross from Nuevo Laredo, Mexico, into Laredo, in the United States, camp out on the border crossing bridge in January.',
#     'copyright': 'Meridith Kohut for The New York Times'},
#    {'url': 'https://static01.nyt.com/images/2019/02/26/world/xxamlo2-promo/xxamlo2-promo-mediumThreeByTwo440-v2.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'Asylum seekers who have been waiting weeks for their turn to cross from Nuevo Laredo, Mexico, into Laredo, in the United States, camp out on the border crossing bridge in January.',
#     'copyright': 'Meridith Kohut for The New York Times'}]}}

# %%
layer3_data[1]
# Out:
# {}

# %%
layer3_data
# Out:
# [{0: {'slug_name': '30SPRINGSURGE',
#    'section': 'U.S.',
#    'subsection': '',
#    'title': 'Spring Brings Surge of Migrants, Stretching Border Facilities Far Beyond Capacity',
#    'abstract': 'Migration along the southern border typically increases in the spring, but authorities said the current numbers have reached “unmanageable” levels.',
#    'url': 'https://www.nytimes.com/2019/03/30/us/border-migrants-el-paso-bridge-spring-surge.html',
#    'byline': 'By MIRIAM JORDAN and SIMON ROMERO',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-03-31T12:59:26-04:00',
#    'created_date': '2019-03-30T11:51:32-04:00',
#    'published_date': '2019-03-29T20:00:00-04:00',
#    'first_published_date': '2019-03-30T11:50:02-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Illegal Immigration',
#     'Immigration and Emigration',
#     'Immigration Detention'],
#    'org_facet': ['Border Patrol (US)',
#     'Customs and Border Protection (US)',
#     'Homeland Security Department',
#     'United States Politics and Government'],
#    'per_facet': ['McAleenan, Kevin K', 'Nielsen, Kirstjen', 'Trump, Donald J'],
#    'geo_facet': ['El Paso (Tex)', 'Texas'],
#    'related_urls': [{'suggested_link_text': 'Border Patrol Facilities Put Detainees With Medical Conditions at Risk',
#      'url': 'https://www.nytimes.com/2019/03/05/us/border-patrol-deaths-migrant-children.html'},
#     {'suggested_link_text': 'Migrants Are Detained Under a Bridge in El Paso. What Happened?',
#      'url': 'https://www.nytimes.com/2019/03/29/us/el-paso-immigration-photo.html'},
#     {'suggested_link_text': 'Former Trump Family Driver Has Been in ICE Custody for 8 Months',
#      'url': 'https://www.nytimes.com/2019/03/29/us/trump-driver-chauffeur-ice-romania.html'},
#     {'suggested_link_text': 'Border Officer’s Secret in Arizona: He Was Undocumented',
#      'url': 'https://www.nytimes.com/2019/03/28/us/border-patrol-agent-undocumented-immigrant.html'}],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/03/31/arts/31SPRINGSURGE-print2/31SPRINGSURGE-print2-thumbStandard-v2.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Migrants under the Paso del Norte bridge in El Paso, Tex., on Friday. The makeshift encampment was set up after the main border processing center reached up to 400 percent of its capacity.',
#      'copyright': 'Tamir Kalifa for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/03/31/arts/31SPRINGSURGE-print2/31SPRINGSURGE-print2-articleInline-v2.jpg',
#      'format': 'Normal',
#      'height': 137,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Migrants under the Paso del Norte bridge in El Paso, Tex., on Friday. The makeshift encampment was set up after the main border processing center reached up to 400 percent of its capacity.',
#      'copyright': 'Tamir Kalifa for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/03/31/arts/31SPRINGSURGE-print2/31SPRINGSURGE-print2-mediumThreeByTwo210-v2.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Migrants under the Paso del Norte bridge in El Paso, Tex., on Friday. The makeshift encampment was set up after the main border processing center reached up to 400 percent of its capacity.',
#      'copyright': 'Tamir Kalifa for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/03/31/arts/31SPRINGSURGE-print2/31SPRINGSURGE-print2-mediumThreeByTwo440-v2.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Migrants under the Paso del Norte bridge in El Paso, Tex., on Friday. The makeshift encampment was set up after the main border processing center reached up to 400 percent of its capacity.',
#      'copyright': 'Tamir Kalifa for The New York Times'}]},
#   1: {'slug_name': '02amlo',
#    'section': 'World',
#    'subsection': 'Americas',
#    'title': 'Trump’s Surprising New Ally in Mexico? The Government',
#    'abstract': 'Mexican officials say this prevents a fight with Trump and costs little, politically, at home. But it defies López Obrador’s promises to defend migrants.',
#    'url': 'https://www.nytimes.com/2019/03/01/world/americas/mexico-migration-trump.html',
#    'byline': 'By AZAM AHMED and KIRK SEMPLE',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-03-02T19:46:40-05:00',
#    'created_date': '2019-03-01T11:42:18-05:00',
#    'published_date': '2019-02-28T19:00:00-05:00',
#    'first_published_date': '2019-03-01T11:40:47-05:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Politics and Government',
#     'Immigration and Emigration',
#     'Asylum, Right of',
#     'United States International Relations'],
#    'org_facet': '',
#    'per_facet': ['Lopez Obrador, Andres Manuel', 'Trump, Donald J'],
#    'geo_facet': ['Mexico'],
#    'related_urls': None,
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/02/26/world/xxamlo2-promo/xxamlo2-promo-thumbStandard-v2.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Asylum seekers who have been waiting weeks for their turn to cross from Nuevo Laredo, Mexico, into Laredo, in the United States, camp out on the border crossing bridge in January.',
#      'copyright': 'Meridith Kohut for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/02/26/world/xxamlo2-promo/xxamlo2-promo-articleInline-v2.jpg',
#      'format': 'Normal',
#      'height': 127,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Asylum seekers who have been waiting weeks for their turn to cross from Nuevo Laredo, Mexico, into Laredo, in the United States, camp out on the border crossing bridge in January.',
#      'copyright': 'Meridith Kohut for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/02/26/world/xxamlo2-promo/xxamlo2-promo-mediumThreeByTwo210-v2.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Asylum seekers who have been waiting weeks for their turn to cross from Nuevo Laredo, Mexico, into Laredo, in the United States, camp out on the border crossing bridge in January.',
#      'copyright': 'Meridith Kohut for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2019/02/26/world/xxamlo2-promo/xxamlo2-promo-mediumThreeByTwo440-v2.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Asylum seekers who have been waiting weeks for their turn to cross from Nuevo Laredo, Mexico, into Laredo, in the United States, camp out on the border crossing bridge in January.',
#      'copyright': 'Meridith Kohut for The New York Times'}]}},
#  {},
#  {0: {'slug_name': '11hongkong',
#    'section': 'World',
#    'subsection': 'Asia Pacific',
#    'title': 'Havoc in Hong Kong Legislature Over Extradition Bill',
#    'abstract': 'Lawmakers scuffled Saturday over legislation that would let the city send people suspected of crimes to mainland China, among other places.',
#    'url': 'https://www.nytimes.com/2019/05/11/world/asia/hong-kong-extradition-law.html',
#    'byline': 'By AUSTIN RAMZY',
#    'item_type': 'Article',
#    'source': 'The New York Times',
#    'updated_date': '2019-05-13T01:28:38-04:00',
#    'created_date': '2019-05-11T04:21:24-04:00',
#    'published_date': '2019-05-10T20:00:00-04:00',
#    'first_published_date': '2019-05-11T04:19:53-04:00',
#    'material_type_facet': 'News',
#    'kicker': None,
#    'subheadline': None,
#    'des_facet': ['Politics and Government', 'Legislatures and Parliaments'],
#    'org_facet': ['Extradition'],
#    'per_facet': '',
#    'geo_facet': ['Hong Kong', 'China'],
#    'related_urls': [{'suggested_link_text': 'Murder Case Poses Dilemma for Hong Kong on Sending Suspects to China',
#      'url': 'https://www.nytimes.com/2019/03/04/world/asia/hong-kong-china-extradition.html'},
#     {'suggested_link_text': 'Despite Fears About China, Hong Kong Pushes Ahead on Extradition Bill',
#      'url': 'https://www.nytimes.com/2019/04/03/world/asia/hong-kong-extradition-law-china.html'},
#     {'suggested_link_text': 'Journalist’s Expulsion Casts Shadow on Hong Kong’s Future',
#      'url': 'https://www.nytimes.com/2018/11/02/world/asia/hong-kong-journalist-financial-times.html'}],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2019/05/11/world/11hongkong4/11hongkong4-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Wu Chi-wai, a pro-democracy lawmaker, struggled with security guards.',
#      'copyright': 'Vincent Yu/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2019/05/11/world/11hongkong4/merlin_154682670_a79c586f-1f1a-4d31-832e-c26dd1b84b4b-articleInline.jpg',
#      'format': 'Normal',
#      'height': 137,
#      'width': 190,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Wu Chi-wai, a pro-democracy lawmaker, struggled with security guards.',
#      'copyright': 'Vincent Yu/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2019/05/11/world/11hongkong4/11hongkong4-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Wu Chi-wai, a pro-democracy lawmaker, struggled with security guards.',
#      'copyright': 'Vincent Yu/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2019/05/11/world/11hongkong4/11hongkong4-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Wu Chi-wai, a pro-democracy lawmaker, struggled with security guards.',
#      'copyright': 'Vincent Yu/Associated Press'}]}},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {}]

# %% [markdown]
# # Render Map with Article Groups as Layers

# %%
import wikipedia

# %%
mapTargets[1]
# Out:
# {'slug_name': '10Mali',
#  'section': 'World',
#  'subsection': 'Africa',
#  'title': 'Massacre in Mali Leaves at Least 95 Dead, Government Says',
#  'abstract': 'An attack on a village of the Dogon ethnic group in central Mali is the latest in violence that has displaced tens of thousands of civilians.',
#  'url': 'https://www.nytimes.com/2019/06/10/world/africa/mali-terrorism-dogon-fulani.html',
#  'byline': 'By THE ASSOCIATED PRESS',
#  'thumbnail_standard': '',
#  'item_type': 'Article',
#  'source': 'The New York Times',
#  'updated_date': '2019-06-10T16:02:25-04:00',
#  'created_date': '2019-06-10T15:31:32-04:00',
#  'published_date': '2019-06-09T20:00:00-04:00',
#  'first_published_date': '2019-06-10T15:30:02-04:00',
#  'material_type_facet': 'News',
#  'kicker': None,
#  'subheadline': None,
#  'des_facet': ['Terrorism'],
#  'org_facet': ['Dan Na Ambassagou'],
#  'per_facet': '',
#  'geo_facet': ['Mali'],
#  'related_urls': [{'suggested_link_text': 'Confronting Mali’s New Jihadist Threat',
#    'url': 'https://www.nytimes.com/2016/05/10/opinion/confronting-malis-new-jihadist-threat.html'},
#   {'suggested_link_text': 'Insecurity Shadows Mali’s President. It May Also Help Him Get Re-Elected.',
#    'url': 'https://www.nytimes.com/2018/07/27/world/africa/insecurity-shadows-malis-president-it-may-also-help-him-get-re-elected.html'},
#   {'suggested_link_text': 'As Refugees Flee Islamists in Mali, Solutions Are Elusive',
#    'url': 'https://www.nytimes.com/2012/07/16/world/africa/local-militia-bolsters-islamist-militants-in-mali.html'}],
#  'multimedia': ''}

# %%
news_map = mapArticleRelations(mapTargets[1]['url'])
# Out:
# Massacre in Mali Leaves at Least 95 Dead, Government Says
# Primary: Blue
# Layer 2 Relations: Red
# Layer 3 Relations: Green
# layer2  0
# layer3 0

# %% [markdown]
# #### TODO Save multiple versions of the map so that the web server can refresh the map to simulate streaming data

# %%
news_map
