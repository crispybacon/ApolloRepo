# %% [markdown]
# # NASA API Endpoints Workbook Page 1

# %% [markdown]
# ####By Jesse Bacon

# %%
# %matplotlib inline

# %%
import pandas, matplotlib, json, urllib, numpy, PIL
from PIL import Image as img
import matplotlib.pyplot as plt
from IPython.display import SVG, Image, HTML
from PIL.ExifTags import TAGS

# %%
key=''

# %%
# %matplotlib inline

# %% [markdown]
# # APOD

# %% [raw]
# APOD
#
# GET https://api.data.gov/nasa/planetary/apod
#
# Query Parameters
#
# Paramter        Type        Default     Description
# date	        YYYY-MM-DD	today	    The date of the APOD image to retrieve
# concept_tags	bool	    False	    Return an ordered dictionary of concepts from the APOD explanation
# api_key	        string	    DEMO_KEY	api.data.gov key for expanded usage
#
# EXAMPLE QUERY
#
# https://api.data.gov/nasa/planetary/apod?concept_tags=True&api_key=DEMO_KEY

# %%
def APOD(date, concept_tags):
    """
    One of the most popular websites at NASA is the Astronomy Picture of the Day. In fact, this website is one of the most popular websites across all federal agencies. It has the popular appeal of a Justin Bieber video. This endpoint structures the APOD imagery and associated metadata so that it can be repurposed for other applications. In addition, if the concept_tags parameter is set to True, then keywords derived from the image explanation are returned. These keywords could be used as auto-generated hashtags for twitter or instagram feeds; but generally help with discoverability of relevant imagery.
    APOD

    GET https://api.data.gov/nasa/planetary/apod

    Query Parameters

    Paramter        Type        Default     Description
    date	        YYYY-MM-DD	today	    The date of the APOD image to retrieve
    concept_tags	bool	    False	    Return an ordered dictionary of concepts from the APOD explanation
    api_key	        string	    DEMO_KEY	api.data.gov key for expanded usage

    EXAMPLE QUERY

    https://api.data.gov/nasa/planetary/apod?concept_tags=True&api_key=DEMO_KEY
    """
    request='https://api.data.gov/nasa/planetary/apod'
    key=''
    form={'date': date, 'concept_tags': concept_tags, 'api_key': key}
    query=urllib.urlencode(form)
    APOD_request=urllib.urlopen(request+"?"+query)
    print(APOD_request.info())
    response=json.loads(APOD_request.read())
    print('Title: ' + response['title'])
    print('Date: ' + response['date'])
    print('Explanation: '+ response['explanation'])
    print('URL : ' + response['url'])
    fname=str('APOD'+'_'+date+'.jpg')
    apod_img=urllib.urlretrieve(response['url'], fname)
    im=img.open(fname)
    display=plt.imread(fname)
    plt.imshow(display)
    PIL_format=PIL.Image.open(fname)
    exif_data = PIL_format._getexif()
    #print(exif_data)
    ret = {}
    for tag, value in exif_data.items():
        decoded = TAGS.get(tag, tag)
        ret[decoded] = value
    return ret, response
    #print(exif_data.keys())
    #print(exif_data.values())

# %%
APOD('2015-4-12','True')
# Out:
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=0.5
# cache-control: no-cache
# Content-Type: application/json
# Date: Sun, 12 Apr 2015 20:03:24 GMT
# Server: nginx
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 969
# x-varnish: 1083628
# Content-Length: 999
# Connection: Close
#
# Title: Sentinels of the Arctic
# Date: 2015-4-12
# Explanation: Who guards the north?  Judging from the above photograph, possibly giant trees covered in snow and ice. The featured picture was taken a few winters ago in Finnish Lapland where weather can include sub-freezing temperatures and driving snow.  Surreal landscapes sometimes result, where common trees become cloaked in white and so appear, to some, as watchful aliens. Far in the distance, behind this uncommon Earthly vista, is a more common sight -- a Belt of Venus that divided a darkened from sunlit sky as the Sun rose behind the photographer. Of course, in the spring, the trees thaw and Lapland looks much  different.   Follow APOD on: Facebook,  Google Plus, or Twitter
# URL : http://apod.nasa.gov/apod/image/1205/snowtrees_bonfadini_960.jpg
# ({},
#  {u'concept_tags': True,
#   u'concepts': {u'0': u'Sun',
#    u'1': u'Solar System',
#    u'2': u'Finland',
#    u'3': u'Light',
#    u'4': u'Yahoo!',
#    u'5': u'Google',
#    u'6': u'Snow',
#    u'7': u'Social network service'},
#   u'date': u'2015-4-12',
#   u'explanation': u'Who guards the north?  Judging from the above photograph, possibly giant trees covered in snow and ice. The featured picture was taken a few winters ago in Finnish Lapland where weather can include sub-freezing temperatures and driving snow.  Surreal landscapes sometimes result, where common trees become cloaked in white and so appear, to some, as watchful aliens. Far in the distance, behind this uncommon Earthly vista, is a more common sight -- a Belt of Venus that divided a darkened from sunlit sky as the Sun rose behind the photographer. Of course, in the spring, the trees thaw and Lapland looks much  different.   Follow APOD on: Facebook,  Google Plus, or Twitter',
#   u'title': u'Sentinels of the Arctic',
#   u'url': u'http://apod.nasa.gov/apod/image/1205/snowtrees_bonfadini_960.jpg'})

# %%
APOD('2014-7-31','True')
# Out:
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=0.5
# cache-control: no-cache
# Content-Type: application/json
# Date: Sun, 12 Apr 2015 20:04:19 GMT
# Server: nginx
# vary: Accept-Encoding
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 970
# x-varnish: 450798
# Content-Length: 1028
# Connection: Close
#
# Title: Veins of Heaven
# Date: 2014-7-31
# Explanation: Transfusing sunlight through a still dark sky, this exceptional display of noctilucent clouds was captured earlier this month above the island of Gotland, Sweden. From the edge of space, about 80 kilometers above Earth's surface, the icy clouds reflect sunlight even though the Sun itself is below the horizon as seen from the ground. Usually spotted at high latitudes in summer months the night shining clouds made a strong showing this July. Also known as polar mesopheric clouds they are understood to form as water vapor driven into the cold upper atmosphere condenses on the fine dust particles supplied by disintegrating meteors or volcanic ash. NASA's AIM mission provides daily projections of noctilucent clouds as seen from space.
# URL : http://apod.nasa.gov/apod/image/1407/strongNLCs_heden.jpg
# ({'ApertureValue': (433985, 100000),
#   'BitsPerSample': (8, 8, 8),
#   'ColorSpace': 1,
#   'DateTime': u'2014:07:17 23:37:07',
#   'DateTimeDigitized': u'2016:06:19 09:24:39',
#   'DateTimeOriginal': u'2016:06:19 09:24:39',
#   'ExifImageHeight': 529,
#   'ExifImageWidth': 1500,
#   'ExifOffset': 232,
#   'ExifVersion': '0221',
#   'ExposureTime': (1000000000, 769230769),
#   'FNumber': (1000000000, 222222222),
#   'ImageLength': 5268,
#   'ImageWidth': 10893,
#   'Orientation': 1,
#   'PhotometricInterpretation': 2,
#   'ResolutionUnit': 2,
#   'SamplesPerPixel': 3,
#   'Software': u'Adobe Photoshop CS6 (Windows)',
#   'XResolution': (720000, 10000),
#   'YResolution': (720000, 10000)},
#  {u'concept_tags': True,
#   u'concepts': {u'0': u'Earth',
#    u'1': u'Sun',
#    u'2': u'Atmosphere',
#    u'3': u'Volcano',
#    u'4': u'Sky',
#    u'5': u'Mars',
#    u'6': u'Water',
#    u'7': u'Latitude'},
#   u'date': u'2014-7-31',
#   u'explanation': u"Transfusing sunlight through a still dark sky, this exceptional display of noctilucent clouds was captured earlier this month above the island of Gotland, Sweden. From the edge of space, about 80 kilometers above Earth's surface, the icy clouds reflect sunlight even though the Sun itself is below the horizon as seen from the ground. Usually spotted at high latitudes in summer months the night shining clouds made a strong showing this July. Also known as polar mesopheric clouds they are understood to form as water vapor driven into the cold upper atmosphere condenses on the fine dust particles supplied by disintegrating meteors or volcanic ash. NASA's AIM mission provides daily projections of noctilucent clouds as seen from space.",
#   u'title': u'Veins of Heaven',
#   u'url': u'http://apod.nasa.gov/apod/image/1407/strongNLCs_heden.jpg'})

# %% [markdown]
# # Geocode

# %%
def geocode(address):
    """
    Return Lat/Long of an Address from Google
    """
    form = {"address": address, "sensor": "false",}
    google_req = "https://maps.googleapis.com/maps/api/geocode/json"
    query = urllib.urlencode(form)
    base_req=(google_req+"?"+query)
    geocode=urllib.urlopen(base_req)
    print(geocode.headers)
    response=json.loads(geocode.read().decode('UTF-8'))
    print('Address: '+ response['results'][0]['formatted_address'])
    point=response['results'][0]['geometry']['location']
    print(point)
    return point['lat'], point['lng']

# %%
x=geocode('4329 Henry Dr. Newbury Park CA')
# Out:
# Content-Type: application/json; charset=UTF-8
# Date: Sun, 12 Apr 2015 18:31:42 GMT
# Expires: Mon, 13 Apr 2015 18:31:42 GMT
# Cache-Control: public, max-age=86400
# Access-Control-Allow-Origin: *
# Server: mafe
# X-XSS-Protection: 1; mode=block
# X-Frame-Options: SAMEORIGIN
# Alternate-Protocol: 443:quic,p=0.5
# Accept-Ranges: none
# Vary: Accept-Language,Accept-Encoding
#
# Address: 4329 Henry Drive, Newbury Park, CA 91320, USA
# {u'lat': 34.183578, u'lng': -118.9491215}

# %% [markdown]
# # Earth Imagery (landsat8)

# %% [raw]
# HTTP REQUEST
#
# GET https://api.data.gov/nasa/planetary/earth/imagery
#
# QUERY PARAMETERS
# Parameter	Type	    Default	    Description
# lat	        float	    n/a	        Latitude
# lon	        float	    n/a	        Longitude
# dim	        float	    0.025	    width and height of image in degrees
# cloud_score	bool	    False	    calculate the percentage of the image covered by clouds
# api_key	    string	    DEMO_KEY	api.data.gov key for expanded usage
# date	    YYYY-MM-DD	today	    date of image; if not supplied, then the most recent image (i.e., closest to today) is returned
#
# EXAMPLE QUERY
#
# https://api.data.gov/nasa/planetary/earth/imagery?lon=100.75&lat=1.5&date=2014-02-01&cloud_score=True&api_key=DEMO_KEY

# %%
def landsat8(lat, lon, dim, cloud_score, target_date):
    """
    Imagery
    This endpoint retrieves the Landsat 8 image for the supplied location and date. The response will include the date and URL to the image that is closest to the supplied date. The requested resource may not be available for the exact date in the request. You can retrieve a list of available resources through the assets endpoint.
    The cloud score is an optional calculation that returns the percentage of the queried image that is covered by clouds. If False is supplied to the cloud_score parameter, then no keypair is returned. If True is supplied, then a keypair will always be returned, even if the backend algorithm is not able to calculate a score. Note that this is a rough calculation, mainly used to filter out exceedingly cloudy images.
    QUERY PARAMETERS
    Parameter	Type	    Default	    Description
    lat	        float	    n/a	        Latitude
    lon	        float	    n/a	        Longitude
    dim	        float	    0.025	    width and height of image in degrees
    cloud_score	bool	    False	    calculate the percentage of the image covered by clouds
    api_key	    string	    DEMO_KEY	api.data.gov key for expanded usage
    date	    YYYY-MM-DD	today	    date of image; if not supplied, then the most recent image (i.e., closest to today) is returned
    landsat8('34.183578', '-118.9491215', '0.07', 'True', '2014-07-31')
    x=geocode('700 Pennsylvania Avenue NW DC')
    landsat8(x[0], x[1], '0.07', 'True', '2014-07-31')
    """
    request='https://api.data.gov/nasa/planetary/earth/imagery'
    key='avVkP0IKbxes8S3MVnAehU97VAS9vRMmbjbkYjm4'
    form={'lat': str(lat), 'lon': str(lon), 'dim': dim, 'cloud_score': cloud_score, 'date': target_date, 'api_key': key}
    query=urllib.urlencode(form)
    landsat8_request_string=urllib.urlopen(request+"?"+query)
    print(landsat8_request_string.info())
    response=json.loads(landsat8_request_string.read())
    print('date: ' + response['date'])
    print('cloud score: ' + str(response['cloud_score']))
    print('Planet: ' + response['resource']['planet'])
    print('Data Set: ' + response['resource']['dataset'])
    print('ID: ' + str(response['id']))
    print('URL: ' + str(response['url']))
    fname=str('landsat8'+'_'+target_date+'.png')
    landsat8_img=urllib.urlretrieve(response['url'], fname)
    im=img.open(fname)
    display=plt.imread(fname)
    plt.imshow(display)
    PIL_format=PIL.Image.open(fname)
    return response

# %%
x=geocode('700 Pennsylvania Avenue NW DC')
# Out:
# Content-Type: application/json; charset=UTF-8
# Date: Sun, 12 Apr 2015 20:04:38 GMT
# Expires: Mon, 13 Apr 2015 20:04:38 GMT
# Cache-Control: public, max-age=86400
# Access-Control-Allow-Origin: *
# Server: mafe
# X-XSS-Protection: 1; mode=block
# X-Frame-Options: SAMEORIGIN
# Alternate-Protocol: 443:quic,p=0.5
# Accept-Ranges: none
# Vary: Accept-Language,Accept-Encoding
#
# Address: 700 Pennsylvania Avenue Northwest, Washington, DC 20408, USA
# {u'lat': 38.892319, u'lng': -77.022893}

# %%
landsat8(x[0], x[1], '0.025', 'True', '2014-07-31')
# Out:
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=0.5
# cache-control: no-cache
# Content-Type: application/json
# Date: Sun, 12 Apr 2015 20:04:49 GMT
# Server: nginx
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 969
# x-varnish: 450834
# Content-Length: 304
# Connection: Close
#
# date: 2014-07-29T15:46:23
# cloud score: 0.106131879123
# Planet: earth
# Data Set: LC8_L1T_TOA
# ID: LC8_L1T_TOA/LC80150332014210LGN00
# URL: https://earthengine.googleapis.com/api/thumb?thumbid=23b8a7684ad4c7d10bc8eebb4b0b2311&token=0f1e699bc235b6a99e99db17ee49c577
# {u'cloud_score': 0.10613187912310454,
#  u'date': u'2014-07-29T15:46:23',
#  u'id': u'LC8_L1T_TOA/LC80150332014210LGN00',
#  u'resource': {u'dataset': u'LC8_L1T_TOA', u'planet': u'earth'},
#  u'url': u'https://earthengine.googleapis.com/api/thumb?thumbid=23b8a7684ad4c7d10bc8eebb4b0b2311&token=0f1e699bc235b6a99e99db17ee49c577'}

# %% [markdown]
# # Assets

# %% [raw]
# HTTP REQUEST
#
# GET https://api.data.gov/nasa/planetary/earth/assets
#
# QUERY PARAMETERS
#
# Parameter	Type	    Default	    Description
# lat	        float	    n/a	        Latitude
# lon	        float	    n/a	        Longitude
# begin	    YYYY-MM-DD	n/a	        beginning of date range
# end	        YYYY-MM-DD	today	    end of date range
# api_key	    string	    DEMO_KEY	api.data.gov key for expanded usage
#
# EXAMPLE QUERY
#
# https://api.data.gov/nasa/planetary/earth/assets?lon=100.75&lat=1.5&begin=2014-02-01&api_key=DEMO_KEY

# %%
def Assets(lat, lon, begin, end):
    """
    Hey, Charlie, when was the last time a NASA image was taken of my house? This endpoint retrieves the date-times and asset names for available imagery for a supplied location. The satellite passes over each point on earth roughly once every sixteen days. This is an amazing visualization of the acquisition pattern for Landsat 8 imagery. The objective of this endpoint is primarily to support the use of the imagery endpoint.
    GET https://api.data.gov/nasa/planetary/earth/assets

    QUERY PARAMETERS

    Parameter	Type	    Default	    Description
    lat	        float	    n/a	        Latitude
    lon	        float	    n/a	        Longitude
    begin	    YYYY-MM-DD	n/a	        beginning of date range
    end	        YYYY-MM-DD	today	    end of date range
    api_key	    string	    DEMO_KEY	api.data.gov key for expanded usage

    EXAMPLE QUERY

    https://api.data.gov/nasa/planetary/earth/assets?lon=100.75&lat=1.5&begin=2014-02-01&api_key=DEMO_KEY
    """
    request='https://api.data.gov/nasa/planetary/earth/assets'
    key='avVkP0IKbxes8S3MVnAehU97VAS9vRMmbjbkYjm4'
    form={'lat': str(lat), 'lon': str(lon), 'begin': begin, 'end': end, 'api_key': key}
    query=urllib.urlencode(form)
    landsat8_request_string=urllib.urlopen(request+"?"+query)
    print(landsat8_request_string.info())
    response=json.loads(landsat8_request_string.read())
    #print(response.keys())
    #print(response.values())
    print('From: '+ begin)
    print('To: ' + end)
    print('Number of Satellite passes: ' + str(response['count']))
    print('Planet: ' + response['resource']['planet'])
    print('Data Set: ' + response['resource']['dataset'])
    for item in response['results']:
        print('date: ' + item['date'])
        print('id: ' + item['id'])
    return response

# %%
Assets(x[0],x[1],'2014-07-31', '2015-01-01')
# Out:
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=0.5
# cache-control: no-cache
# Content-Type: application/json
# Date: Sun, 12 Apr 2015 20:05:17 GMT
# Server: nginx
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 971
# x-varnish: 450857
# Content-Length: 616
# Connection: Close
#
# From: 2014-07-31
# To: 2015-01-01
# Number of Satellite passes: 7
# Planet: earth
# Data Set: LC8_L1T_TOA
# date: 2014-08-14T15:46:30
# id: LC8_L1T_TOA/LC80150332014226LGN00
# date: 2014-09-15T15:46:35
# id: LC8_L1T_TOA/LC80150332014258LGN00
# date: 2014-10-01T15:46:36
# id: LC8_L1T_TOA/LC80150332014274LGN00
# date: 2014-10-17T15:46:41
# id: LC8_L1T_TOA/LC80150332014290LGN00
# date: 2014-11-02T15:46:38
# id: LC8_L1T_TOA/LC80150332014306LGN00
# date: 2014-11-18T15:46:37
# id: LC8_L1T_TOA/LC80150332014322LGN00
# date: 2014-12-04T15:46:37
# id: LC8_L1T_TOA/LC80150332014338LGN00
# {u'count': 7,
#  u'resource': {u'dataset': u'LC8_L1T_TOA', u'planet': u'earth'},
#  u'results': [{u'date': u'2014-08-14T15:46:30',
#    u'id': u'LC8_L1T_TOA/LC80150332014226LGN00'},
#   {u'date': u'2014-09-15T15:46:35',
#    u'id': u'LC8_L1T_TOA/LC80150332014258LGN00'},
#   {u'date': u'2014-10-01T15:46:36',
#    u'id': u'LC8_L1T_TOA/LC80150332014274LGN00'},
#   {u'date': u'2014-10-17T15:46:41',
#    u'id': u'LC8_L1T_TOA/LC80150332014290LGN00'},
#   {u'date': u'2014-11-02T15:46:38',
#    u'id': u'LC8_L1T_TOA/LC80150332014306LGN00'},
#   {u'date': u'2014-11-18T15:46:37',
#    u'id': u'LC8_L1T_TOA/LC80150332014322LGN00'},
#   {u'date': u'2014-12-04T15:46:37',
#    u'id': u'LC8_L1T_TOA/LC80150332014338LGN00'}]}

# %% [markdown]
# # Earth temperature anomalies

# %% [raw]
# Address
# The location can be specified as an address string.
#
# HTTP REQUEST
#
# GET https://api.data.gov/nasa/planetary/earth/temperature/address
#
# QUERY PARAMETERS
#
# Parameter	Type	Default	    Description
# text        string	n/a	        Address string
# begin	    int	    1880	    beginning year for date range, inclusive
# end	        int	    2014	    end year for date range, inclusive
# api_key	    string	DEMO_KEY	api.data.gov key for expanded usage
#
# EXAMPLE QUERY
#
# https://api.data.gov/nasa/planetary/earth/temperature/address?text=1800 F Street, NW, Washington DC&begin=1990

# %%
 def temperature_anomolies_address(begin, end, text):
    """
    There is no doubt that, on average, the earth is warming. However, the warming is spatially heterogenous. How much warmer (or cooler) is your hometown? This endpoint reports local temperature anomalies from the Goddard Institute for Space Studies Surface Temperature Analysis via the New Scientist web application to explore global temperature anomalies. This endpoint restructures the query and response to correspond to other APIs on api.nasa.gov. The developer supplies a location and date range, and the returned object is a list of dictionaries that is ready for visualization in the d3 framework.
    Address
    The location can be specified as an address string.

    HTTP REQUEST

    GET https://api.data.gov/nasa/planetary/earth/temperature/address

    QUERY PARAMETERS

    Parameter	Type	Default	    Description
    text        string	n/a	        Address string
    begin	    int	    1880	    beginning year for date range, inclusive
    end	        int	    2014	    end year for date range, inclusive
    api_key	    string	DEMO_KEY	api.data.gov key for expanded usage

    EXAMPLE QUERY

    https://api.data.gov/nasa/planetary/earth/temperature/address?text=1800 F Street, NW, Washington DC&begin=1990
    
    temperature_anomolies_address('1880', '2015', '20110')
    """
    request='https://api.data.gov/nasa/planetary/earth/temperature/address'
    key='avVkP0IKbxes8S3MVnAehU97VAS9vRMmbjbkYjm4'
    form={'begin':  str(begin), 'end': str(end), 'text': text, 'api_key': key}
    query=urllib.urlencode(form)
    temp_address_request_string=urllib.urlopen(request+"?"+query)
    print(temp_address_request_string.info())
    response=json.loads(temp_address_request_string.read())
    #print(response.keys())
    #print(response.values())
    return response

# %%
temperature_anomolies_address('1880', '2015', '20110')
# Out:
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=0.5
# cache-control: no-cache
# Content-Type: application/json
# Date: Sun, 12 Apr 2015 20:47:50 GMT
# Server: nginx
# vary: Accept-Encoding
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 964
# x-varnish: 1147234
# Content-Length: 6282
# Connection: Close
# {u'count': 135,
#  u'results': [{u'anomaly': 0.118000001, u'year': 1880},
#   {u'anomaly': 0.224299997, u'year': 1881},
#   {u'anomaly': -0.202199996, u'year': 1882},
#   {u'anomaly': -1.28550005, u'year': 1883},
#   {u'anomaly': -0.547999978, u'year': 1884},
#   {u'anomaly': -1.755200028, u'year': 1885},
#   {u'anomaly': -0.993799984, u'year': 1886},
#   {u'anomaly': -0.687099993, u'year': 1887},
#   {u'anomaly': -1.314599991, u'year': 1888},
#   {u'anomaly': -0.0339, u'year': 1889},
#   {u'anomaly': -0.0581, u'year': 1890},
#   {u'anomaly': 0.088100001, u'year': 1891},
#   {u'anomaly': -0.559099972, u'year': 1892},
#   {u'anomaly': -0.828299999, u'year': 1893},
#   {u'anomaly': 0.468600005, u'year': 1894},
#   {u'anomaly': -0.586199999, u'year': 1895},
#   {u'anomaly': 0.121100001, u'year': 1896},
#   {u'anomaly': 0.071800001, u'year': 1897},
#   {u'anomaly': 0.530499995, u'year': 1898},
#   {u'anomaly': 0.0166, u'year': 1899},
#   {u'anomaly': 0.603100002, u'year': 1900},
#   {u'anomaly': -0.49180001, u'year': 1901},
#   {u'anomaly': -0.096199997, u'year': 1902},
#   {u'anomaly': -0.280600011, u'year': 1903},
#   {u'anomaly': -1.401600003, u'year': 1904},
#   {u'anomaly': -0.506900012, u'year': 1905},
#   {u'anomaly': 0.237100005, u'year': 1906},
#   {u'anomaly': -0.726000011, u'year': 1907},
#   {u'anomaly': 0.300300002, u'year': 1908},
#   {u'anomaly': -0.059500001, u'year': 1909},
#   {u'anomaly': -0.213100001, u'year': 1910},
#   {u'anomaly': 0.616100013, u'year': 1911},
#   {u'anomaly': -0.601000011, u'year': 1912},
#   {u'anomaly': 0.821399987, u'year': 1913},
#   {u'anomaly': -0.386299998, u'year': 1914},
#   {u'anomaly': 0.021199999, u'year': 1915},
#   {u'anomaly': -0.194600001, u'year': 1916},
#   {u'anomaly': -1.539000034, u'year': 1917},
#   {u'anomaly': -0.132200003, u'year': 1918},
#   {u'anomaly': 0.480800003, u'year': 1919},
#   {u'anomaly': -0.528500021, u'year': 1920},
#   {u'anomaly': 1.442299962, u'year': 1921},
#   {u'anomaly': 0.543099999, u'year': 1922},
#   {u'anomaly': -0.103100002, u'year': 1923},
#   {u'anomaly': -0.906599998, u'year': 1924},
#   {u'anomaly': 0.138099998, u'year': 1925},
#   {u'anomaly': -0.819400012, u'year': 1926},
#   {u'anomaly': 0.331800014, u'year': 1927},
#   {u'anomaly': -0.125200003, u'year': 1928},
#   {u'anomaly': -0.115099996, u'year': 1929},
#   {u'anomaly': 0.416799992, u'year': 1930},
#   {u'anomaly': 1.245399952, u'year': 1931},
#   {u'anomaly': 0.683200002, u'year': 1932},
#   {u'anomaly': 0.742600024, u'year': 1933},
#   {u'anomaly': -0.0266, u'year': 1934},
#   {u'anomaly': -0.197600007, u'year': 1935},
#   {u'anomaly': -0.023499999, u'year': 1936},
#   {u'anomaly': 0.178599998, u'year': 1937},
#   {u'anomaly': 0.819000006, u'year': 1938},
#   {u'anomaly': 0.505299985, u'year': 1939},
#   {u'anomaly': -0.915499985, u'year': 1940},
#   {u'anomaly': 0.5546, u'year': 1941},
#   {u'anomaly': 0.278699994, u'year': 1942},
#   {u'anomaly': -0.210999995, u'year': 1943},
#   {u'anomaly': 0.272399992, u'year': 1944},
#   {u'anomaly': 0.163499996, u'year': 1945},
#   {u'anomaly': 0.829900026, u'year': 1946},
#   {u'anomaly': -0.0117, u'year': 1947},
#   {u'anomaly': 0.203199998, u'year': 1948},
#   {u'anomaly': 1.284199953, u'year': 1949},
#   {u'anomaly': -0.127399996, u'year': 1950},
#   {u'anomaly': 0.231700003, u'year': 1951},
#   {u'anomaly': 0.729900002, u'year': 1952},
#   {u'anomaly': 1.250800014, u'year': 1953},
#   {u'anomaly': 0.516600013, u'year': 1954},
#   {u'anomaly': 0.458099991, u'year': 1955},
#   {u'anomaly': 0.071000002, u'year': 1956},
#   {u'anomaly': 0.498800009, u'year': 1957},
#   {u'anomaly': -0.765600026, u'year': 1958},
#   {u'anomaly': 0.550899982, u'year': 1959},
#   {u'anomaly': -0.320600003, u'year': 1960},
#   {u'anomaly': 0.015, u'year': 1961},
#   {u'anomaly': -0.452699989, u'year': 1962},
#   {u'anomaly': -0.675400019, u'year': 1963},
#   {u'anomaly': 0.158600003, u'year': 1964},
#   {u'anomaly': -0.146599993, u'year': 1965},
#   {u'anomaly': -0.387400001, u'year': 1966},
#   {u'anomaly': -0.506900012, u'year': 1967},
#   {u'anomaly': -0.296299994, u'year': 1968},
#   {u'anomaly': -0.320499986, u'year': 1969},
#   {u'anomaly': -0.032400001, u'year': 1970},
#   {u'anomaly': 0.139699996, u'year': 1971},
#   {u'anomaly': -0.451200008, u'year': 1972},
#   {u'anomaly': 0.850600004, u'year': 1973},
#   {u'anomaly': 0.116300002, u'year': 1974},
#   {u'anomaly': 0.540600002, u'year': 1975},
#   {u'anomaly': -0.57099998, u'year': 1976},
#   {u'anomaly': 0.063600004, u'year': 1977},
#   {u'anomaly': -0.738200009, u'year': 1978},
#   {u'anomaly': -0.250699997, u'year': 1979},
#   {u'anomaly': -0.276899993, u'year': 1980},
#   {u'anomaly': -0.173800007, u'year': 1981},
#   {u'anomaly': -0.0206, u'year': 1982},
#   {u'anomaly': 0.268099993, u'year': 1983},
#   {u'anomaly': 0.247600004, u'year': 1984},
#   {u'anomaly': 0.231399998, u'year': 1985},
#   {u'anomaly': 0.501399994, u'year': 1986},
#   {u'anomaly': 0.609300017, u'year': 1987},
#   {u'anomaly': -0.0024, u'year': 1988},
#   {u'anomaly': -0.278800011, u'year': 1989},
#   {u'anomaly': 1.434200048, u'year': 1990},
#   {u'anomaly': 1.337499976, u'year': 1991},
#   {u'anomaly': -0.193000004, u'year': 1992},
#   {u'anomaly': 0.091600001, u'year': 1993},
#   {u'anomaly': 0.200299993, u'year': 1994},
#   {u'anomaly': 0.2579, u'year': 1995},
#   {u'anomaly': -0.253800005, u'year': 1996},
#   {u'anomaly': -0.077399999, u'year': 1997},
#   {u'anomaly': 1.819200039, u'year': 1998},
#   {u'anomaly': 1.122699976, u'year': 1999},
#   {u'anomaly': 0.208900005, u'year': 2000},
#   {u'anomaly': 0.987200022, u'year': 2001},
#   {u'anomaly': 1.139000058, u'year': 2002},
#   {u'anomaly': 0.016000001, u'year': 2003},
#   {u'anomaly': 0.529299974, u'year': 2004},
#   {u'anomaly': 0.773599982, u'year': 2005},
#   {u'anomaly': 1.331099987, u'year': 2006},
#   {u'anomaly': 0.958999991, u'year': 2007},
#   {u'anomaly': 0.470400006, u'year': 2008},
#   {u'anomaly': 0.209800005, u'year': 2009},
#   {u'anomaly': 0.966000021, u'year': 2010},
#   {u'anomaly': 1.236700058, u'year': 2011},
#   {u'anomaly': 1.936300039, u'year': 2012},
#   {u'anomaly': 0.373100013, u'year': 2013},
#   {u'anomaly': -0.219600007, u'year': 2014}]}

# %%
def plot_temps(begin, end, text):
    """
    Plot temperature variations to a line chart
    """
    response=temp_data=temperature_anomolies_address(begin, end, text)
    z=response['results']
    x=[]
    y=[]
    for item in z:
        y.append(item['anomaly'])
        x.append(item['year'])
    plt.ylabel('Temp Variation')
    plt.xlabel('Years')
    plt.plot(x,y)

# %%
def plot_temps_points(begin, end, lat, lon):
    """
    Plot temperature variations to a line chart
    """
    response=temp_data=temperature_anomolies_coordinates(begin, end, lat, lon)
    z=response['results']
    x=[]
    y=[]
    for item in z:
        y.append(item['anomaly'])
        x.append(item['year'])
    plt.ylabel('Temp Variation')
    plt.xlabel('Years')
    plt.plot(x,y)

# %%
plot_temps('1880', '2015', '90210')
# Out:
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=0.5
# cache-control: no-cache
# Content-Type: application/json
# Date: Sun, 12 Apr 2015 20:52:32 GMT
# Server: nginx
# vary: Accept-Encoding
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 963
# x-varnish: 421736
# Content-Length: 6314
# Connection: Close

# %%
 def temperature_anomolies_coordinates(begin, end, lat, lon):
    """
    Coordinates
    Alternatively, you can supply the precise latitude and longitude as the location.

    HTTP REQUEST

    GET https://api.data.gov/planetary/earth/temperature/coords

    QUERY PARAMETERS

    Parameter	Type	Default	    Description
    lat	        float	n/a	        Latitude
    lon	        float	n/a	        Longitude
    begin	    int	    1880	    beginning year for date range, inclusive
    end	        int	    2014	    end year for date range, inclusive
    api_key	    string	DEMO_KEY	api.data.gov key for expanded usage
    
    EXAMPLE QUERY

    https://api.data.gov/nasa/planetary/earth/temperature/coords?lon=100.3&lat=1.6&begin=1990&end=2005&api_key=DEMO_KEY
    """
    request='https://api.data.gov/nasa/planetary/earth/temperature/coords'
    key='avVkP0IKbxes8S3MVnAehU97VAS9vRMmbjbkYjm4'
    form={'begin':  str(begin), 'end': str(end), 'lat': lat, 'lon': lon, 'api_key': key}
    query=urllib.urlencode(form)
    temp_point_request_string=urllib.urlopen(request+"?"+query)
    print(temp_point_request_string.info())
    response=json.loads(temp_point_request_string.read())
    #print(response.keys())
    #print(response.values())
    return response

# %%
x=geocode('700 Pennsylvania Dr Northwest Wshington DC')
# Out:
# Content-Type: application/json; charset=UTF-8
# Date: Sun, 12 Apr 2015 21:00:22 GMT
# Expires: Mon, 13 Apr 2015 21:00:22 GMT
# Cache-Control: public, max-age=86400
# Access-Control-Allow-Origin: *
# Server: mafe
# X-XSS-Protection: 1; mode=block
# X-Frame-Options: SAMEORIGIN
# Alternate-Protocol: 443:quic,p=0.5
# Accept-Ranges: none
# Vary: Accept-Language,Accept-Encoding
#
# Address: 700 Pennsylvania Avenue Northwest, Washington, DC 20408, USA
# {u'lat': 38.892319, u'lng': -77.022893}

# %%
temperature_anomolies_coordinates('1880','2015',x[0],x[1])
# Out:
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=0.5
# cache-control: no-cache
# Content-Type: application/json
# Date: Sun, 12 Apr 2015 21:01:19 GMT
# Server: nginx
# vary: Accept-Encoding
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 962
# x-varnish: 1068654
# Content-Length: 6282
# Connection: Close
# {u'count': 135,
#  u'results': [{u'anomaly': 0.118000001, u'year': 1880},
#   {u'anomaly': 0.224299997, u'year': 1881},
#   {u'anomaly': -0.202199996, u'year': 1882},
#   {u'anomaly': -1.28550005, u'year': 1883},
#   {u'anomaly': -0.547999978, u'year': 1884},
#   {u'anomaly': -1.755200028, u'year': 1885},
#   {u'anomaly': -0.993799984, u'year': 1886},
#   {u'anomaly': -0.687099993, u'year': 1887},
#   {u'anomaly': -1.314599991, u'year': 1888},
#   {u'anomaly': -0.0339, u'year': 1889},
#   {u'anomaly': -0.0581, u'year': 1890},
#   {u'anomaly': 0.088100001, u'year': 1891},
#   {u'anomaly': -0.559099972, u'year': 1892},
#   {u'anomaly': -0.828299999, u'year': 1893},
#   {u'anomaly': 0.468600005, u'year': 1894},
#   {u'anomaly': -0.586199999, u'year': 1895},
#   {u'anomaly': 0.121100001, u'year': 1896},
#   {u'anomaly': 0.071800001, u'year': 1897},
#   {u'anomaly': 0.530499995, u'year': 1898},
#   {u'anomaly': 0.0166, u'year': 1899},
#   {u'anomaly': 0.603100002, u'year': 1900},
#   {u'anomaly': -0.49180001, u'year': 1901},
#   {u'anomaly': -0.096199997, u'year': 1902},
#   {u'anomaly': -0.280600011, u'year': 1903},
#   {u'anomaly': -1.401600003, u'year': 1904},
#   {u'anomaly': -0.506900012, u'year': 1905},
#   {u'anomaly': 0.237100005, u'year': 1906},
#   {u'anomaly': -0.726000011, u'year': 1907},
#   {u'anomaly': 0.300300002, u'year': 1908},
#   {u'anomaly': -0.059500001, u'year': 1909},
#   {u'anomaly': -0.213100001, u'year': 1910},
#   {u'anomaly': 0.616100013, u'year': 1911},
#   {u'anomaly': -0.601000011, u'year': 1912},
#   {u'anomaly': 0.821399987, u'year': 1913},
#   {u'anomaly': -0.386299998, u'year': 1914},
#   {u'anomaly': 0.021199999, u'year': 1915},
#   {u'anomaly': -0.194600001, u'year': 1916},
#   {u'anomaly': -1.539000034, u'year': 1917},
#   {u'anomaly': -0.132200003, u'year': 1918},
#   {u'anomaly': 0.480800003, u'year': 1919},
#   {u'anomaly': -0.528500021, u'year': 1920},
#   {u'anomaly': 1.442299962, u'year': 1921},
#   {u'anomaly': 0.543099999, u'year': 1922},
#   {u'anomaly': -0.103100002, u'year': 1923},
#   {u'anomaly': -0.906599998, u'year': 1924},
#   {u'anomaly': 0.138099998, u'year': 1925},
#   {u'anomaly': -0.819400012, u'year': 1926},
#   {u'anomaly': 0.331800014, u'year': 1927},
#   {u'anomaly': -0.125200003, u'year': 1928},
#   {u'anomaly': -0.115099996, u'year': 1929},
#   {u'anomaly': 0.416799992, u'year': 1930},
#   {u'anomaly': 1.245399952, u'year': 1931},
#   {u'anomaly': 0.683200002, u'year': 1932},
#   {u'anomaly': 0.742600024, u'year': 1933},
#   {u'anomaly': -0.0266, u'year': 1934},
#   {u'anomaly': -0.197600007, u'year': 1935},
#   {u'anomaly': -0.023499999, u'year': 1936},
#   {u'anomaly': 0.178599998, u'year': 1937},
#   {u'anomaly': 0.819000006, u'year': 1938},
#   {u'anomaly': 0.505299985, u'year': 1939},
#   {u'anomaly': -0.915499985, u'year': 1940},
#   {u'anomaly': 0.5546, u'year': 1941},
#   {u'anomaly': 0.278699994, u'year': 1942},
#   {u'anomaly': -0.210999995, u'year': 1943},
#   {u'anomaly': 0.272399992, u'year': 1944},
#   {u'anomaly': 0.163499996, u'year': 1945},
#   {u'anomaly': 0.829900026, u'year': 1946},
#   {u'anomaly': -0.0117, u'year': 1947},
#   {u'anomaly': 0.203199998, u'year': 1948},
#   {u'anomaly': 1.284199953, u'year': 1949},
#   {u'anomaly': -0.127399996, u'year': 1950},
#   {u'anomaly': 0.231700003, u'year': 1951},
#   {u'anomaly': 0.729900002, u'year': 1952},
#   {u'anomaly': 1.250800014, u'year': 1953},
#   {u'anomaly': 0.516600013, u'year': 1954},
#   {u'anomaly': 0.458099991, u'year': 1955},
#   {u'anomaly': 0.071000002, u'year': 1956},
#   {u'anomaly': 0.498800009, u'year': 1957},
#   {u'anomaly': -0.765600026, u'year': 1958},
#   {u'anomaly': 0.550899982, u'year': 1959},
#   {u'anomaly': -0.320600003, u'year': 1960},
#   {u'anomaly': 0.015, u'year': 1961},
#   {u'anomaly': -0.452699989, u'year': 1962},
#   {u'anomaly': -0.675400019, u'year': 1963},
#   {u'anomaly': 0.158600003, u'year': 1964},
#   {u'anomaly': -0.146599993, u'year': 1965},
#   {u'anomaly': -0.387400001, u'year': 1966},
#   {u'anomaly': -0.506900012, u'year': 1967},
#   {u'anomaly': -0.296299994, u'year': 1968},
#   {u'anomaly': -0.320499986, u'year': 1969},
#   {u'anomaly': -0.032400001, u'year': 1970},
#   {u'anomaly': 0.139699996, u'year': 1971},
#   {u'anomaly': -0.451200008, u'year': 1972},
#   {u'anomaly': 0.850600004, u'year': 1973},
#   {u'anomaly': 0.116300002, u'year': 1974},
#   {u'anomaly': 0.540600002, u'year': 1975},
#   {u'anomaly': -0.57099998, u'year': 1976},
#   {u'anomaly': 0.063600004, u'year': 1977},
#   {u'anomaly': -0.738200009, u'year': 1978},
#   {u'anomaly': -0.250699997, u'year': 1979},
#   {u'anomaly': -0.276899993, u'year': 1980},
#   {u'anomaly': -0.173800007, u'year': 1981},
#   {u'anomaly': -0.0206, u'year': 1982},
#   {u'anomaly': 0.268099993, u'year': 1983},
#   {u'anomaly': 0.247600004, u'year': 1984},
#   {u'anomaly': 0.231399998, u'year': 1985},
#   {u'anomaly': 0.501399994, u'year': 1986},
#   {u'anomaly': 0.609300017, u'year': 1987},
#   {u'anomaly': -0.0024, u'year': 1988},
#   {u'anomaly': -0.278800011, u'year': 1989},
#   {u'anomaly': 1.434200048, u'year': 1990},
#   {u'anomaly': 1.337499976, u'year': 1991},
#   {u'anomaly': -0.193000004, u'year': 1992},
#   {u'anomaly': 0.091600001, u'year': 1993},
#   {u'anomaly': 0.200299993, u'year': 1994},
#   {u'anomaly': 0.2579, u'year': 1995},
#   {u'anomaly': -0.253800005, u'year': 1996},
#   {u'anomaly': -0.077399999, u'year': 1997},
#   {u'anomaly': 1.819200039, u'year': 1998},
#   {u'anomaly': 1.122699976, u'year': 1999},
#   {u'anomaly': 0.208900005, u'year': 2000},
#   {u'anomaly': 0.987200022, u'year': 2001},
#   {u'anomaly': 1.139000058, u'year': 2002},
#   {u'anomaly': 0.016000001, u'year': 2003},
#   {u'anomaly': 0.529299974, u'year': 2004},
#   {u'anomaly': 0.773599982, u'year': 2005},
#   {u'anomaly': 1.331099987, u'year': 2006},
#   {u'anomaly': 0.958999991, u'year': 2007},
#   {u'anomaly': 0.470400006, u'year': 2008},
#   {u'anomaly': 0.209800005, u'year': 2009},
#   {u'anomaly': 0.966000021, u'year': 2010},
#   {u'anomaly': 1.236700058, u'year': 2011},
#   {u'anomaly': 1.936300039, u'year': 2012},
#   {u'anomaly': 0.373100013, u'year': 2013},
#   {u'anomaly': -0.219600007, u'year': 2014}]}

# %%
plot_temps_points('1880','2015',x[0],x[1])
# Out:
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=0.5
# cache-control: no-cache
# Content-Type: application/json
# Date: Sun, 12 Apr 2015 21:05:10 GMT
# Server: nginx
# vary: Accept-Encoding
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 965
# x-varnish: 926313
# Content-Length: 6282
# Connection: Close

# %% [markdown]
# # Patents

# %% [raw]
# The NASA patent portfolio is available to benefit US citizens. Through partnerships and licensing agreements with industry, these patents ensure that NASA’s investments in pioneering research find secondary uses that benefit the economy, create jobs, and improve quality of life. This endpoint provides structured, searchable developer access to NASA’s patents that have been curated to support technology transfer.
#
# HTTP REQUEST
#
# GET https://api.data.gov/nasa/patents
#
# QUERY PARAMETERS
#
# Parameter	    Type	 Default	Description
# query	        string	 None	    Search text to filter results
# concept_tags	bool	 False	    Return an ordered dictionary of concepts from the patent abstract
# limit	        int	     all	    number of patents to return
# api_key	string	DEMO_KEY	        api.data.gov key for expanded usage
#
# EXAMPLE QUERY
#
# https://api.data.gov/nasa/patents/content?query=temperature&limit=5&api_key=DEMO_KEY

# %%
def patents(text, concept_tags):
    """
    The NASA patent portfolio is available to benefit US citizens. Through partnerships and licensing agreements with industry, these patents ensure that NASA’s investments in pioneering research find secondary uses that benefit the economy, create jobs, and improve quality of life. This endpoint provides structured, searchable developer access to NASA’s patents that have been curated to support technology transfer.

    HTTP REQUEST

    GET https://api.data.gov/nasa/patents

    QUERY PARAMETERS

    Parameter	    Type	 Default	Description
    query	        string	 None	    Search text to filter results
    concept_tags	bool	 False	    Return an ordered dictionary of concepts from the patent abstract
    limit	        int	     all	    number of patents to return
    api_key	string	DEMO_KEY	        api.data.gov key for expanded usage

    EXAMPLE QUERY

    https://api.data.gov/nasa/patents/content?query=temperature&limit=5&api_key=DEMO_KEY
    """
    request='https://api.data.gov/nasa/patents/content'
    key='avVkP0IKbxes8S3MVnAehU97VAS9vRMmbjbkYjm4'
    form={'query': text,'concepte_tags': concept_tags, 'api_key': key}
    query=urllib.urlencode(form)
    patent_request_string=urllib.urlopen(request+"?"+query)
    print(patent_request_string.info())
    response=json.loads(patent_request_string.read())
    #print(response.keys())
    #print(response.values())
    return response

# %%
patents('brain', 'True')
# Out:
# https://api.data.gov/nasa/patents/content?query=brain&concepte_tags=True&api_key=avVkP0IKbxes8S3MVnAehU97VAS9vRMmbjbkYjm4
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=0.5
# cache-control: no-cache
# Content-Type: application/json
# Date: Sun, 12 Apr 2015 21:19:16 GMT
# Server: nginx
# vary: Accept-Encoding
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 979
# x-varnish: 1091191
# Content-Length: 9256
# Connection: Close
# {u'count': 4,
#  u'results': [{u'_id': u'53f657e55904da2c9fc2fee2',
#    u'abstract': u'A system with multimodality instrument for tissue identification includes a     computer-controlled motor driven heuristic probe with a multisensory tip.     For neurosurgical applications, the instrument is mounted on a     stereotactic frame for the probe to penetrate the brain in a precisely     controlled fashion. The resistance of the brain tissue being penetrated is     continually monitored by a miniaturized strain gauge attached to the probe     tip. Other modality sensors may be mounted near the probe tip to provide     real-time tissue characterizations and the ability to detect the proximity     of blood vessels, thus eliminating errors normally associated with     registration of pre-operative scans, tissue swelling, elastic tissue     deformation, human judgement, etc., and rendering surgical procedures     safer, more accurate, and efficient. A neural network program adaptively     learns the information on resistance and other characteristic features of     normal brain tissue during the surgery and provides near real-time     modeling. A fuzzy logic interface to the neural network program     incorporates expert medical knowledge in the learning process.     Identification of abnormal brain tissue is determined by the detection of     change and comparison with previously learned models of abnormal brain     tissues. The operation of the instrument is controlled through a user     friendly graphical interface. Patient data is presented in a 3D     stereographics display. Acoustic feedback of selected information may     optionally be provided. Upon detection of the close proximity to blood     vessels or abnormal brain tissue, the computer-controlled motor     immediately stops probe penetration.',
#    u'category': u'health medicine and biotechnology',
#    u'center': u'ARC',
#    u'client_record_id': u'patent_ARC-14231-1',
#    u'concepts': None,
#    u'contact': {u'address': u'Mail Stop 202A-3, Moffett Field, CA 94035',
#     u'email': u'Trupti.D.Sanghani@nasa.gov',
#     u'facility': u'NASA Ames Research Center',
#     u'name': u'Trupti D. Sanghani',
#     u'office': u'Technology Partnerships Division'},
#    u'eRelations': [],
#    u'expiration_date': u'',
#    u'id': u'patent_ARC-14231-1',
#    u'innovator': [{u'company': u'NASA Ames Research Center',
#      u'fname': u'Robert',
#      u'lname': u'Mah',
#      u'mname': u'W.',
#      u'order': u'1'},
#     {u'fname': u'Stefanie', u'lname': u'Jeffrey', u'order': u'3'},
#     {u'company': u'Veteran&#8217;s Affairs Medical Center',
#      u'fname': u'Russell',
#      u'lname': u'Andrews',
#      u'mname': u'J.',
#      u'order': u'2'}],
#    u'patent_number': u'6109270',
#    u'publication': None,
#    u'reference_number': u'ARC-14231-1',
#    u'serial_number': u'09/017,519',
#    u'title': u'Multimodality instrument for tissue characterization',
#    u'trl': u'6 - Demonstration in a relevant environment'},
#   {u'_id': u'53f657e95904da2c9fc2fee4',
#    u'abstract': u'A system with multimodality instrument for tissue identification includes a     computer-controlled motor driven heuristic probe with a multisensory tip.     For neurosurgical applications, the instrument is mounted on a     stereotactic frame for the probe to penetrate the brain in a precisely     controlled fashion. The resistance of the brain tissue being penetrated is     continually monitored by a miniaturized strain gauge attached to the probe     tip. Other modality sensors may be mounted near the probe tip to provide     real-time tissue characterizations and the ability to detect the proximity     of blood vessels, thus eliminating errors normally associated with     registration of pre-operative scans, tissue swelling, elastic tissue     deformation, human judgement, etc., and rendering surgical procedures     safer, more accurate, and efficient. A neural network program adaptively     learns the information on resistance and other characteristic features of     normal brain tissue during the surgery and provides near real-time     modeling. A fuzzy logic interface to the neural network program     incorporates expert medical knowledge in the learning process.     Identification of abnormal brain tissue is determined by the detection of     change and comparison with previously learned models of abnormal brain     tissues. The operation of the instrument is controlled through a user     friendly graphical interface. Patient data is presented in a 3D     stereographics display. Acoustic feedback of selected information may     optionally be provided. Upon detection of the close proximity to blood     vessels or abnormal brain tissue, the computer-controlled motor     immediately stops probe penetration. The use of this system will make     surgical procedures safer, more accurate, and more efficient. Other     applications of this system include the detection, prognosis and treatment     of breast cancer, prostate cancer, spinal diseases, and use in general     exploratory surgery.',
#    u'category': u'health medicine and biotechnology',
#    u'center': u'ARC',
#    u'client_record_id': u'patent_ARC-14231-3',
#    u'concepts': None,
#    u'contact': {u'address': u'Mail Stop 202A-3, Moffett Field, CA 94035',
#     u'email': u'Trupti.D.Sanghani@nasa.gov',
#     u'facility': u'NASA Ames Research Center',
#     u'name': u'Trupti D. Sanghani',
#     u'office': u'Technology Partnerships Division'},
#    u'eRelations': [],
#    u'expiration_date': u'',
#    u'id': u'patent_ARC-14231-3',
#    u'innovator': [{u'company': u'NASA Ames Research Center',
#      u'fname': u'Robert',
#      u'lname': u'Mah',
#      u'mname': u'W.',
#      u'order': u'1'},
#     {u'company': u'Veteran&#8217;s Affairs Medical Center',
#      u'fname': u'Russell',
#      u'lname': u'Andrews',
#      u'mname': u'J.',
#      u'order': u'2'}],
#    u'patent_number': u'6718196',
#    u'publication': None,
#    u'reference_number': u'ARC-14231-3',
#    u'serial_number': u'09/652,299',
#    u'title': u'Multimodality instrument for tissue characterization',
#    u'trl': u'6 - Demonstration in a relevant environment'},
#   {u'_id': u'53f6589c5904da2c9fc2ff3d',
#    u'abstract': u'Changes in intracranial pressure can be measured dynamically and     non-invasively by monitoring one or more cerebrospinal fluid pulsatile     components. Pulsatile components such as systolic and diastolic blood     pressures are partially transferred to the cerebrospinal fluid by way of     blood vessels contained in the surrounding brain tissue and membrane. As     intracranial pressure varies these cerebrospinal fluid pulsatile     components also vary. Thus, intracranial pressure can be dynamically     measured. Furthermore, use of acoustics allows the measurement to be     completely non-invasive. In the preferred embodiment, phase comparison of     a reflected acoustic signal to a reference signal using a constant     frequency pulsed phase-locked-loop ultrasonic device allows the pulsatile     components to be monitored. Calibrating the device by inducing a known     change in intracranial pressure allows conversion to changes in     intracranial pressure.',
#    u'category': u'health medicine and biotechnology',
#    u'center': u'LARC',
#    u'client_record_id': u'patent_LAR-15507-1',
#    u'concepts': None,
#    u'contact': {u'address': u'MS 218, Hampton, VA 23681-2199',
#     u'email': u'Sandra.k.pretlow@nasa.gov',
#     u'facility': u'NASA Langley Research Center',
#     u'name': u'Sandra Pretlow',
#     u'office': u'Innovative Partnerships Office',
#     u'phone': u'(757) 864-2358'},
#    u'eRelations': [],
#    u'expiration_date': u'',
#    u'id': u'patent_LAR-15507-1',
#    u'innovator': [{u'company': u'NASA Langley Research Center',
#      u'fname': u'John',
#      u'lname': u'Cantrell',
#      u'mname': u'H.',
#      u'order': u'1'},
#     {u'company': u'NASA Langley Research Center',
#      u'fname': u'William',
#      u'lname': u'Yost',
#      u'mname': u'T',
#      u'order': u'2'}],
#    u'patent_number': u'6475147',
#    u'publication': None,
#    u'reference_number': u'LAR-15507-1',
#    u'serial_number': u'09/493,044',
#    u'title': u'Ultrasonic apparatus and technique to measure changes in intracranial     pressure',
#    u'trl': u'undefined'},
#   {u'_id': u'53f658255904da2c9fc2ff02',
#    u'abstract': u'fNIRS may be used in real time or near-real time to detect the mental state of individuals.  Phase measurement can be applied to drive an adaptive filter for the removal of motion artifacts in real time or near-real time.  In this manner, the application of fNIRS may be extended to practical non-laboratory environments.  For example, the mental state of an operator of a vehicle may be monitored, and alerts may be issued and/or an autopilot may be engaged when the mental state of the operator indicates that the operator is inattentive.',
#    u'category': u'health medicine and biotechnology',
#    u'center': u'GRC',
#    u'client_record_id': u'patent_LEW-18952-1',
#    u'concepts': None,
#    u'contact': {u'email': u'ttp@grc.nasa.gov',
#     u'facility': u'NASA Glenn Research Center',
#     u'office': u'Innovation Projects Office'},
#    u'eRelations': [],
#    u'expiration_date': u'',
#    u'id': u'patent_LEW-18952-1',
#    u'innovator': [{u'company': u'NASA John H. Glenn Research Center At Lewis Field',
#      u'fname': u'Angela',
#      u'lname': u'Harrivel',
#      u'mname': u'R.',
#      u'order': u'1'},
#     {u'company': u'NASA John H. Glenn Research Center At Lewis Field',
#      u'fname': u'Tristan',
#      u'lname': u'Hearn',
#      u'mname': u'A.',
#      u'order': u'2'}],
#    u'publication': [{u'title': u'Functional Near  Infrared Spectroscopy: Watching the brain in flight ',
#      u'type': u'Conference or Seminar'}],
#    u'reference_number': u'LEW-18952-1',
#    u'serial_number': u'14/278,426',
#    u'title': u'A Novel Real Time Adaptive Filter For The Reduction Of Artifacts In Functional Near Infrared Spectroscopy Signals',
#    u'trl': u'4 - Validation in laboratory environment'}]}

# %% [markdown]
# # Sounds (Beta)

# %% [raw]
# Sound exists in space. Sometimes. And NASA has released a series of space sounds via sound cloud. We have abstracted away some of the hassle in accessing these sounds, so that developers can play with the audio files. For example, a useful application would be an automatic filter to identify human voices in these audio files. For now, that would help identify content. Later, however, when we retrieve sounds from far-off planets, we can apply the filter to identify unknown human space colonies. That was a joke. Sort of.
#
# HTTP REQUEST
#
# GET https://api.data.gov/nasa/planetary/sounds
#
# QUERY PARAMETERS
#
# Parameter	Type	Default	    Description
# q	        string	None	    Search text to filter results
# limit	    int	    10	        number of tracks to return
# api_key	    string	DEMO_KEY	api.data.gov key for expanded usage
#
# EXAMPLE QUERY
#
# http://api.data.gov/nasa/planetary/sounds?q=apollo&api_key=DEMO_KEY

# %%
def sounds(text):
    """
    Sound exists in space. Sometimes. And NASA has released a series of space sounds via sound cloud. We have abstracted away some of the hassle in accessing these sounds, so that developers can play with the audio files. For example, a useful application would be an automatic filter to identify human voices in these audio files. For now, that would help identify content. Later, however, when we retrieve sounds from far-off planets, we can apply the filter to identify unknown human space colonies. That was a joke. Sort of.

    HTTP REQUEST

    GET https://api.data.gov/nasa/planetary/sounds

    QUERY PARAMETERS

    Parameter	Type	Default	    Description
    q	        string	None	    Search text to filter results
    limit	    int	    10	        number of tracks to return
    api_key	    string	DEMO_KEY	api.data.gov key for expanded usage

    EXAMPLE QUERY

    http://api.data.gov/nasa/planetary/sounds?q=apollo&api_key=DEMO_KEY
    """
    request='https://api.data.gov/nasa/planetary/sounds'
    key='avVkP0IKbxes8S3MVnAehU97VAS9vRMmbjbkYjm4'
    form={'q': text, 'api_key': key}
    query=urllib.urlencode(form)
    sound_request_string=urllib.urlopen(request+"?"+query)
    print(sound_request_string.info())
    response=json.loads(sound_request_string.read())
    #print(response.keys())
    #print(response.values())
    return response

# %%
sounds('alien')
# Out:
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=0.5
# cache-control: no-cache
# Content-Type: application/json
# Date: Sun, 12 Apr 2015 21:24:48 GMT
# Server: nginx
# vary: Accept-Encoding
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 983
# x-varnish: 650212
# Content-Length: 3535
# Connection: Close
# {u'count': 10,
#  u'results': [{u'description': u'The Voyager 1 spacecraft has experienced three "tsunami waves" in interstellar space. Listen to how these waves cause surrounding ionized matter to ring. More details on this sound can be found here: http://www.nasa.gov/jpl/nasa-voyager-tsunami-wave-still-flies-through-interstellar-space/',
#    u'download_url': u'https://api.soundcloud.com/tracks/181835738/download',
#    u'duration': 18365,
#    u'id': 181835738,
#    u'last_modified': u'2014/12/16 22:34:23 +0000',
#    u'license': u'cc-by-nc-sa',
#    u'stream_url': u'https://api.soundcloud.com/tracks/181835738/stream',
#    u'tag_list': u'Space',
#    u'title': u'Voyager 1: Three "Tsunami Waves" in Interstellar Space'},
#   {u'description': u'Courtesy of United Launch Alliance',
#    u'download_url': u'https://api.soundcloud.com/tracks/173578614/download',
#    u'duration': 30095,
#    u'id': 173578614,
#    u'last_modified': u'2014/10/24 02:16:33 +0000',
#    u'license': u'cc-by-nc',
#    u'stream_url': u'https://api.soundcloud.com/tracks/173578614/stream',
#    u'tag_list': u'space',
#    u'title': u'Delta IV: Launch'},
#   {u'description': None,
#    u'download_url': u'https://api.soundcloud.com/tracks/172463130/download',
#    u'duration': 5903,
#    u'id': 172463130,
#    u'last_modified': u'2014/10/16 19:29:13 +0000',
#    u'license': u'cc-by-nc',
#    u'stream_url': u'https://api.soundcloud.com/tracks/172463130/stream',
#    u'tag_list': u'space',
#    u'title': u'Wheel Stop'},
#   {u'description': None,
#    u'download_url': u'https://api.soundcloud.com/tracks/172463129/download',
#    u'duration': 3760,
#    u'id': 172463129,
#    u'last_modified': u'2014/10/16 19:29:12 +0000',
#    u'license': u'cc-by-nc',
#    u'stream_url': u'https://api.soundcloud.com/tracks/172463129/stream',
#    u'tag_list': u'space',
#    u'title': u'Vector Transfer'},
#   {u'description': None,
#    u'download_url': u'https://api.soundcloud.com/tracks/172463128/download',
#    u'duration': 1515,
#    u'id': 172463128,
#    u'last_modified': u'2014/10/16 19:29:12 +0000',
#    u'license': u'cc-by-nc',
#    u'stream_url': u'https://api.soundcloud.com/tracks/172463128/stream',
#    u'tag_list': u'space',
#    u'title': u'Roger Roll'},
#   {u'description': None,
#    u'download_url': u'https://api.soundcloud.com/tracks/172463126/download',
#    u'duration': 7497,
#    u'id': 172463126,
#    u'last_modified': u'2014/10/16 19:29:12 +0000',
#    u'license': u'cc-by-nc',
#    u'stream_url': u'https://api.soundcloud.com/tracks/172463126/stream',
#    u'tag_list': u'space',
#    u'title': u'On its way to Orbit'},
#   {u'description': None,
#    u'download_url': u'https://api.soundcloud.com/tracks/172463124/download',
#    u'duration': 2560,
#    u'id': 172463124,
#    u'last_modified': u'2014/10/16 19:29:12 +0000',
#    u'license': u'cc-by-nc',
#    u'stream_url': u'https://api.soundcloud.com/tracks/172463124/stream',
#    u'tag_list': u'space',
#    u'title': u'Press to ATO'},
#   {u'description': None,
#    u'download_url': u'https://api.soundcloud.com/tracks/172463122/download',
#    u'duration': 5641,
#    u'id': 172463122,
#    u'last_modified': u'2014/10/16 19:29:11 +0000',
#    u'license': u'cc-by-nc',
#    u'stream_url': u'https://api.soundcloud.com/tracks/172463122/stream',
#    u'tag_list': u'space',
#    u'title': u'Nice to be in Orbit'},
#   {u'description': None,
#    u'download_url': u'https://api.soundcloud.com/tracks/172463117/download',
#    u'duration': 3187,
#    u'id': 172463117,
#    u'last_modified': u'2014/10/16 19:29:11 +0000',
#    u'license': u'cc-by-nc',
#    u'stream_url': u'https://api.soundcloud.com/tracks/172463117/stream',
#    u'tag_list': u'space',
#    u'title': u'MECO'},
#   {u'description': None,
#    u'download_url': u'https://api.soundcloud.com/tracks/172463116/download',
#    u'duration': 2429,
#    u'id': 172463116,
#    u'last_modified': u'2014/10/16 19:29:10 +0000',
#    u'license': u'cc-by-nc',
#    u'stream_url': u'https://api.soundcloud.com/tracks/172463116/stream',
#    u'tag_list': u'space',
#    u'title': u'Lookin At It'}]}

# %%
# create a client object with your app credentials
def grab_audio(term):
    request_endpoint='https://api.soundcloud.com/tracks/'
    key='8258960f9077b43e8d0570cd0d2dce39'
    form={'client_id': key}
    query=urllib.urlencode(form)
    data=sounds(term)
    results=data['results']
    print('Fetching Remote Adio and storing in Current directory.')
    for items in results:
        print(items['title'])
        print(items['tag_list'])
        print(items['stream_url'])
        print(items['license'])
        print(items['last_modified'])
        print(items['id'])
        print(items['duration'])
        print(items['download_url'])
        print(items['description'])
        print('')
        #print(items['download_url']+"?"+query)
        sound_request_string=urllib.urlopen(items['download_url']+"?"+query)
        print('')
        with open(str(items['title'])+'.mp3', 'w') as mp3:
            mp3.write(sound_request_string.read())

# %%
grab_audio('alien')

# %%
APOD('2015-04-23', 'TRUE')
# Out:
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=1
# cache-control: no-cache
# Content-Type: application/json
# Date: Fri, 24 Apr 2015 05:37:35 GMT
# Server: nginx
# vary: Accept-Encoding
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 997
# x-varnish: 2437479
# Content-Length: 1043
# Connection: Close
#
# Title: Meteor in the Milky Way
# Date: 2015-04-23
# Explanation: rth's April showers include the Lyrid Meteor Shower, observed for more than 2,000 years when the planet makes its annual passage through the dust stream of long-period Comet Thatcher. A grain of that comet's dust, moving 48 kilometers per second at an altitude of 100 kilometers or so, is swept up in this night sky view from the early hours of April 21. Flashing toward the southeastern horizon, the meteor's brilliant streak crosses the central region of the rising Milky Way. Its trail points back toward the shower's radiant in the constellation Lyra, high in the northern springtime sky and off the top of the frame. The yellowish hue of giant star Antares shines to the right of the Milky Way's bulge. Higher still is bright planet Saturn, near the right edge. Seen from Istra, Croatia, the Lyrid meteor's greenish glow reflects in the waters of the Adriatic Sea.
# URL : http://apod.nasa.gov/apod/image/1504/IMG_2999korosecMilkyMet.jpg
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-52744ce736e2> in <module>()
# ----> 1 APOD('2015-04-23', 'TRUE')
#
# <ipython-input-5-73689d6acbbd> in APOD(date, concept_tags)
#      37     #print(exif_data)
#      38     ret = {}
# ---> 39     for tag, value in exif_data.items():
#      40         decoded = TAGS.get(tag, tag)
#      41         ret[decoded] = value
#
# AttributeError: 'NoneType' object has no attribute 'items'

# %%
ls
# Out:
# 148505                          brown_reader.py*
# APOD_2014-7-31.jpg              capitolWordsAPI.py*
# APOD_2015-04-23.jpg             closest.py*
# APOD_2015-4-12.jpg              geo/
# Bhistorical-USD.csv             gmail-tools/
# Bhistorical-USD.csv.html        inaugural_Corpus.py*
# BoardGames.py*                  landsat8_2014-07-31.png
# BoardGames.pyc                  large_csv_files.py*
# BroadBand Map.ipynb             linker.py
# CobraIcon1.png                  method_man.py*
# CompletelyConfigure.ipynb       network1.diag
# Decleration_of_Human_Rights.py* network1.png
# MailApp.ipynb                   panda.py
# NASA endpoints-Copy1.ipynb      psum.py*
# NASA endpoints.ipynb            psum.pyc
# NASA_API.py*                    psum_test.py*
# NASA_API.pyc                    requestsExample.py*
# OSGEO.ipynb                     scale_interval.diag
# PICS/                           scale_interval.png
# TCP.diag                        seqdiag.diag
# TCP.png                         seqdiag.png
# TIFF/                           slither
# Tiger-BW-thumb.png              slither.py
# Tiger-BW.png                    spam_map.kml
# UDHR_graph_example.py*          state_fips_codes.csv
# actdiag.diag                    sunlightAPI.py*
# actdiag.png                     test.kml
# audio/                          test.wav
# audio-command.sh*               tmp/
# blockdiag.diag                  wordGem.py*
# blockdiag.png                   worldcitiespop.txt

# %%
APOD('2015-04-24', 'TRUE')
# Out:
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=1
# cache-control: no-cache
# Content-Type: application/json
# Date: Fri, 24 Apr 2015 05:39:39 GMT
# Server: nginx
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 996
# x-varnish: 2443479
# Content-Length: 802
# Connection: Close
#
# Title: Blue Tears and the Milky Way
# Date: 2015-04-24
# Explanation: Lapping at rocks along the shore of the Island of Nangan, Taiwan, planet Earth, waves are infused with a subtle blue light in this sea and night skyscape. Composed of a series of long exposures made on April 16 the image captures the faint glow from Noctiluca scintillans. Also known as sea sparkles or blue tears, the marine plankton's bioluminescence is stimulated by wave motion. City lights along the coast of mainland China shine beneath low clouds in the west but stars and the faint Milky Way still fill the night above. Over the horizon the galaxy's central bulge and dark rifts seem to echo the rocks and luminous waves.
# URL : http://apod.nasa.gov/apod/image/1504/RBA_BlueTears1024.jpg
# ({'ColorSpace': 65535,
#   'ExifOffset': 78,
#   'ExifVersion': '0210',
#   'FlashPixVersion': '0100',
#   'ResolutionUnit': 2,
#   'XResolution': (72, 1),
#   'YResolution': (72, 1)},
#  {u'concept_tags': True,
#   u'date': u'2015-04-24',
#   u'explanation': u"Lapping at rocks along the shore of the Island of Nangan, Taiwan, planet Earth, waves are infused with a subtle blue light in this sea and night skyscape. Composed of a series of long exposures made on April 16 the image captures the faint glow from Noctiluca scintillans. Also known as sea sparkles or blue tears, the marine plankton's bioluminescence is stimulated by wave motion. City lights along the coast of mainland China shine beneath low clouds in the west but stars and the faint Milky Way still fill the night above. Over the horizon the galaxy's central bulge and dark rifts seem to echo the rocks and luminous waves.",
#   u'title': u'Blue Tears and the Milky Way',
#   u'url': u'http://apod.nasa.gov/apod/image/1504/RBA_BlueTears1024.jpg'})

# %%
APOD('2001-09-1', 'TRUE')
# Out:
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=1
# cache-control: no-cache
# Content-Type: application/json
# Date: Fri, 24 Apr 2015 05:41:33 GMT
# Server: nginx
# vary: Accept-Encoding
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 995
# x-varnish: 2437828
# Content-Length: 1371
# Connection: Close
#
# Title: Magnetars In The Sky
# Date: 2001-09-1
# Explanation: Indicated on this infrared image of the galactic center region are positions of candidate magnetars -- believed to be the strongest magnets in the galaxy. Classified by observers as Soft Gamma Repeaters (SGRs) and Anomalous X-ray Pulsars (AXPs), these cosmic powerhouses are likely city-sized, spinning, highly-magnetized neutron stars. How strong is a magnetar's magnetic field? The Earth's magnetic field which deflects compass needles is measured to be about 1 Gauss, while the strongest fields sustainable in earthbound laboratories are about 100,000 Gauss. A magnetar's monster magnetic field is estimated to be as high as 1,000,000,000,000,000 Gauss. A magnet this strong, located at about half the distance to the Moon would easily erase your credit cards and suck pens out of your pocket. In 1998, from a distance of about 20,000 light-years, one magnetar, SGR 1900+14 generated a powerful flash of gamma-rays detected by many spacecraft. That blast of high-energy radiation is now known to have had a measurable effect on Earth's ionosphere. At the surface of the magnetar, its powerful magnetic field is thought to buckle and shift the neutron star crust generating the intense high-energy flares.
# URL : http://apod.nasa.gov/apod/image/0109/magnetars_cobeloc.jpg
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-f93af661db4d> in <module>()
# ----> 1 APOD('2001-09-1', 'TRUE')
#
# <ipython-input-5-73689d6acbbd> in APOD(date, concept_tags)
#      37     #print(exif_data)
#      38     ret = {}
# ---> 39     for tag, value in exif_data.items():
#      40         decoded = TAGS.get(tag, tag)
#      41         ret[decoded] = value
#
# AttributeError: 'NoneType' object has no attribute 'items'
