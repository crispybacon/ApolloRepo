# %% [markdown]
# # NASA API Endpoints Workbook Page 1

# %% [markdown]
# #### By Jesse Bacon

# %%
# %matplotlib inline

# %%
import pandas, matplotlib, json, urllib, numpy, PIL
from PIL import Image as img
import matplotlib.pyplot as plt
from IPython.display import SVG, Image, HTML
from PIL.ExifTags import TAGS

# %%
# %matplotlib inline

# %%
api_key = ''

# %% [markdown]
# # APOD
# get a key - 50/day
# https://api.nasa.gov/index.html#apply-for-an-api-key

# %% [raw]
# APOD
#
# GET https://api.nasa.gov/planetary/apod
#
# Query Parameters
#
# Parameter 	Type 	Default 	Description
# date 	YYYY-MM-DD 	today 	The date of the APOD image to retrieve
# hd 	bool 	False 	Retrieve the URL for the high resolution image
# api_key 	string 	DEMO_KEY 	api.nasa.gov key for expanded usage

# %%
def APOD(date, key, hd=False, debug=False):
    """We will be pulling some data from the images."""
    request='https://api.nasa.gov/planetary/apod'
    key=key
    form={'date': date, 'api_key': key}
    query=urllib.parse.urlencode(form)
    APOD_request=urllib.request.urlopen(request+"?"+query)
    if debug==True:
        print(APOD_request.info())
    response=json.loads(APOD_request.read())
    print('Title: ' + response['title'])
    print('Date: ' + response['date'])
    print('Explanation: '+ response['explanation'])
    print('URL : ' + response['url'])
    fname=str('APOD'+'_'+date+'.jpg')
    apod_img=urllib.request.urlretrieve(response['url'], fname)
    im=img.open(fname)
    display=plt.imread(fname)
    plt.imshow(display)
    PIL_format=PIL.Image.open(fname)
    exif_data = PIL_format._getexif()
    ret = {}
    try:
        for tag, value in exif_data.items():
            decoded = TAGS.get(tag, tag)
            ret[decoded] = value
    except:
        pass
    return ret, response

# %%
request='https://api.nasa.gov/planetary/apod'
key=key
form={'date': '2018-7-31', 'api_key': key}
query=urllib.parse.urlencode(form)
APOD_request=urllib.request.urlopen(request+"?"+query)
print(APOD_request.info())
response=json.loads(APOD_request.read())
print('Title: ' + response['title'])
print('Date: ' + response['date'])
print('Explanation: '+ response['explanation'])
print('URL : ' + response['url'])
fname=str('APOD'+'_'+'2018-7-31.jpg')
apod_img=urllib.request.urlretrieve(response['url'], fname)
im=img.open(fname)
display=plt.imread(fname)
plt.imshow(display)
# Out:
# Server: openresty
# Date: Sat, 01 Jun 2019 01:51:49 GMT
# Content-Type: application/json
# Content-Length: 985
# Connection: close
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 990
# Via: 1.1 vegur, http/1.1 api-umbrella (ApacheTrafficServer [cMsSf ])
# Age: 1
# X-Cache: MISS
# Access-Control-Allow-Origin: *
# Strict-Transport-Security: max-age=31536000; preload
#
#
# Title: Layers of the South Pole of Mars
# Date: 2018-07-31
# Explanation: What lies beneath the layered south pole of Mars? A recent measurement with ground-penetrating radar from ESA's Mars Express satellite has detected a bright reflection layer consistent with an underground lake of salty water. The reflection comes from about 1.5 kilometers down and covers an area 20 kilometers across. Liquid water evaporates quickly from the surface of Mars, but a briny confined lake, such as implied by the radar reflection, could last much longer and be a candidate to host life such as microbes.  Pictured, an infrared, green, and blue image of the south pole of Mars taken by Mars Express in 2012 shows a complex mixture of layers of dirt, frozen carbon dioxide, and frozen water.
# URL : https://apod.nasa.gov/apod/image/1807/SouthPole_MarsExpress_1080.jpg

# %%
im.save
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x656 at 0x7FBB537322B0>

# %%
APOD('2015-12-4', key)
# Out:
# Title: Cygnus: Bubble and Crescent
# Date: 2015-12-04
# Explanation: These clouds of gas and dust drift through rich star fields along the plane of our Milky Way Galaxy toward the high flying constellation Cygnus. Caught within the telescopic field of view are the Soap Bubble (lower left) and the Crescent Nebula (upper right). Both were formed at a final phase in the life of a star. Also known as NGC 6888, the Crescent was shaped as its bright, central massive Wolf-Rayet star, WR 136, shed its outer envelope in a strong stellar wind. Burning through fuel at a prodigious rate, WR 136 is near the end of a short life that should finish in a spectacular supernova explosion.  recently discovered Soap Bubble Nebula is likely a planetary nebula, the final shroud of a lower mass, long-lived, sun-like star destined to become a slowly cooling white dwarf. While both are some 5,000 light-years or so distant, the larger Crescent Nebula is around 25 light-years across.
# URL : https://apod.nasa.gov/apod/image/1512/ngc6888_soap_eder_m1024.jpg
# ({'ResolutionUnit': 2,
#   'ExifOffset': 78,
#   'XResolution': (72, 1),
#   'YResolution': (72, 1),
#   'ExifVersion': b'0210',
#   'FlashPixVersion': b'0100',
#   'ColorSpace': 65535},
#  {'copyright': 'Ivan Eder',
#   'date': '2015-12-04',
#   'explanation': 'These clouds of gas and dust drift through rich star fields along the plane of our Milky Way Galaxy toward the high flying constellation Cygnus. Caught within the telescopic field of view are the Soap Bubble (lower left) and the Crescent Nebula (upper right). Both were formed at a final phase in the life of a star. Also known as NGC 6888, the Crescent was shaped as its bright, central massive Wolf-Rayet star, WR 136, shed its outer envelope in a strong stellar wind. Burning through fuel at a prodigious rate, WR 136 is near the end of a short life that should finish in a spectacular supernova explosion.  recently discovered Soap Bubble Nebula is likely a planetary nebula, the final shroud of a lower mass, long-lived, sun-like star destined to become a slowly cooling white dwarf. While both are some 5,000 light-years or so distant, the larger Crescent Nebula is around 25 light-years across.',
#   'hdurl': 'https://apod.nasa.gov/apod/image/1512/ngc6888_soap_eder_m.jpg',
#   'media_type': 'image',
#   'service_version': 'v1',
#   'title': 'Cygnus: Bubble and Crescent',
#   'url': 'https://apod.nasa.gov/apod/image/1512/ngc6888_soap_eder_m1024.jpg'})

# %%
APOD('2016-5-5', key)
# Out:
# Title: The SONG and the Hunter
# Date: 2016-05-05
# Explanation: Near first quarter, the Moon in March lights this snowy, rugged landscape, a view across the top of Tenerife toward La Palma in the Canary Islands Spanish archipelago. The large Teide volcano, the highest point in Spain, looms over the horizon. Shining above are familiar bright stars of Orion, the Hunter. Adding to the dreamlike scene is the 1 meter diameter prototype telescope of the global network project called the Stellar Observations Network Group or SONG. The SONG's fully robotic observatory was captured during the 30 second exposure while the observatory dome, with slit open, was rotated across the field of view.
# URL : https://apod.nasa.gov/apod/image/1605/IMG_5214_SONGandersen1024.JPG
# ({'ResolutionUnit': 2,
#   'ExifOffset': 204,
#   'Make': 'Canon',
#   'Model': 'Canon EOS 600D',
#   'Artist': '',
#   'Orientation': 1,
#   'DateTime': '2016:05:04 15:05:55',
#   'YCbCrPositioning': 2,
#   'Copyright': '',
#   'XResolution': (72, 1),
#   'YResolution': (72, 1),
#   'ExifVersion': b'0230',
#   'ComponentsConfiguration': b'\x01\x02\x03\x00',
#   'ShutterSpeedValue': (-327680, 65536),
#   'DateTimeOriginal': '2016:03:14 00:22:02',
#   'DateTimeDigitized': '2016:03:14 00:22:02',
#   'ApertureValue': (237568, 65536),
#   'ExposureBiasValue': (0, 1),
#   'MeteringMode': 3,
#   'UserComment': b'',
#   'Flash': 16,
#   'FocalLength': (18, 1),
#   'ColorSpace': 1,
#   'ExifImageWidth': 1024,
#   'ExifInteroperabilityOffset': 7846,
#   'FocalPlaneXResolution': (5184000, 905),
#   'FocalPlaneYResolution': (3456000, 595),
#   'SubsecTime': '71',
#   'SubsecTimeOriginal': '71',
#   'SubsecTimeDigitized': '71',
#   'ExifImageHeight': 683,
#   'FocalPlaneResolutionUnit': 2,
#   'ExposureTime': (30, 1),
#   'FNumber': (35, 10),
#   'ExposureProgram': 1,
#   'CustomRendered': 0,
#   'ISOSpeedRatings': 1600,
#   'ExposureMode': 1,
#   'FlashPixVersion': b'0100',
#   'WhiteBalance': 0,
#   'MakerNote': b'%\x00\x01\x00\x03\x001\x00\x00\x00`\x04\x00\x00\x02\x00\x03\x00\x04\x00\x00\x00\xc2\x04\x00\x00\x03\x00\x03\x00\x04\x00\x00\x00\xca\x04\x00\x00\x04\x00\x03\x00"\x00\x00\x00\xd2\x04\x00\x00\x06\x00\x02\x00\x0f\x00\x00\x00\x16\x05\x00\x00\x07\x00\x02\x00\x18\x00\x00\x00&\x05\x00\x00\t\x00\x02\x00 \x00\x00\x00>\x05\x00\x00\r\x00\x07\x00\x00\x06\x00\x00^\x05\x00\x00\x10\x00\x04\x00\x01\x00\x00\x00\x86\x02\x00\x80\x13\x00\x03\x00\x04\x00\x00\x00^\x0b\x00\x00\x19\x00\x03\x00\x01\x00\x00\x00\x01\x00\x00\x00&\x00\x03\x000\x00\x00\x00f\x0b\x00\x00\x83\x00\x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x93\x00\x03\x00\x1c\x00\x00\x00\xc6\x0b\x00\x00\x95\x00\x02\x00F\x00\x00\x00\xfe\x0b\x00\x00\x96\x00\x02\x00\x10\x00\x00\x00D\x0c\x00\x00\x97\x00\x07\x00\x00\x04\x00\x00T\x0c\x00\x00\x98\x00\x03\x00\x04\x00\x00\x00T\x10\x00\x00\x99\x00\x04\x002\x00\x00\x00\\\x10\x00\x00\x9a\x00\x04\x00\x05\x00\x00\x00$\x11\x00\x00\xa0\x00\x03\x00\x0e\x00\x00\x008\x11\x00\x00\xaa\x00\x03\x00\x06\x00\x00\x00T\x11\x00\x00\xb4\x00\x03\x00\x01\x00\x00\x00\x01\x00\x00\x00\xd0\x00\x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\xe0\x00\x03\x00\x11\x00\x00\x00`\x11\x00\x00\x01@\x03\x00\xf9\x04\x00\x00\x82\x11\x00\x00\x08@\x03\x00\x03\x00\x00\x00t\x1b\x00\x00\t@\x03\x00\x03\x00\x00\x00z\x1b\x00\x00\x10@\x02\x00 \x00\x00\x00\x80\x1b\x00\x00\x11@\x07\x00\xfc\x00\x00\x00\xa0\x1b\x00\x00\x12@\x02\x00 \x00\x00\x00\x9c\x1c\x00\x00\x15@\x07\x00t\x00\x00\x00\xbc\x1c\x00\x00\x16@\x04\x00\x06\x00\x00\x000\x1d\x00\x00\x17@\x04\x00\x02\x00\x00\x00H\x1d\x00\x00\x18@\x04\x00\x03\x00\x00\x00P\x1d\x00\x00\x19@\x07\x00\x1e\x00\x00\x00\\\x1d\x00\x00 @\x04\x00\x05\x00\x00\x00z\x1d\x00\x00\x00\x00\x00\x00b\x00\x02\x00\x14\x00\x03\x00\x00\x00\x00\x00\x00\x00\x03\x00\x00\x00\x07\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\xff\x7f\xff\x7f\x01\x00\x02\x00\x00\x00\x04\x00\xff\xff4\x007\x00\x12\x00\x01\x00t\x00 \x01\x00\x00\x00\x00\x00\x00\x00\x00\xff\xff\xff\xff\xff\xff\x00\x00\x00\x00\x00\x00\x00\x00\xff\xff\xff\xff\x00\x00\x00\x00\xff\x7f\xff\xff\xff\xff\x00\x00\x00\x00\x04\x00\x00\x00\x12\x00\xc6"\xeaL\x00\x00\x00\x00\x00\x00\x00\x00D\x00\x00\x00 \x01\xf8\xfet\x00`\xff\x00\x00\x00\x00\x03\x00\x00\x00\x08\x00\x08\x00\x8d\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x00\x00t\x00`\xff\x1f\x00\x00\x00\x00\x00\xf8\x00\xff\xff\xff\xff\xff\xff\xff\xff\x00\x00\x00\x00\x00\x00Canon EOS 600D\x00\x00Firmware Version 1.0.2\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xaa\xaa\x10%\x10%hh\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xc4\t%P\x004\x00\x12\x007\x91u\x92?\x00\xff\xff\xff\xff\xff\xff\x02\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00@\x14\x00\x00\x80\r\x00\x00\xde\x04\x00\x00\xcc\x02\x00\x00\x04\x02\x00\x00X\x01\x00\x00\xd0\x02\x00\x00\xe0\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xd0\x02\x00\x00\xe0\x01\x00\x00\xd0\x02\x00\x00\xe0\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xd0\x02\x00\x00\xe0\x01\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\n\x00\x00\x00\x00\x00\x00\x00\x01\x00\x0 ...
#   'SceneCaptureType': 0},
#  {'copyright': 'Mads\nFredslund Andersen',
#   'date': '2016-05-05',
#   'explanation': "Near first quarter, the Moon in March lights this snowy, rugged landscape, a view across the top of Tenerife toward La Palma in the Canary Islands Spanish archipelago. The large Teide volcano, the highest point in Spain, looms over the horizon. Shining above are familiar bright stars of Orion, the Hunter. Adding to the dreamlike scene is the 1 meter diameter prototype telescope of the global network project called the Stellar Observations Network Group or SONG. The SONG's fully robotic observatory was captured during the 30 second exposure while the observatory dome, with slit open, was rotated across the field of view.",
#   'hdurl': 'https://apod.nasa.gov/apod/image/1605/IMG_5214_SONGandersen2048.JPG',
#   'media_type': 'image',
#   'service_version': 'v1',
#   'title': 'The SONG and the Hunter',
#   'url': 'https://apod.nasa.gov/apod/image/1605/IMG_5214_SONGandersen1024.JPG'})

# %%
APOD('2010-3-20', key)
# Out:
# Title: Zodiacal Light Vs. Milky Way
# Date: 2010-03-20
# Explanation: Ghostly Zodiacal light, featured near the center of this remarkable panorama, is produced as sunlight is scattered by dust in the Solar System's ecliptic plane. In the weeks surrounding the March equinox (today at 1732 UT) Zodiacal light is more prominent after sunset in the northern hemisphere, and before sunrise in the south, when the ecliptic makes a steep angle with the horizon. In the picture, the narrow triangle of Zodiacal light extends above the western horizon and seems to end at the lovely Pleiades star cluster. Arcing above the Pleiades are stars and nebulae along the plane of our Milky Way Galaxy. Recorded on March 10 from Teide National Park on the island of Tenerife, the vista is composed of 4 separate pictures spanning over 180 degrees.
# URL : https://apod.nasa.gov/apod/image/1003/01_zodiacal_lactea_DLopez600h.jpg
# ({},
#  {'copyright': 'Daniel López',
#   'date': '2010-03-20',
#   'explanation': "Ghostly Zodiacal light, featured near the center of this remarkable panorama, is produced as sunlight is scattered by dust in the Solar System's ecliptic plane. In the weeks surrounding the March equinox (today at 1732 UT) Zodiacal light is more prominent after sunset in the northern hemisphere, and before sunrise in the south, when the ecliptic makes a steep angle with the horizon. In the picture, the narrow triangle of Zodiacal light extends above the western horizon and seems to end at the lovely Pleiades star cluster. Arcing above the Pleiades are stars and nebulae along the plane of our Milky Way Galaxy. Recorded on March 10 from Teide National Park on the island of Tenerife, the vista is composed of 4 separate pictures spanning over 180 degrees.",
#   'hdurl': 'https://apod.nasa.gov/apod/image/1003/01_zodiacal_lactea_DLopez.jpg',
#   'media_type': 'image',
#   'service_version': 'v1',
#   'title': 'Zodiacal Light Vs. Milky Way',
#   'url': 'https://apod.nasa.gov/apod/image/1003/01_zodiacal_lactea_DLopez600h.jpg'})

# %%
APOD('2012-7-31', key)
# Out:
# Title: Curiosity Before Mars: Seven Minutes of Terror
# Date: 2012-07-31
# Explanation: Next week at this time, there may be an amazing new robotic explorer on Mars. Or there may be a new pile of junk. It all likely depends on many things going correctly in the minutes after the Mars Science Laboratory mission arrives at Mars and attempts to deploy the Curiosity rover from orbit. Arguably the most sophisticated landing yet attempted on the red planet, consecutive precision events will involve a heat shield, a parachute, several rocket maneuvers, and the automatic operation of an unusual device called a Sky Crane.  These "Seven Minutes of Terror" -- depicted in the above dramatic video -- will begin on Monday, August 6 at about 5:24 am Universal time, which occurs on Sunday night, August 5 for western North Americans. If successful, the car-sized Curiosity rover will rest on the surface of Mars, soon to begin exploring Gale Crater to better determine the habitability of this seemingly barren world to life -- past, present, and future. Although multiple media outlets may cover this event, one way to watch these landing events unfold is on the NASA channel live on the web.
# URL : https://www.youtube.com/embed/Ki_Af_o9Q9s?rel=0
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-32-63af4bf60f09> in <module>
# ----> 1 APOD('2012-7-31', key)
#
# <ipython-input-27-6fbe2e2ded1c> in APOD(date, key, hd, debug)
#      15     fname=str('APOD'+'_'+date+'.jpg')
#      16     apod_img=urllib.request.urlretrieve(response['url'], fname)
# ---> 17     im=img.open(fname)
#      18     display=plt.imread(fname)
#      19     plt.imshow(display)
#
# /usr/local/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode)
#    2583         fp.close()
#    2584     raise IOError("cannot identify image file %r"
# -> 2585                   % (filename if filename else fp))
#    2586
#    2587 #
#
# OSError: cannot identify image file 'APOD_2012-7-31.jpg'

# %%
APOD('2014-7-31', key)
# Out:
# Title: Veins of Heaven
# Date: 2014-07-31
# Explanation: Transfusing sunlight through a still dark sky, this exceptional display of noctilucent clouds was captured earlier this month above the island of Gotland, Sweden. From the edge of space, about 80 kilometers above Earth's surface, the icy clouds reflect sunlight even though the Sun itself is below the horizon as seen from the ground. Usually spotted at high latitudes in summer months the night shining clouds made a strong showing this July. Also known as polar mesopheric clouds they are understood to form as water vapor driven into the cold upper atmosphere condenses on the fine dust particles supplied by disintegrating meteors or volcanic ash. NASA's AIM mission provides daily projections of noctilucent clouds as seen from space.
# URL : https://apod.nasa.gov/apod/image/1407/strongNLCs_heden.jpg
# ({'ImageWidth': 10893,
#   'ImageLength': 5268,
#   'BitsPerSample': (8, 8, 8),
#   'PhotometricInterpretation': 2,
#   'ResolutionUnit': 2,
#   'ExifOffset': 232,
#   'Software': 'Adobe Photoshop CS6 (Windows)',
#   'Orientation': 1,
#   'DateTime': '2014:07:17 23:37:07',
#   'SamplesPerPixel': 3,
#   'XResolution': (720000, 10000),
#   'YResolution': (720000, 10000),
#   'ExifVersion': b'0221',
#   'ShutterSpeedValue': (-378512, 1000000),
#   'ApertureValue': (433985, 100000),
#   'DateTimeOriginal': '2016:06:19 09:24:39',
#   'DateTimeDigitized': '2016:06:19 09:24:39',
#   'ColorSpace': 1,
#   'ExifImageWidth': 1500,
#   'ExifImageHeight': 529,
#   'ExposureTime': (1000000000, 769230769),
#   'FNumber': (1000000000, 222222222)},
#  {'copyright': 'Clear Skies',
#   'date': '2014-07-31',
#   'explanation': "Transfusing sunlight through a still dark sky, this exceptional display of noctilucent clouds was captured earlier this month above the island of Gotland, Sweden. From the edge of space, about 80 kilometers above Earth's surface, the icy clouds reflect sunlight even though the Sun itself is below the horizon as seen from the ground. Usually spotted at high latitudes in summer months the night shining clouds made a strong showing this July. Also known as polar mesopheric clouds they are understood to form as water vapor driven into the cold upper atmosphere condenses on the fine dust particles supplied by disintegrating meteors or volcanic ash. NASA's AIM mission provides daily projections of noctilucent clouds as seen from space.",
#   'hdurl': 'https://apod.nasa.gov/apod/image/1407/strongNLCs_heden.jpg',
#   'media_type': 'image',
#   'service_version': 'v1',
#   'title': 'Veins of Heaven',
#   'url': 'https://apod.nasa.gov/apod/image/1407/strongNLCs_heden.jpg'})

# %% [markdown]
# # NEO
#  Retrieve a list of Asteroids based on their closest approach date to Earth.
#  GET https://api.nasa.gov/neo/rest/v1/feed?start_date=START_DATE&end_date=END_DATE&api_key=API_KEY
# Query Parameters
# Parameter 	Type 	Default 	Description
# start_date 	YYYY-MM-DD 	none 	Starting date for asteroid search
# end_date 	YYYY-MM-DD 	7 days after start_date 	Ending date for asteroid search
# api_key 	string 	DEMO_KEY 	api.nasa.gov key for expanded usage
# Example query
#
# https://api.nasa.gov/neo/rest/v1/feed?start_date=2015-09-07&end_date=2015-09-08&api_key=DEMO_KEY

# %%
def NEO(start_date, end_date, key, debug=False):
    """We will be pulling some data from the images."""
    request='https://api.nasa.gov/neo/rest/v1/feed'
    key=key
    form={'start_date': start_date, 'start_date': start_date, 'api_key': key}
    query=urllib.parse.urlencode(form)
    NEO_request=urllib.request.urlopen(request+"?"+query)
    if debug==True:
        print(NEO_request.info())
    response=json.loads(NEO_request.read())
    return response

# %%
test_data = NEO('2018-07-31', '2018-07-31', api_key)

# %%
type(test_data)
# Out:
# dict

# %%
test_data
# Out:
# {'links': {'next': 'http://www.neowsapp.com/rest/v1/feed?start_date=2018-08-07&end_date=2018-08-14&detailed=false&api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4',
#   'prev': 'http://www.neowsapp.com/rest/v1/feed?start_date=2018-07-24&end_date=2018-07-31&detailed=false&api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4',
#   'self': 'http://www.neowsapp.com/rest/v1/feed?start_date=2018-07-31&end_date=2018-08-07&detailed=false&api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#  'element_count': 77,
#  'near_earth_objects': {'2018-08-01': [{'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3092334?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3092334',
#     'neo_reference_id': '3092334',
#     'name': '(2001 SC170)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3092334',
#     'absolute_magnitude_h': 20.4,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2210828104,
#       'estimated_diameter_max': 0.4943561926},
#      'meters': {'estimated_diameter_min': 221.0828103591,
#       'estimated_diameter_max': 494.3561926196},
#      'miles': {'estimated_diameter_min': 0.137374447,
#       'estimated_diameter_max': 0.3071786018},
#      'feet': {'estimated_diameter_min': 725.3373275385,
#       'estimated_diameter_max': 1621.9035709942}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-01',
#       'close_approach_date_full': '2018-Aug-01 09:51',
#       'epoch_date_close_approach': 1533117060000,
#       'relative_velocity': {'kilometers_per_second': '7.9503412498',
#        'kilometers_per_hour': '28621.2284993945',
#        'miles_per_hour': '17784.1183417488'},
#       'miss_distance': {'astronomical': '0.176385598',
#        'lunar': '68.613997622',
#        'kilometers': '26386909.75947626',
#        'miles': '16396065.428881988'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3674338?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3674338',
#     'neo_reference_id': '3674338',
#     'name': '(2014 NE3)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3674338',
#     'absolute_magnitude_h': 20.1,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2538370294,
#       'estimated_diameter_max': 0.5675968529},
#      'meters': {'estimated_diameter_min': 253.8370293645,
#       'estimated_diameter_max': 567.5968528656},
#      'miles': {'estimated_diameter_min': 0.1577269688,
#       'estimated_diameter_max': 0.3526882241},
#      'feet': {'estimated_diameter_min': 832.7986794202,
#       'estimated_diameter_max': 1862.1944587557}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-01',
#       'close_approach_date_full': '2018-Aug-01 04:39',
#       'epoch_date_close_approach': 1533098340000,
#       'relative_velocity': {'kilometers_per_second': '14.1312311789',
#        'kilometers_per_hour': '50872.4322439298',
#        'miles_per_hour': '31610.151024013'},
#       'miss_distance': {'astronomical': '0.1495192981',
#        'lunar': '58.1630069609',
#        'kilometers': '22367768.519655047',
#        'miles': '13898686.8674397686'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3826673?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3826673',
#     'neo_reference_id': '3826673',
#     'name': '(2018 PQ9)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3826673',
#     'absolute_magnitude_h': 24.8,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0291443905,
#       'estimated_diameter_max': 0.0651688382},
#      'meters': {'estimated_diameter_min': 29.1443904535,
#       'estimated_diameter_max': 65.1688382168},
#      'miles': {'estimated_diameter_min': 0.018109479,
#       'estimated_diameter_max': 0.0404940262},
#      'feet': {'estimated_diameter_min': 95.6180819754,
#       'estimated_diameter_max': 213.8085311752}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-01',
#       'close_approach_date_full': '2018-Aug-01 21:19',
#       'epoch_date_close_approach': 1533158340000,
#       'relative_velocity': {'kilometers_per_second': '6.6566195446',
#        'kilometers_per_hour': '23963.8303605946',
#        'miles_per_hour': '14890.1922593373'},
#       'miss_distance': {'astronomical': '0.1127986783',
#        'lunar': '43.8786858587',
#        'kilometers': '16874442.012495221',
#        'miles': '10485292.0571112098'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3826886?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3826886',
#     'neo_reference_id': '3826886',
#     'name': '(2018 PR24)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3826886',
#     'absolute_magnitude_h': 24.8,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0291443905,
#       'estimated_diameter_max': 0.0651688382},
#      'meters': {'estimated_diameter_min': 29.1443904535,
#       'estimated_diameter_max': 65.1688382168},
#      'miles': {'estimated_diameter_min': 0.018109479,
#       'estimated_diameter_max': 0.0404940262},
#      'feet': {'estimated_diameter_min': 95.6180819754,
#       'estimated_diameter_max': 213.8085311752}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-01',
#       'close_approach_date_full': '2018-Aug-01 12:37',
#       'epoch_date_close_approach': 1533127020000,
#       'relative_velocity': {'kilometers_per_second': '14.0110739352',
#        'kilometers_per_hour': '50439.8661665854',
#        'miles_per_hour': '31341.3712855652'},
#       'miss_distance': {'astronomical': '0.0365241859',
#        'lunar': '14.2079083151',
#        'kilometers': '5463940.414124033',
#        'miles': '3395135.1388283354'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3826652?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3826652',
#     'neo_reference_id': '3826652',
#     'name': '(2018 PD9)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3826652',
#     'absolute_magnitude_h': 27.4,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0088014652,
#       'estimated_diameter_max': 0.0196806745},
#      'meters': {'estimated_diameter_min': 8.801465209,
#       'estimated_diameter_max': 19.6806745089},
#      'miles': {'estimated_diameter_min': 0.0054689752,
#       'estimated_diameter_max': 0.0122290004},
#      'feet': {'estimated_diameter_min': 28.8761991163,
#       'estimated_diameter_max': 64.5691441559}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-01',
#       'close_approach_date_full': '2018-Aug-01 09:10',
#       'epoch_date_close_approach': 1533114600000,
#       'relative_velocity': {'kilometers_per_second': '6.1840495263',
#        'kilometers_per_hour': '22262.5782946276',
#        'miles_per_hour': '13833.1003853479'},
#       'miss_distance': {'astronomical': '0.0136524091',
#        'lunar': '5.3107871399',
#        'kilometers': '2042371.321728617',
#        'miles': '1269070.6917322346'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3826798?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3826798',
#     'neo_reference_id': '3826798',
#     'name': '(2018 PA22)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3826798',
#     'absolute_magnitude_h': 25.7,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0192555078,
#       'estimated_diameter_max': 0.0430566244},
#      'meters': {'estimated_diameter_min': 19.2555078188,
#       'estimated_diameter_max': 43.0566244241},
#      'miles': {'estimated_diameter_min': 0.0119648141,
#       'estimated_diameter_max': 0.0267541378},
#      'feet': {'estimated_diameter_min': 63.1742402722,
#       'estimated_diameter_max': 141.2618956756}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-01',
#       'close_approach_date_full': '2018-Aug-01 23:22',
#       'epoch_date_close_approach': 1533165720000,
#       'relative_velocity': {'kilometers_per_second': '5.1446842552',
#        'kilometers_per_hour': '18520.8633188246',
#        'miles_per_hour': '11508.1442105219'},
#       'miss_distance': {'astronomical': '0.085317468',
#        'lunar': '33.188495052',
#        'kilometers': '12763311.48659316',
#        'miles': '7930754.003819208'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2420591?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '2420591',
#     'neo_reference_id': '2420591',
#     'name': '420591 (2012 HF31)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2420591',
#     'absolute_magnitude_h': 19.3,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3669061375,
#       'estimated_diameter_max': 0.8204270649},
#      'meters': {'estimated_diameter_min': 366.9061375314,
#       'estimated_diameter_max': 820.4270648822},
#      'miles': {'estimated_diameter_min': 0.2279848336,
#       'estimated_diameter_max': 0.5097895857},
#      'feet': {'estimated_diameter_min': 1203.7603322587,
#       'estimated_diameter_max': 2691.6899315481}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-01',
#       'close_approach_date_full': '2018-Aug-01 09:38',
#       'epoch_date_close_approach': 1533116280000,
#       'relative_velocity': {'kilometers_per_second': '10.6585433545',
#        'kilometers_per_hour': '38370.7560762036',
#        'miles_per_hour': '23842.0956296833'},
#       'miss_distance': {'astronomical': '0.0720698876',
#        'lunar': '28.0351862764',
#        'kilometers': '10781501.676099412',
#        'miles': '6699314.4901874056'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3477703?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3477703',
#     'neo_reference_id': '3477703',
#     'name': '(2009 WQ6)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3477703',
#     'absolute_magnitude_h': 29.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0038419789,
#       'estimated_diameter_max': 0.008590926},
#      'meters': {'estimated_diameter_min': 3.8419789106,
#       'estimated_diameter_max': 8.5909260123},
#      'miles': {'estimated_diameter_min': 0.0023872943,
#       'estimated_diameter_max': 0.0053381523},
#      'feet': {'estimated_diameter_min': 12.6049180892,
#       'estimated_diameter_max': 28.1854536983}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-01',
#       'close_approach_date_full': '2018-Aug-01 01:39',
#       'epoch_date_close_approach': 1533087540000,
#       'relative_velocity': {'kilometers_per_second': '18.6349236443',
#        'kilometers_per_hour': '67085.7251196406',
#        'miles_per_hour': '41684.4607000344'},
#       'miss_distance': {'astronomical': '0.4913769782',
#        'lunar': '191.1456445198',
#        'kilometers': '73508949.305756434',
#        'miles': '45676343.0584254292'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3837859?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3837859',
#     'neo_reference_id': '3837859',
#     'name': '(2019 AN11)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3837859',
#     'absolute_magnitude_h': 25.311,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.023033237,
#       'estimated_diameter_max': 0.0515038837},
#      'meters': {'estimated_diameter_min': 23.0332370172,
#       'estimated_diameter_max': 51.5038837124},
#      'miles': {'estimated_diameter_min': 0.0143121855,
#       'estimated_diameter_max': 0.0320030197},
#      'feet': {'estimated_diameter_min': 75.5683653356,
#       'estimated_diameter_max': 168.976001839}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-01',
#       'close_approach_date_full': '2018-Aug-01 18:47',
#       'epoch_date_close_approach': 1533149220000,
#       'relative_velocity': {'kilometers_per_second': '9.5861019003',
#        'kilometers_per_hour': '34509.9668409268',
#        'miles_per_hour': '21443.1513406859'},
#       'miss_distance': {'astronomical': '0.2938277484',
#        'lunar': '114.2989941276',
#        'kilometers': '43956005.307535908',
#        'miles': '27312995.1776872104'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2018-08-02': [{'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3721161?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3721161',
#     'neo_reference_id': '3721161',
#     'name': '(2015 LN21)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3721161',
#     'absolute_magnitude_h': 23.0,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0667659413,
#       'estimated_diameter_max': 0.1492931834},
#      'meters': {'estimated_diameter_min': 66.7659413495,
#       'estimated_diameter_max': 149.2931834393},
#      'miles': {'estimated_diameter_min': 0.0414864197,
#       'estimated_diameter_max': 0.0927664547},
#      'feet': {'estimated_diameter_min': 219.0483710172,
#       'estimated_diameter_max': 489.807047955}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-02',
#       'close_approach_date_full': '2018-Aug-02 12:51',
#       'epoch_date_close_approach': 1533214260000,
#       'relative_velocity': {'kilometers_per_second': '9.3282762475',
#        'kilometers_per_hour': '33581.7944908493',
#        'miles_per_hour': '20866.4211379391'},
#       'miss_distance': {'astronomical': '0.1805407089',
#        'lunar': '70.2303357621',
#        'kilometers': '27008505.499730043',
#        'miles': '16782307.1116108734'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3826625?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3826625',
#     'neo_reference_id': '3826625',
#     'name': '(2018 PX7)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3826625',
#     'absolute_magnitude_h': 22.1,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1010543415,
#       'estimated_diameter_max': 0.2259643771},
#      'meters': {'estimated_diameter_min': 101.054341542,
#       'estimated_diameter_max': 225.9643771094},
#      'miles': {'estimated_diameter_min': 0.0627922373,
#       'estimated_diameter_max': 0.140407711},
#      'feet': {'estimated_diameter_min': 331.5431259047,
#       'estimated_diameter_max': 741.3529669956}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-02',
#       'close_approach_date_full': '2018-Aug-02 01:41',
#       'epoch_date_close_approach': 1533174060000,
#       'relative_velocity': {'kilometers_per_second': '5.5821891025',
#        'kilometers_per_hour': '20095.8807689591',
#        'miles_per_hour': '12486.7988033569'},
#       'miss_distance': {'astronomical': '0.1910470827',
#        'lunar': '74.3173151703',
#        'kilometers': '28580236.641633849',
#        'miles': '17758935.5563271562'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3733138?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3733138',
#     'neo_reference_id': '3733138',
#     'name': '(2015 VK1)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3733138',
#     'absolute_magnitude_h': 26.6,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0127219879,
#       'estimated_diameter_max': 0.0284472297},
#      'meters': {'estimated_diameter_min': 12.7219878539,
#       'estimated_diameter_max': 28.4472296503},
#      'miles': {'estimated_diameter_min': 0.0079050743,
#       'estimated_diameter_max': 0.0176762835},
#      'feet': {'estimated_diameter_min': 41.7388066307,
#       'estimated_diameter_max': 93.330808926}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-02',
#       'close_approach_date_full': '2018-Aug-02 14:52',
#       'epoch_date_close_approach': 1533221520000,
#       'relative_velocity': {'kilometers_per_second': '16.2663968149',
#        'kilometers_per_hour': '58559.0285335813',
#        'miles_per_hour': '36386.3030352133'},
#       'miss_distance': {'astronomical': '0.4589271348',
#        'lunar': '178.5226554372',
#        'kilometers': '68654521.851282876',
#        'miles': '42659941.7106046488'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2018-07-31': [{'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3825662?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3825662',
#     'neo_reference_id': '3825662',
#     'name': '(2018 NR4)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3825662',
#     'absolute_magnitude_h': 20.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2424124811,
#       'estimated_diameter_max': 0.5420507863},
#      'meters': {'estimated_diameter_min': 242.4124811008,
#       'estimated_diameter_max': 542.0507863358},
#      'miles': {'estimated_diameter_min': 0.1506280858,
#       'estimated_diameter_max': 0.3368146392},
#      'feet': {'estimated_diameter_min': 795.3165644948,
#       'estimated_diameter_max': 1778.3819018419}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-07-31',
#       'close_approach_date_full': '2018-Jul-31 12:03',
#       'epoch_date_close_approach': 1533038580000,
#       'relative_velocity': {'kilometers_per_second': '30.6705713378',
#        'kilometers_per_hour': '110414.0568159418',
#        'miles_per_hour': '68607.0010254389'},
#       'miss_distance': {'astronomical': '0.4546576378',
#        'lunar': '176.8618211042',
#        'kilometers': '68015814.194111486',
#        'miles': '42263067.1757550668'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3653687?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3653687',
#     'neo_reference_id': '3653687',
#     'name': '(2013 VG13)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3653687',
#     'absolute_magnitude_h': 21.7,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1214940408,
#       'estimated_diameter_max': 0.2716689341},
#      'meters': {'estimated_diameter_min': 121.4940407996,
#       'estimated_diameter_max': 271.6689340891},
#      'miles': {'estimated_diameter_min': 0.0754928736,
#       'estimated_diameter_max': 0.1688071972},
#      'feet': {'estimated_diameter_min': 398.6025088171,
#       'estimated_diameter_max': 891.3023057169}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-07-31',
#       'close_approach_date_full': None,
#       'epoch_date_close_approach': 1533020400000,
#       'relative_velocity': {'kilometers_per_second': '24.2087037531',
#        'kilometers_per_hour': '87151.3335110794',
#        'miles_per_hour': '54152.4494252593'},
#       'miss_distance': {'astronomical': '0.4590240683',
#        'lunar': '178.5603625687',
#        'kilometers': '68669022.896414521',
#        'miles': '42668952.2422255498'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3709711?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3709711',
#     'neo_reference_id': '3709711',
#     'name': '(2015 BP515)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3709711',
#     'absolute_magnitude_h': 21.1,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.160160338,
#       'estimated_diameter_max': 0.358129403},
#      'meters': {'estimated_diameter_min': 160.1603379786,
#       'estimated_diameter_max': 358.1294030194},
#      'miles': {'estimated_diameter_min': 0.0995189894,
#       'estimated_diameter_max': 0.2225312253},
#      'feet': {'estimated_diameter_min': 525.4604432536,
#       'estimated_diameter_max': 1174.9652706022}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2018-07-31',
#       'close_approach_date_full': '2018-Jul-31 17:21',
#       'epoch_date_close_approach': 1533057660000,
#       'relative_velocity': {'kilometers_per_second': '10.7343652863',
#        'kilometers_per_hour': '38643.7150307714',
#        'miles_per_hour': '24011.7017089813'},
#       'miss_distance': {'astronomical': '0.1307073171',
#        'lunar': '50.8451463519',
#        'kilometers': '19553536.231574577',
#        'miles': '12150004.0111280826'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3825597?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3825597',
#     'neo_reference_id': '3825597',
#     'name': '(2018 NG2)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3825597',
#     'absolute_magnitude_h': 21.6,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1272198785,
#       'estimated_diameter_max': 0.2844722965},
#      'meters': {'estimated_diameter_min': 127.2198785394,
#       'estimated_diameter_max': 284.4722965033},
#      'miles': {'estimated_diameter_min': 0.0790507431,
#       'estimated_diameter_max': 0.1767628354},
#      'feet': {'estimated_diameter_min': 417.3880663071,
#       'estimated_diameter_max': 933.3080892598}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-07-31',
#       'close_approach_date_full': '2018-Jul-31 09:00',
#       'epoch_date_close_approach': 1533027600000,
#       'relative_velocity': {'kilometers_per_second': '9.4089839455',
#        'kilometers_per_hour': '33872.3422038725',
#        'miles_per_hour': '21046.956187734'},
#       'miss_distance': {'astronomical': '0.284722798',
#        'lunar': '110.757168422',
#        'kilometers': '42593924.12124026',
#        'miles': '26466637.174665188'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3826771?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3826771',
#     'neo_reference_id': '3826771',
#     'name': '(2018 PM21)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3826771',
#     'absolute_magnitude_h': 25.6,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0201629919,
#       'estimated_diameter_max': 0.0450858206},
#      'meters': {'estimated_diameter_min': 20.1629919443,
#       'estimated_diameter_max': 45.0858206172},
#      'miles': {'estimated_diameter_min': 0.0125286985,
#       'estimated_diameter_max': 0.0280150214},
#      'feet': {'estimated_diameter_min': 66.1515504905,
#       'estimated_diameter_max': 147.9193637137}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-07-31',
#       'close_approach_date_full': '2018-Jul-31 00:17',
#       'epoch_date_close_approach': 1532996220000,
#       'relative_velocity': {'kilometers_per_second': '2.8158800596',
#        'kilometers_per_hour': '10137.1682143967',
#        'miles_per_hour': '6298.8421052178'},
#       'miss_distance': {'astronomical': '0.085013209',
#        'lunar': '33.070138301',
#        'kilometers': '12717794.98826483',
#        'miles': '7902471.363241454'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3803763?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3803763',
#     'neo_reference_id': '3803763',
#     'name': '(2018 GA5)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3803763',
#     'absolute_magnitude_h': 18.5,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.5303407233,
#       'estimated_diameter_max': 1.1858779086},
#      'meters': {'estimated_diameter_min': 530.3407233187,
#       'estimated_diameter_max': 1185.8779085771},
#      'miles': {'estimated_diameter_min': 0.3295383456,
#       'estimated_diameter_max': 0.7368701419},
#      'feet': {'estimated_diameter_min': 1739.963058693,
#       'estimated_diameter_max': 3890.675677576}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-07-31',
#       'close_approach_date_full': '2018-Jul-31 13:02',
#       'epoch_date_close_approach': 1533042120000,
#       'relative_velocity': {'kilometers_per_second': '16.6116081539',
#        'kilometers_per_hour': '59801.7893540746',
#        'miles_per_hour': '37158.5062794804'},
#       'miss_distance': {'astronomical': '0.2460784083',
#        'lunar': '95.7245008287',
#        'kilometers': '36812805.734670321',
#        'miles': '22874416.7827235898'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3826800?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3826800',
#     'neo_reference_id': '3826800',
#     'name': '(2018 PW21)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3826800',
#     'absolute_magnitude_h': 24.9,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0278326768,
#       'estimated_diameter_max': 0.0622357573},
#      'meters': {'estimated_diameter_min': 27.8326768072,
#       'estimated_diameter_max': 62.2357573367},
#      'miles': {'estimated_diameter_min': 0.0172944182,
#       'estimated_diameter_max': 0.0386714948},
#      'feet': {'estimated_diameter_min': 91.3145593761,
#       'estimated_diameter_max': 204.1855621004}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-07-31',
#       'close_approach_date_full': '2018-Jul-31 16:53',
#       'epoch_date_close_approach': 1533055980000,
#       'relative_velocity': {'kilometers_per_second': '7.6071345471',
#        'kilometers_per_hour': '27385.6843697237',
#        'miles_per_hour': '17016.3992685097'},
#       'miss_distance': {'astronomical': '0.0882631813',
#        'lunar': '34.3343775257',
#        'kilometers': '13203983.921903831',
#        'miles': '8204575.1578656278'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3825585?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3825585',
#     'neo_reference_id': '3825585',
#     'name': '(2018 NU1)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3825585',
#     'absolute_magnitude_h': 21.5,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1332155667,
#       'estimated_diameter_max': 0.2978790628},
#      'meters': {'estimated_diameter_min': 133.2155666981,
#       'estimated_diameter_max': 297.8790627982},
#      'miles': {'estimated_diameter_min': 0.0827762899,
#       'estimated_diameter_max': 0.1850934111},
#      'feet': {'estimated_diameter_min': 437.0589598459,
#       'estimated_diameter_max': 977.2935443908}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-07-31',
#       'close_approach_date_full': '2018-Jul-31 08:15',
#       'epoch_date_close_approach': 1533024900000,
#       'relative_velocity': {'kilometers_per_second': '9.9756286059',
#        'kilometers_per_hour': '35912.2629813694',
#        'miles_per_hour': '22314.4836286181'},
#       'miss_distance': {'astronomical': '0.2133522618',
#        'lunar': '82.9940298402',
#        'kilometers': '31917043.924962366',
#        'miles': '19832331.4575420108'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3826622?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3826622',
#     'neo_reference_id': '3826622',
#     'name': '(2018 PU7)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3826622',
#     'absolute_magnitude_h': 23.4,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0555334912,
#       'estimated_diameter_max': 0.1241766613},
#      'meters': {'estimated_diameter_min': 55.5334911581,
#       'estimated_diameter_max': 124.1766612574},
#      'miles': {'estimated_diameter_min': 0.0345069009,
#       'estimated_diameter_max': 0.0771597762},
#      'feet': {'estimated_diameter_min': 182.1964991311,
#       'estimated_diameter_max': 407.4037573197}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-07-31',
#       'close_approach_date_full': '2018-Jul-31 01:35',
#       'epoch_date_close_approach': 1533000900000,
#       'relative_velocity': {'kilometers_per_second': '10.3948961421',
#        'kilometers_per_hour': '37421.6261116471',
#        'miles_per_hour': '23252.3431803176'},
#       'miss_distance': {'astronomical': '0.0361305854',
#        'lunar': '14.0547977206',
#        'kilometers': '5405058.617693098',
#        'miles': '3358547.6871088324'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3827130?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3827130',
#     'neo_reference_id': '3827130',
#     'name': '(2018 PA25)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3827130',
#     'absolute_magnitude_h': 24.8,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0291443905,
#       'estimated_diameter_max': 0.0651688382},
#      'meters': {'estimated_diameter_min': 29.1443904535,
#       'estimated_diameter_max': 65.1688382168},
#      'miles': {'estimated_diameter_min': 0.018109479,
#       'estimated_diameter_max': 0.0404940262},
#      'feet': {'estimated_diameter_min': 95.6180819754,
#       'estimated_diameter_max': 213.8085311752}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-07-31',
#       'close_approach_date_full': '2018-Jul-31 15:03',
#       'epoch_date_close_approach': 1533049380000,
#       'relative_velocity': {'kilometers_per_second': '17.8962401702',
#        'kilometers_per_hour': '64426.4646128233',
#        'miles_per_hour': '40032.0996367846'},
#       'miss_distance': {'astronomical': '0.0273223867',
#        'lunar': '10.6284084263',
#        'kilometers': '4087370.853636329',
#        'miles': '2539774.4775421802'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2337252?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '2337252',
#     'neo_reference_id': '2337252',
#     'name': '337252 (2000 SD8)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2337252',
#     'absolute_magnitude_h': 20.8,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1838886721,
#       'estimated_diameter_max': 0.411187571},
#      'meters': {'estimated_diameter_min': 183.8886720703,
#       'estimated_diameter_max': 411.1875710413},
#      'miles': {'estimated_diameter_min': 0.1142630881,
#       'estimated_diameter_max': 0.2555000322},
#      'feet': {'estimated_diameter_min': 603.309310875,
#       'estimated_diameter_max': 1349.040630575}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-07-31',
#       'close_approach_date_full': '2018-Jul-31 13:18',
#       'epoch_date_close_approach': 1533043080000,
#       'relative_velocity': {'kilometers_per_second': '5.6557036106',
#        'kilometers_per_hour': '20360.5329980614',
#        'miles_per_hour': '12651.2434064899'},
#       'miss_distance': {'astronomical': '0.1737686535',
#        'lunar': '67.5960062115',
#        'kilometers': '25995420.436368045',
#        'miles': '16152805.243627221'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2501243?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '2501243',
#     'neo_reference_id': '2501243',
#     'name': '501243 (2013 VG13)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2501243',
#     'absolute_magnitude_h': 21.8,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1160259082,
#       'estimated_diameter_max': 0.2594418179},
#      'meters': {'estimated_diameter_min': 116.0259082094,
#       'estimated_diameter_max': 259.4418179074},
#      'miles': {'estimated_diameter_min': 0.0720951346,
#       'estimated_diameter_max': 0.1612096218},
#      'feet': {'estimated_diameter_min': 380.6624406898,
#       'estimated_diameter_max': 851.1870938635}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-07-31',
#       'close_approach_date_full': '2018-Jul-31 06:34',
#       'epoch_date_close_approach': 1533018840000,
#       'relative_velocity': {'kilometers_per_second': '24.208703766',
#        'kilometers_per_hour': '87151.3335577044',
#        'miles_per_hour': '54152.4494542303'},
#       'miss_distance': {'astronomical': '0.4590240685',
#        'lunar': '178.5603626465',
#        'kilometers': '68669022.926334095',
#        'miles': '42668952.260816711'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3572706?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3572706',
#     'neo_reference_id': '3572706',
#     'name': '(2011 OB)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3572706',
#     'absolute_magnitude_h': 19.4,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3503926411,
#       'estimated_diameter_max': 0.7835017643},
#      'meters': {'estimated_diameter_min': 350.3926411083,
#       'estimated_diameter_max': 783.5017643338},
#      'miles': {'estimated_diameter_min': 0.2177238258,
#       'estimated_diameter_max': 0.4868452748},
#      'feet': {'estimated_diameter_min': 1149.5821926537,
#       'estimated_diameter_max': 2570.543928497}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2018-07-31',
#       'close_approach_date_full': '2018-Jul-31 21:07',
#       'epoch_date_close_approach': 1533071220000,
#       'relative_velocity': {'kilometers_per_second': '14.9470052319',
#        'kilometers_per_hour': '53809.2188346974',
#        'miles_per_hour': '33434.9560031485'},
#       'miss_distance': {'astronomical': '0.4941436235',
#        'lunar': '192.2218695415',
#        'kilometers': '73922833.549681945',
#        'miles': '45933518.802203041'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3837682?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3837682',
#     'neo_reference_id': '3837682',
#     'name': '(2019 AN5)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3837682',
#     'absolute_magnitude_h': 21.164,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1555088023,
#       'estimated_diameter_max': 0.3477282531},
#      'meters': {'estimated_diameter_min': 155.5088023283,
#       'estimated_diameter_max': 347.7282531057},
#      'miles': {'estimated_diameter_min': 0.09662866,
#       'estimated_diameter_max': 0.2160682524},
#      'feet': {'estimated_diameter_min': 510.1994990308,
#       'estimated_diameter_max': 1140.8407619192}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2018-07-31',
#       'close_approach_date_full': '2018-Jul-31 03:26',
#       'epoch_date_close_approach': 1533007560000,
#       'relative_velocity': {'kilometers_per_second': '17.394177959',
#        'kilometers_per_hour': '62619.0406523489',
#        'miles_per_hour': '38909.0366764553'},
#       'miss_distance': {'astronomical': '0.3151695317',
#        'lunar': '122.6009478313',
#        'kilometers': '47148690.631217479',
#        'miles': '29296837.8458160502'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2018-08-07': [{'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2217013?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '2217013',
#     'neo_reference_id': '2217013',
#     'name': '217013 (2001 AA50)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2217013',
#     'absolute_magnitude_h': 18.7,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.4836764882,
#       'estimated_diameter_max': 1.0815335068},
#      'meters': {'estimated_diameter_min': 483.6764882185,
#       'estimated_diameter_max': 1081.533506775},
#      'miles': {'estimated_diameter_min': 0.3005425432,
#       'estimated_diameter_max': 0.6720335566},
#      'feet': {'estimated_diameter_min': 1586.8651696069,
#       'estimated_diameter_max': 3548.3383903678}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-07',
#       'close_approach_date_full': '2018-Aug-07 00:48',
#       'epoch_date_close_approach': 1533602880000,
#       'relative_velocity': {'kilometers_per_second': '22.4420581873',
#        'kilometers_per_hour': '80791.409474348',
#        'miles_per_hour': '50200.6399592136'},
#       'miss_distance': {'astronomical': '0.4500478618',
#        'lunar': '175.0686182402',
#        'kilometers': '67326201.523334366',
#        'miles': '41834561.7321956108'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3825486?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3825486',
#     'neo_reference_id': '3825486',
#     'name': '(2018 MD7)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3825486',
#     'absolute_magnitude_h': 22.6,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0802703167,
#       'estimated_diameter_max': 0.1794898848},
#      'meters': {'estimated_diameter_min': 80.2703167283,
#       'estimated_diameter_max': 179.4898847799},
#      'miles': {'estimated_diameter_min': 0.049877647,
#       'estimated_diameter_max': 0.1115298092},
#      'feet': {'estimated_diameter_min': 263.3540659348,
#       'estimated_diameter_max': 588.8775935812}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-07',
#       'close_approach_date_full': '2018-Aug-07 05:40',
#       'epoch_date_close_approach': 1533620400000,
#       'relative_velocity': {'kilometers_per_second': '5.847649663',
#        'kilometers_per_hour': '21051.5387867511',
#        'miles_per_hour': '13080.6075311343'},
#       'miss_distance': {'astronomical': '0.0588634739',
#        'lunar': '22.8978913471',
#        'kilometers': '8805850.316240593',
#        'miles': '5471701.6603344634'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3674659?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3674659',
#     'neo_reference_id': '3674659',
#     'name': '(2014 NL52)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3674659',
#     'absolute_magnitude_h': 23.6,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0506471459,
#       'estimated_diameter_max': 0.1132504611},
#      'meters': {'estimated_diameter_min': 50.6471458835,
#       'estimated_diameter_max': 113.2504610618},
#      'miles': {'estimated_diameter_min': 0.0314706677,
#       'estimated_diameter_max': 0.0703705522},
#      'feet': {'estimated_diameter_min': 166.1651821003,
#       'estimated_diameter_max': 371.5566426699}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-07',
#       'close_approach_date_full': '2018-Aug-07 07:04',
#       'epoch_date_close_approach': 1533625440000,
#       'relative_velocity': {'kilometers_per_second': '14.2212822476',
#        'kilometers_per_hour': '51196.6160913776',
#        'miles_per_hour': '31811.5862596674'},
#       'miss_distance': {'astronomical': '0.3328630987',
#        'lunar': '129.4837453943',
#        'kilometers': '49795610.567119769',
#        'miles': '30941557.6273160522'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3150768?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3150768',
#     'neo_reference_id': '3150768',
#     'name': '(2003 EM1)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3150768',
#     'absolute_magnitude_h': 24.5,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0334622374,
#       'estimated_diameter_max': 0.0748238376},
#      'meters': {'estimated_diameter_min': 33.4622374455,
#       'estimated_diameter_max': 74.8238376074},
#      'miles': {'estimated_diameter_min': 0.0207924639,
#       'estimated_diameter_max': 0.0464933628},
#      'feet': {'estimated_diameter_min': 109.7842471007,
#       'estimated_diameter_max': 245.4850393757}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-07',
#       'close_approach_date_full': '2018-Aug-07 16:59',
#       'epoch_date_close_approach': 1533661140000,
#       'relative_velocity': {'kilometers_per_second': '9.4864574716',
#        'kilometers_per_hour': '34151.2468978402',
#        'miles_per_hour': '21220.2567182719'},
#       'miss_distance': {'astronomical': '0.211485768',
#        'lunar': '82.267963752',
#        'kilometers': '31637820.42811416',
#        'miles': '19658830.021969008'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3826762?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3826762',
#     'neo_reference_id': '3826762',
#     'name': '(2018 PO20)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3826762',
#     'absolute_magnitude_h': 26.5,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0133215567,
#       'estimated_diameter_max': 0.0297879063},
#      'meters': {'estimated_diameter_min': 13.3215566698,
#       'estimated_diameter_max': 29.7879062798},
#      'miles': {'estimated_diameter_min': 0.008277629,
#       'estimated_diameter_max': 0.0185093411},
#      'feet': {'estimated_diameter_min': 43.7058959846,
#       'estimated_diameter_max': 97.7293544391}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-07',
#       'close_approach_date_full': '2018-Aug-07 01:06',
#       'epoch_date_close_approach': 1533603960000,
#       'relative_velocity': {'kilometers_per_second': '6.8288018133',
#        'kilometers_per_hour': '24583.6865278524',
#        'miles_per_hour': '15275.3467761536'},
#       'miss_distance': {'astronomical': '0.0192272157',
#        'lunar': '7.4793869073',
#        'kilometers': '2876350.514750559',
#        'miles': '1787281.3325293542'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3826681?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3826681',
#     'neo_reference_id': '3826681',
#     'name': '(2018 PN10)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3826681',
#     'absolute_magnitude_h': 25.7,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0192555078,
#       'estimated_diameter_max': 0.0430566244},
#      'meters': {'estimated_diameter_min': 19.2555078188,
#       'estimated_diameter_max': 43.0566244241},
#      'miles': {'estimated_diameter_min': 0.0119648141,
#       'estimated_diameter_max': 0.0267541378},
#      'feet': {'estimated_diameter_min': 63.1742402722,
#       'estimated_diameter_max': 141.2618956756}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-07',
#       'close_approach_date_full': '2018-Aug-07 21:09',
#       'epoch_date_close_approach': 1533676140000,
#       'relative_velocity': {'kilometers_per_second': '7.1253621506',
#        'kilometers_per_hour': '25651.3037421528',
#        'miles_per_hour': '15938.7225946726'},
#       'miss_distance': {'astronomical': '0.0839202286',
#        'lunar': '32.6449689254',
#        'kilometers': '12554287.448473082',
#        'miles': '7800872.4892172516'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3826890?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3826890',
#     'neo_reference_id': '3826890',
#     'name': '(2018 QQ)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3826890',
#     'absolute_magnitude_h': 25.5,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0211132445,
#       'estimated_diameter_max': 0.0472106499},
#      'meters': {'estimated_diameter_min': 21.113244479,
#       'estimated_diameter_max': 47.2106498806},
#      'miles': {'estimated_diameter_min': 0.0131191578,
#       'estimated_diameter_max': 0.0293353287},
#      'feet': {'estimated_diameter_min': 69.2691770164,
#       'estimated_diameter_max': 154.8905885541}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-07',
#       'close_approach_date_full': '2018-Aug-07 23:25',
#       'epoch_date_close_approach': 1533684300000,
#       'relative_velocity': {'kilometers_per_second': '4.7389172448',
#        'kilometers_per_hour': '17060.1020811842',
#        'miles_per_hour': '10600.4839848336'},
#       'miss_distance': {'astronomical': '0.0390203273',
#        'lunar': '15.1789073197',
#        'kilometers': '5837357.850782851',
#        'miles': '3627165.9745553038'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2376788?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '2376788',
#     'neo_reference_id': '2376788',
#     'name': '376788 (2000 RV37)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2376788',
#     'absolute_magnitude_h': 19.4,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3503926411,
#       'estimated_diameter_max': 0.7835017643},
#      'meters': {'estimated_diameter_min': 350.3926411083,
#       'estimated_diameter_max': 783.5017643338},
#      'miles': {'estimated_diameter_min': 0.2177238258,
#       'estimated_diameter_max': 0.4868452748},
#      'feet': {'estimated_diameter_min': 1149.5821926537,
#       'estimated_diameter_max': 2570.543928497}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-07',
#       'close_approach_date_full': '2018-Aug-07 05:53',
#       'epoch_date_close_approach': 1533621180000,
#       'relative_velocity': {'kilometers_per_second': '12.3925036678',
#        'kilometers_per_hour': '44613.0132041142',
#        'miles_per_hour': '27720.7914545231'},
#       'miss_distance': {'astronomical': '0.3301343383',
#        'lunar': '128.4222575987',
#        'kilometers': '49387393.823539421',
#        'miles': '30687903.5049531698'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2388189?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '2388189',
#     'neo_reference_id': '2388189',
#     'name': '388189 (2006 DS14)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2388189',
#     'absolute_magnitude_h': 20.5,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2111324448,
#       'estimated_diameter_max': 0.4721064988},
#      'meters': {'estimated_diameter_min': 211.1324447897,
#       'estimated_diameter_max': 472.1064988055},
#      'miles': {'estimated_diameter_min': 0.1311915784,
#       'estimated_diameter_max': 0.2933532873},
#      'feet': {'estimated_diameter_min': 692.6917701639,
#       'estimated_diameter_max': 1548.9058855411}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-07',
# ...
#      'meters': {'estimated_diameter_min': 48.3676488219,
#       'estimated_diameter_max': 108.1533506775},
#      'miles': {'estimated_diameter_min': 0.0300542543,
#       'estimated_diameter_max': 0.0672033557},
#      'feet': {'estimated_diameter_min': 158.6865169607,
#       'estimated_diameter_max': 354.8338390368}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-06',
#       'close_approach_date_full': '2018-Aug-06 05:58',
#       'epoch_date_close_approach': 1533535080000,
#       'relative_velocity': {'kilometers_per_second': '19.0164016443',
#        'kilometers_per_hour': '68459.0459193054',
#        'miles_per_hour': '42537.7888380262'},
#       'miss_distance': {'astronomical': '0.1246000536',
#        'lunar': '48.4694208504',
#        'kilometers': '18639902.620445832',
#        'miles': '11582298.4100312016'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3698848?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3698848',
#     'neo_reference_id': '3698848',
#     'name': '(2014 WW202)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3698848',
#     'absolute_magnitude_h': 24.4,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0350392641,
#       'estimated_diameter_max': 0.0783501764},
#      'meters': {'estimated_diameter_min': 35.0392641108,
#       'estimated_diameter_max': 78.3501764334},
#      'miles': {'estimated_diameter_min': 0.0217723826,
#       'estimated_diameter_max': 0.0486845275},
#      'feet': {'estimated_diameter_min': 114.9582192654,
#       'estimated_diameter_max': 257.0543928497}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-06',
#       'close_approach_date_full': '2018-Aug-06 23:39',
#       'epoch_date_close_approach': 1533598740000,
#       'relative_velocity': {'kilometers_per_second': '15.3064346587',
#        'kilometers_per_hour': '55103.1647712725',
#        'miles_per_hour': '34238.9636880165'},
#       'miss_distance': {'astronomical': '0.2974929093',
#        'lunar': '115.7247417177',
#        'kilometers': '44504305.571383191',
#        'miles': '27653693.1632663958'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3797902?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3797902',
#     'neo_reference_id': '3797902',
#     'name': '(2018 BF5)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3797902',
#     'absolute_magnitude_h': 24.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0384197891,
#       'estimated_diameter_max': 0.0859092601},
#      'meters': {'estimated_diameter_min': 38.4197891064,
#       'estimated_diameter_max': 85.9092601232},
#      'miles': {'estimated_diameter_min': 0.0238729428,
#       'estimated_diameter_max': 0.0533815229},
#      'feet': {'estimated_diameter_min': 126.0491808919,
#       'estimated_diameter_max': 281.8545369825}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-06',
#       'close_approach_date_full': '2018-Aug-06 21:25',
#       'epoch_date_close_approach': 1533590700000,
#       'relative_velocity': {'kilometers_per_second': '10.4109348807',
#        'kilometers_per_hour': '37479.365570691',
#        'miles_per_hour': '23288.2202347441'},
#       'miss_distance': {'astronomical': '0.173438615',
#        'lunar': '67.467621235',
#        'kilometers': '25946047.37975005',
#        'miles': '16122126.24884869'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3560079?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3560079',
#     'neo_reference_id': '3560079',
#     'name': '(2011 FQ6)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3560079',
#     'absolute_magnitude_h': 27.7,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0076657557,
#       'estimated_diameter_max': 0.0171411509},
#      'meters': {'estimated_diameter_min': 7.6657557353,
#       'estimated_diameter_max': 17.1411509231},
#      'miles': {'estimated_diameter_min': 0.0047632783,
#       'estimated_diameter_max': 0.0106510141},
#      'feet': {'estimated_diameter_min': 25.1501180466,
#       'estimated_diameter_max': 56.2373735944}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-06',
#       'close_approach_date_full': '2018-Aug-06 02:16',
#       'epoch_date_close_approach': 1533521760000,
#       'relative_velocity': {'kilometers_per_second': '12.2792205275',
#        'kilometers_per_hour': '44205.1938989014',
#        'miles_per_hour': '27467.3883979035'},
#       'miss_distance': {'astronomical': '0.0937647698',
#        'lunar': '36.4744954522',
#        'kilometers': '14027009.843120326',
#        'miles': '8715979.7511634588'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3797858?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3797858',
#     'neo_reference_id': '3797858',
#     'name': '(2018 BH3)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3797858',
#     'absolute_magnitude_h': 25.4,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.022108281,
#       'estimated_diameter_max': 0.0494356193},
#      'meters': {'estimated_diameter_min': 22.1082810359,
#       'estimated_diameter_max': 49.435619262},
#      'miles': {'estimated_diameter_min': 0.0137374447,
#       'estimated_diameter_max': 0.0307178602},
#      'feet': {'estimated_diameter_min': 72.5337327539,
#       'estimated_diameter_max': 162.1903570994}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-06',
#       'close_approach_date_full': '2018-Aug-06 22:42',
#       'epoch_date_close_approach': 1533595320000,
#       'relative_velocity': {'kilometers_per_second': '14.0934003458',
#        'kilometers_per_hour': '50736.2412448987',
#        'miles_per_hour': '31525.5272335317'},
#       'miss_distance': {'astronomical': '0.4123252139',
#        'lunar': '160.3945082071',
#        'kilometers': '61682973.746734393',
#        'miles': '38328022.5921969034'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3826670?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3826670',
#     'neo_reference_id': '3826670',
#     'name': '(2018 PF9)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3826670',
#     'absolute_magnitude_h': 25.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0242412481,
#       'estimated_diameter_max': 0.0542050786},
#      'meters': {'estimated_diameter_min': 24.2412481101,
#       'estimated_diameter_max': 54.2050786336},
#      'miles': {'estimated_diameter_min': 0.0150628086,
#       'estimated_diameter_max': 0.0336814639},
#      'feet': {'estimated_diameter_min': 79.5316564495,
#       'estimated_diameter_max': 177.8381901842}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-06',
#       'close_approach_date_full': '2018-Aug-06 08:05',
#       'epoch_date_close_approach': 1533542700000,
#       'relative_velocity': {'kilometers_per_second': '5.2247484039',
#        'kilometers_per_hour': '18809.0942539904',
#        'miles_per_hour': '11687.2397046531'},
#       'miss_distance': {'astronomical': '0.1140576748',
#        'lunar': '44.3684354972',
#        'kilometers': '17062785.207232676',
#        'miles': '10602323.0915198888'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3825828?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3825828',
#     'neo_reference_id': '3825828',
#     'name': '(2018 OZ)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3825828',
#     'absolute_magnitude_h': 24.9,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0278326768,
#       'estimated_diameter_max': 0.0622357573},
#      'meters': {'estimated_diameter_min': 27.8326768072,
#       'estimated_diameter_max': 62.2357573367},
#      'miles': {'estimated_diameter_min': 0.0172944182,
#       'estimated_diameter_max': 0.0386714948},
#      'feet': {'estimated_diameter_min': 91.3145593761,
#       'estimated_diameter_max': 204.1855621004}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-06',
#       'close_approach_date_full': '2018-Aug-06 12:02',
#       'epoch_date_close_approach': 1533556920000,
#       'relative_velocity': {'kilometers_per_second': '9.6180494194',
#        'kilometers_per_hour': '34624.9779099304',
#        'miles_per_hour': '21514.614746312'},
#       'miss_distance': {'astronomical': '0.0179033044',
#        'lunar': '6.9643854116',
#        'kilometers': '2678296.204201628',
#        'miles': '1664216.0905653464'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3826711?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3826711',
#     'neo_reference_id': '3826711',
#     'name': '(2018 PC20)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3826711',
#     'absolute_magnitude_h': 25.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0242412481,
#       'estimated_diameter_max': 0.0542050786},
#      'meters': {'estimated_diameter_min': 24.2412481101,
#       'estimated_diameter_max': 54.2050786336},
#      'miles': {'estimated_diameter_min': 0.0150628086,
#       'estimated_diameter_max': 0.0336814639},
#      'feet': {'estimated_diameter_min': 79.5316564495,
#       'estimated_diameter_max': 177.8381901842}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-06',
#       'close_approach_date_full': '2018-Aug-06 20:57',
#       'epoch_date_close_approach': 1533589020000,
#       'relative_velocity': {'kilometers_per_second': '8.038387156',
#        'kilometers_per_hour': '28938.1937615159',
#        'miles_per_hour': '17981.0682292041'},
#       'miss_distance': {'astronomical': '0.0285919033',
#        'lunar': '11.1222503837',
#        'kilometers': '4277287.832925971',
#        'miles': '2657783.4163255598'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3826799?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3826799',
#     'neo_reference_id': '3826799',
#     'name': '(2018 PY21)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3826799',
#     'absolute_magnitude_h': 23.3,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.058150704,
#       'estimated_diameter_max': 0.130028927},
#      'meters': {'estimated_diameter_min': 58.1507039646,
#       'estimated_diameter_max': 130.0289270043},
#      'miles': {'estimated_diameter_min': 0.0361331611,
#       'estimated_diameter_max': 0.0807962044},
#      'feet': {'estimated_diameter_min': 190.7831555951,
#       'estimated_diameter_max': 426.6041048727}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-06',
#       'close_approach_date_full': '2018-Aug-06 06:03',
#       'epoch_date_close_approach': 1533535380000,
#       'relative_velocity': {'kilometers_per_second': '4.0761396961',
#        'kilometers_per_hour': '14674.1029059961',
#        'miles_per_hour': '9117.9168862285'},
#       'miss_distance': {'astronomical': '0.2855005647',
#        'lunar': '111.0597196683',
#        'kilometers': '42710276.362917189',
#        'miles': '26538935.1051436482'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3826619?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3826619',
#     'neo_reference_id': '3826619',
#     'name': '(2018 PR7)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3826619',
#     'absolute_magnitude_h': 28.5,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0053034072,
#       'estimated_diameter_max': 0.0118587791},
#      'meters': {'estimated_diameter_min': 5.3034072332,
#       'estimated_diameter_max': 11.8587790858},
#      'miles': {'estimated_diameter_min': 0.0032953835,
#       'estimated_diameter_max': 0.0073687014},
#      'feet': {'estimated_diameter_min': 17.3996305869,
#       'estimated_diameter_max': 38.9067567758}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-06',
#       'close_approach_date_full': '2018-Aug-06 01:59',
#       'epoch_date_close_approach': 1533520740000,
#       'relative_velocity': {'kilometers_per_second': '4.3476465023',
#        'kilometers_per_hour': '15651.5274082176',
#        'miles_per_hour': '9725.2504609561'},
#       'miss_distance': {'astronomical': '0.0034834463',
#        'lunar': '1.3550606107',
#        'kilometers': '521116.146739381',
#        'miles': '323806.5584742178'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3283950?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3283950',
#     'neo_reference_id': '3283950',
#     'name': '(2005 NJ63)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3283950',
#     'absolute_magnitude_h': 21.0,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1677084622,
#       'estimated_diameter_max': 0.3750075218},
#      'meters': {'estimated_diameter_min': 167.7084621628,
#       'estimated_diameter_max': 375.0075217981},
#      'miles': {'estimated_diameter_min': 0.1042091748,
#       'estimated_diameter_max': 0.2330187988},
#      'feet': {'estimated_diameter_min': 550.2246310023,
#       'estimated_diameter_max': 1230.3396778159}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-06',
#       'close_approach_date_full': '2018-Aug-06 06:56',
#       'epoch_date_close_approach': 1533538560000,
#       'relative_velocity': {'kilometers_per_second': '14.5605563104',
#        'kilometers_per_hour': '52418.0027172686',
#        'miles_per_hour': '32570.5084106273'},
#       'miss_distance': {'astronomical': '0.2391647332',
#        'lunar': '93.0350812148',
#        'kilometers': '35778534.665838284',
#        'miles': '22231750.5413809592'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3826546?api_key=XSshU09cDCSJjfAxllHTTsjs8gFnhXZXD9GsOPE4'},
#     'id': '3826546',
#     'neo_reference_id': '3826546',
#     'name': '(2018 PC)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3826546',
#     'absolute_magnitude_h': 23.9,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.04411182,
#       'estimated_diameter_max': 0.0986370281},
#      'meters': {'estimated_diameter_min': 44.1118199997,
#       'estimated_diameter_max': 98.6370281305},
#      'miles': {'estimated_diameter_min': 0.0274098057,
#       'estimated_diameter_max': 0.0612901888},
#      'feet': {'estimated_diameter_min': 144.7238235278,
#       'estimated_diameter_max': 323.6123073718}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2018-08-06',
#       'close_approach_date_full': '2018-Aug-06 13:43',
#       'epoch_date_close_approach': 1533562980000,
#       'relative_velocity': {'kilometers_per_second': '9.2977874799',
#        'kilometers_per_hour': '33472.0349276306',
#        'miles_per_hour': '20798.2208137824'},
#       'miss_distance': {'astronomical': '0.0309474103',
#        'lunar': '12.0385426067',
#        'kilometers': '4629666.662896061',
#        'miles': '2876741.4680492018'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}]}}

# %% [markdown]
# # Earth Imagery (landsat8)

# %% [raw]
# HTTP REQUEST
#
# GET https://api.data.gov/nasa/planetary/earth/imagery
#
# QUERY PARAMETERS
# Parameter	Type	    Default	    Description
# lat	        float	    n/a	        Latitude
# lon	        float	    n/a	        Longitude
# dim	        float	    0.025	    width and height of image in degrees
# cloud_score	bool	    False	    calculate the percentage of the image covered by clouds
# api_key	    string	    DEMO_KEY	api.data.gov key for expanded usage
# date	    YYYY-MM-DD	today	    date of image; if not supplied, then the most recent image (i.e., closest to today) is returned
#
# EXAMPLE QUERY
#
# https://api.data.gov/nasa/planetary/earth/imagery?lon=100.75&lat=1.5&date=2014-02-01&cloud_score=True&api_key=DEMO_KEY

# %%
def landsat8(lat, lon, dim, cloud_score, target_date):
    """
    Imagery
    This endpoint retrieves the Landsat 8 image for the supplied location and date. The response will include the date and URL to the image that is closest to the supplied date. The requested resource may not be available for the exact date in the request. You can retrieve a list of available resources through the assets endpoint.
    The cloud score is an optional calculation that returns the percentage of the queried image that is covered by clouds. If False is supplied to the cloud_score parameter, then no keypair is returned. If True is supplied, then a keypair will always be returned, even if the backend algorithm is not able to calculate a score. Note that this is a rough calculation, mainly used to filter out exceedingly cloudy images.
    QUERY PARAMETERS
    Parameter	Type	    Default	    Description
    lat	        float	    n/a	        Latitude
    lon	        float	    n/a	        Longitude
    dim	        float	    0.025	    width and height of image in degrees
    cloud_score	bool	    False	    calculate the percentage of the image covered by clouds
    api_key	    string	    DEMO_KEY	api.data.gov key for expanded usage
    date	    YYYY-MM-DD	today	    date of image; if not supplied, then the most recent image (i.e., closest to today) is returned
    landsat8('34.183578', '-118.9491215', '0.07', 'True', '2014-07-31')
    x=geocode('700 Pennsylvania Avenue NW DC')
    landsat8(x[0], x[1], '0.07', 'True', '2014-07-31')
    """
    request='https://api.data.gov/nasa/planetary/earth/imagery'
    key=''
    form={'lat': str(lat), 'lon': str(lon), 'dim': dim, 'cloud_score': cloud_score, 'date': target_date, 'api_key': key}
    query=urllib.urlencode(form)
    landsat8_request_string=urllib.urlopen(request+"?"+query)
    print(landsat8_request_string.info())
    response=json.loads(landsat8_request_string.read())
    print('date: ' + response['date'])
    print('cloud score: ' + str(response['cloud_score']))
    print('Planet: ' + response['resource']['planet'])
    print('Data Set: ' + response['resource']['dataset'])
    print('ID: ' + str(response['id']))
    print('URL: ' + str(response['url']))
    fname=str('landsat8'+'_'+target_date+'.png')
    landsat8_img=urllib.urlretrieve(response['url'], fname)
    im=img.open(fname)
    display=plt.imread(fname)
    plt.imshow(display)
    PIL_format=PIL.Image.open(fname)
    return response

# %%
x=geocode('700 Pennsylvania Avenue NW DC')
# Out:
# Content-Type: application/json; charset=UTF-8
# Date: Sun, 12 Apr 2015 20:04:38 GMT
# Expires: Mon, 13 Apr 2015 20:04:38 GMT
# Cache-Control: public, max-age=86400
# Access-Control-Allow-Origin: *
# Server: mafe
# X-XSS-Protection: 1; mode=block
# X-Frame-Options: SAMEORIGIN
# Alternate-Protocol: 443:quic,p=0.5
# Accept-Ranges: none
# Vary: Accept-Language,Accept-Encoding
#
# Address: 700 Pennsylvania Avenue Northwest, Washington, DC 20408, USA
# {u'lat': 38.892319, u'lng': -77.022893}

# %%
landsat8(x[0], x[1], '0.025', 'True', '2014-07-31')
# Out:
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=0.5
# cache-control: no-cache
# Content-Type: application/json
# Date: Sun, 12 Apr 2015 20:04:49 GMT
# Server: nginx
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 969
# x-varnish: 450834
# Content-Length: 304
# Connection: Close
#
# date: 2014-07-29T15:46:23
# cloud score: 0.106131879123
# Planet: earth
# Data Set: LC8_L1T_TOA
# ID: LC8_L1T_TOA/LC80150332014210LGN00
# URL: https://earthengine.googleapis.com/api/thumb?thumbid=23b8a7684ad4c7d10bc8eebb4b0b2311&token=0f1e699bc235b6a99e99db17ee49c577
# {u'cloud_score': 0.10613187912310454,
#  u'date': u'2014-07-29T15:46:23',
#  u'id': u'LC8_L1T_TOA/LC80150332014210LGN00',
#  u'resource': {u'dataset': u'LC8_L1T_TOA', u'planet': u'earth'},
#  u'url': u'https://earthengine.googleapis.com/api/thumb?thumbid=23b8a7684ad4c7d10bc8eebb4b0b2311&token=0f1e699bc235b6a99e99db17ee49c577'}

# %% [markdown]
# # Assets

# %% [raw]
# HTTP REQUEST
#
# GET https://api.data.gov/nasa/planetary/earth/assets
#
# QUERY PARAMETERS
#
# Parameter	Type	    Default	    Description
# lat	        float	    n/a	        Latitude
# lon	        float	    n/a	        Longitude
# begin	    YYYY-MM-DD	n/a	        beginning of date range
# end	        YYYY-MM-DD	today	    end of date range
# api_key	    string	    DEMO_KEY	api.data.gov key for expanded usage
#
# EXAMPLE QUERY
#
# https://api.data.gov/nasa/planetary/earth/assets?lon=100.75&lat=1.5&begin=2014-02-01&api_key=DEMO_KEY

# %%
def Assets(lat, lon, begin, end):
    """
    Hey, Charlie, when was the last time a NASA image was taken of my house? This endpoint retrieves the date-times and asset names for available imagery for a supplied location. The satellite passes over each point on earth roughly once every sixteen days. This is an amazing visualization of the acquisition pattern for Landsat 8 imagery. The objective of this endpoint is primarily to support the use of the imagery endpoint.
    GET https://api.data.gov/nasa/planetary/earth/assets

    QUERY PARAMETERS

    Parameter	Type	    Default	    Description
    lat	        float	    n/a	        Latitude
    lon	        float	    n/a	        Longitude
    begin	    YYYY-MM-DD	n/a	        beginning of date range
    end	        YYYY-MM-DD	today	    end of date range
    api_key	    string	    DEMO_KEY	api.data.gov key for expanded usage

    EXAMPLE QUERY

    https://api.data.gov/nasa/planetary/earth/assets?lon=100.75&lat=1.5&begin=2014-02-01&api_key=DEMO_KEY
    """
    request='https://api.data.gov/nasa/planetary/earth/assets'
    key=''
    form={'lat': str(lat), 'lon': str(lon), 'begin': begin, 'end': end, 'api_key': key}
    query=urllib.urlencode(form)
    landsat8_request_string=urllib.urlopen(request+"?"+query)
    print(landsat8_request_string.info())
    response=json.loads(landsat8_request_string.read())
    #print(response.keys())
    #print(response.values())
    print('From: '+ begin)
    print('To: ' + end)
    print('Number of Satellite passes: ' + str(response['count']))
    print('Planet: ' + response['resource']['planet'])
    print('Data Set: ' + response['resource']['dataset'])
    for item in response['results']:
        print('date: ' + item['date'])
        print('id: ' + item['id'])
    return response

# %%
Assets(x[0],x[1],'2014-07-31', '2015-01-01')
# Out:
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=0.5
# cache-control: no-cache
# Content-Type: application/json
# Date: Sun, 12 Apr 2015 20:05:17 GMT
# Server: nginx
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 971
# x-varnish: 450857
# Content-Length: 616
# Connection: Close
#
# From: 2014-07-31
# To: 2015-01-01
# Number of Satellite passes: 7
# Planet: earth
# Data Set: LC8_L1T_TOA
# date: 2014-08-14T15:46:30
# id: LC8_L1T_TOA/LC80150332014226LGN00
# date: 2014-09-15T15:46:35
# id: LC8_L1T_TOA/LC80150332014258LGN00
# date: 2014-10-01T15:46:36
# id: LC8_L1T_TOA/LC80150332014274LGN00
# date: 2014-10-17T15:46:41
# id: LC8_L1T_TOA/LC80150332014290LGN00
# date: 2014-11-02T15:46:38
# id: LC8_L1T_TOA/LC80150332014306LGN00
# date: 2014-11-18T15:46:37
# id: LC8_L1T_TOA/LC80150332014322LGN00
# date: 2014-12-04T15:46:37
# id: LC8_L1T_TOA/LC80150332014338LGN00
# {u'count': 7,
#  u'resource': {u'dataset': u'LC8_L1T_TOA', u'planet': u'earth'},
#  u'results': [{u'date': u'2014-08-14T15:46:30',
#    u'id': u'LC8_L1T_TOA/LC80150332014226LGN00'},
#   {u'date': u'2014-09-15T15:46:35',
#    u'id': u'LC8_L1T_TOA/LC80150332014258LGN00'},
#   {u'date': u'2014-10-01T15:46:36',
#    u'id': u'LC8_L1T_TOA/LC80150332014274LGN00'},
#   {u'date': u'2014-10-17T15:46:41',
#    u'id': u'LC8_L1T_TOA/LC80150332014290LGN00'},
#   {u'date': u'2014-11-02T15:46:38',
#    u'id': u'LC8_L1T_TOA/LC80150332014306LGN00'},
#   {u'date': u'2014-11-18T15:46:37',
#    u'id': u'LC8_L1T_TOA/LC80150332014322LGN00'},
#   {u'date': u'2014-12-04T15:46:37',
#    u'id': u'LC8_L1T_TOA/LC80150332014338LGN00'}]}

# %% [markdown]
# # Earth temperature anomalies

# %% [raw]
# Address
# The location can be specified as an address string.
#
# HTTP REQUEST
#
# GET https://api.data.gov/nasa/planetary/earth/temperature/address
#
# QUERY PARAMETERS
#
# Parameter	Type	Default	    Description
# text        string	n/a	        Address string
# begin	    int	    1880	    beginning year for date range, inclusive
# end	        int	    2014	    end year for date range, inclusive
# api_key	    string	DEMO_KEY	api.data.gov key for expanded usage
#
# EXAMPLE QUERY
#
# https://api.data.gov/nasa/planetary/earth/temperature/address?text=1800 F Street, NW, Washington DC&begin=1990

# %%
 def temperature_anomolies_address(begin, end, text):
    """
    There is no doubt that, on average, the earth is warming. However, the warming is spatially heterogenous. How much warmer (or cooler) is your hometown? This endpoint reports local temperature anomalies from the Goddard Institute for Space Studies Surface Temperature Analysis via the New Scientist web application to explore global temperature anomalies. This endpoint restructures the query and response to correspond to other APIs on api.nasa.gov. The developer supplies a location and date range, and the returned object is a list of dictionaries that is ready for visualization in the d3 framework.
    Address
    The location can be specified as an address string.

    HTTP REQUEST

    GET https://api.data.gov/nasa/planetary/earth/temperature/address

    QUERY PARAMETERS

    Parameter	Type	Default	    Description
    text        string	n/a	        Address string
    begin	    int	    1880	    beginning year for date range, inclusive
    end	        int	    2014	    end year for date range, inclusive
    api_key	    string	DEMO_KEY	api.data.gov key for expanded usage

    EXAMPLE QUERY

    https://api.data.gov/nasa/planetary/earth/temperature/address?text=1800 F Street, NW, Washington DC&begin=1990
    
    temperature_anomolies_address('1880', '2015', '20110')
    """
    request='https://api.data.gov/nasa/planetary/earth/temperature/address'
    key=''
    form={'begin':  str(begin), 'end': str(end), 'text': text, 'api_key': key}
    query=urllib.urlencode(form)
    temp_address_request_string=urllib.urlopen(request+"?"+query)
    print(temp_address_request_string.info())
    response=json.loads(temp_address_request_string.read())
    #print(response.keys())
    #print(response.values())
    return response

# %%
temperature_anomolies_address('1880', '2015', '20110')
# Out:
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=0.5
# cache-control: no-cache
# Content-Type: application/json
# Date: Sun, 12 Apr 2015 20:47:50 GMT
# Server: nginx
# vary: Accept-Encoding
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 964
# x-varnish: 1147234
# Content-Length: 6282
# Connection: Close
# {u'count': 135,
#  u'results': [{u'anomaly': 0.118000001, u'year': 1880},
#   {u'anomaly': 0.224299997, u'year': 1881},
#   {u'anomaly': -0.202199996, u'year': 1882},
#   {u'anomaly': -1.28550005, u'year': 1883},
#   {u'anomaly': -0.547999978, u'year': 1884},
#   {u'anomaly': -1.755200028, u'year': 1885},
#   {u'anomaly': -0.993799984, u'year': 1886},
#   {u'anomaly': -0.687099993, u'year': 1887},
#   {u'anomaly': -1.314599991, u'year': 1888},
#   {u'anomaly': -0.0339, u'year': 1889},
#   {u'anomaly': -0.0581, u'year': 1890},
#   {u'anomaly': 0.088100001, u'year': 1891},
#   {u'anomaly': -0.559099972, u'year': 1892},
#   {u'anomaly': -0.828299999, u'year': 1893},
#   {u'anomaly': 0.468600005, u'year': 1894},
#   {u'anomaly': -0.586199999, u'year': 1895},
#   {u'anomaly': 0.121100001, u'year': 1896},
#   {u'anomaly': 0.071800001, u'year': 1897},
#   {u'anomaly': 0.530499995, u'year': 1898},
#   {u'anomaly': 0.0166, u'year': 1899},
#   {u'anomaly': 0.603100002, u'year': 1900},
#   {u'anomaly': -0.49180001, u'year': 1901},
#   {u'anomaly': -0.096199997, u'year': 1902},
#   {u'anomaly': -0.280600011, u'year': 1903},
#   {u'anomaly': -1.401600003, u'year': 1904},
#   {u'anomaly': -0.506900012, u'year': 1905},
#   {u'anomaly': 0.237100005, u'year': 1906},
#   {u'anomaly': -0.726000011, u'year': 1907},
#   {u'anomaly': 0.300300002, u'year': 1908},
#   {u'anomaly': -0.059500001, u'year': 1909},
#   {u'anomaly': -0.213100001, u'year': 1910},
#   {u'anomaly': 0.616100013, u'year': 1911},
#   {u'anomaly': -0.601000011, u'year': 1912},
#   {u'anomaly': 0.821399987, u'year': 1913},
#   {u'anomaly': -0.386299998, u'year': 1914},
#   {u'anomaly': 0.021199999, u'year': 1915},
#   {u'anomaly': -0.194600001, u'year': 1916},
#   {u'anomaly': -1.539000034, u'year': 1917},
#   {u'anomaly': -0.132200003, u'year': 1918},
#   {u'anomaly': 0.480800003, u'year': 1919},
#   {u'anomaly': -0.528500021, u'year': 1920},
#   {u'anomaly': 1.442299962, u'year': 1921},
#   {u'anomaly': 0.543099999, u'year': 1922},
#   {u'anomaly': -0.103100002, u'year': 1923},
#   {u'anomaly': -0.906599998, u'year': 1924},
#   {u'anomaly': 0.138099998, u'year': 1925},
#   {u'anomaly': -0.819400012, u'year': 1926},
#   {u'anomaly': 0.331800014, u'year': 1927},
#   {u'anomaly': -0.125200003, u'year': 1928},
#   {u'anomaly': -0.115099996, u'year': 1929},
#   {u'anomaly': 0.416799992, u'year': 1930},
#   {u'anomaly': 1.245399952, u'year': 1931},
#   {u'anomaly': 0.683200002, u'year': 1932},
#   {u'anomaly': 0.742600024, u'year': 1933},
#   {u'anomaly': -0.0266, u'year': 1934},
#   {u'anomaly': -0.197600007, u'year': 1935},
#   {u'anomaly': -0.023499999, u'year': 1936},
#   {u'anomaly': 0.178599998, u'year': 1937},
#   {u'anomaly': 0.819000006, u'year': 1938},
#   {u'anomaly': 0.505299985, u'year': 1939},
#   {u'anomaly': -0.915499985, u'year': 1940},
#   {u'anomaly': 0.5546, u'year': 1941},
#   {u'anomaly': 0.278699994, u'year': 1942},
#   {u'anomaly': -0.210999995, u'year': 1943},
#   {u'anomaly': 0.272399992, u'year': 1944},
#   {u'anomaly': 0.163499996, u'year': 1945},
#   {u'anomaly': 0.829900026, u'year': 1946},
#   {u'anomaly': -0.0117, u'year': 1947},
#   {u'anomaly': 0.203199998, u'year': 1948},
#   {u'anomaly': 1.284199953, u'year': 1949},
#   {u'anomaly': -0.127399996, u'year': 1950},
#   {u'anomaly': 0.231700003, u'year': 1951},
#   {u'anomaly': 0.729900002, u'year': 1952},
#   {u'anomaly': 1.250800014, u'year': 1953},
#   {u'anomaly': 0.516600013, u'year': 1954},
#   {u'anomaly': 0.458099991, u'year': 1955},
#   {u'anomaly': 0.071000002, u'year': 1956},
#   {u'anomaly': 0.498800009, u'year': 1957},
#   {u'anomaly': -0.765600026, u'year': 1958},
#   {u'anomaly': 0.550899982, u'year': 1959},
#   {u'anomaly': -0.320600003, u'year': 1960},
#   {u'anomaly': 0.015, u'year': 1961},
#   {u'anomaly': -0.452699989, u'year': 1962},
#   {u'anomaly': -0.675400019, u'year': 1963},
#   {u'anomaly': 0.158600003, u'year': 1964},
#   {u'anomaly': -0.146599993, u'year': 1965},
#   {u'anomaly': -0.387400001, u'year': 1966},
#   {u'anomaly': -0.506900012, u'year': 1967},
#   {u'anomaly': -0.296299994, u'year': 1968},
#   {u'anomaly': -0.320499986, u'year': 1969},
#   {u'anomaly': -0.032400001, u'year': 1970},
#   {u'anomaly': 0.139699996, u'year': 1971},
#   {u'anomaly': -0.451200008, u'year': 1972},
#   {u'anomaly': 0.850600004, u'year': 1973},
#   {u'anomaly': 0.116300002, u'year': 1974},
#   {u'anomaly': 0.540600002, u'year': 1975},
#   {u'anomaly': -0.57099998, u'year': 1976},
#   {u'anomaly': 0.063600004, u'year': 1977},
#   {u'anomaly': -0.738200009, u'year': 1978},
#   {u'anomaly': -0.250699997, u'year': 1979},
#   {u'anomaly': -0.276899993, u'year': 1980},
#   {u'anomaly': -0.173800007, u'year': 1981},
#   {u'anomaly': -0.0206, u'year': 1982},
#   {u'anomaly': 0.268099993, u'year': 1983},
#   {u'anomaly': 0.247600004, u'year': 1984},
#   {u'anomaly': 0.231399998, u'year': 1985},
#   {u'anomaly': 0.501399994, u'year': 1986},
#   {u'anomaly': 0.609300017, u'year': 1987},
#   {u'anomaly': -0.0024, u'year': 1988},
#   {u'anomaly': -0.278800011, u'year': 1989},
#   {u'anomaly': 1.434200048, u'year': 1990},
#   {u'anomaly': 1.337499976, u'year': 1991},
#   {u'anomaly': -0.193000004, u'year': 1992},
#   {u'anomaly': 0.091600001, u'year': 1993},
#   {u'anomaly': 0.200299993, u'year': 1994},
#   {u'anomaly': 0.2579, u'year': 1995},
#   {u'anomaly': -0.253800005, u'year': 1996},
#   {u'anomaly': -0.077399999, u'year': 1997},
#   {u'anomaly': 1.819200039, u'year': 1998},
#   {u'anomaly': 1.122699976, u'year': 1999},
#   {u'anomaly': 0.208900005, u'year': 2000},
#   {u'anomaly': 0.987200022, u'year': 2001},
#   {u'anomaly': 1.139000058, u'year': 2002},
#   {u'anomaly': 0.016000001, u'year': 2003},
#   {u'anomaly': 0.529299974, u'year': 2004},
#   {u'anomaly': 0.773599982, u'year': 2005},
#   {u'anomaly': 1.331099987, u'year': 2006},
#   {u'anomaly': 0.958999991, u'year': 2007},
#   {u'anomaly': 0.470400006, u'year': 2008},
#   {u'anomaly': 0.209800005, u'year': 2009},
#   {u'anomaly': 0.966000021, u'year': 2010},
#   {u'anomaly': 1.236700058, u'year': 2011},
#   {u'anomaly': 1.936300039, u'year': 2012},
#   {u'anomaly': 0.373100013, u'year': 2013},
#   {u'anomaly': -0.219600007, u'year': 2014}]}

# %%
def plot_temps(begin, end, text):
    """
    Plot temperature variations to a line chart
    """
    response=temp_data=temperature_anomolies_address(begin, end, text)
    z=response['results']
    x=[]
    y=[]
    for item in z:
        y.append(item['anomaly'])
        x.append(item['year'])
    plt.ylabel('Temp Variation')
    plt.xlabel('Years')
    plt.plot(x,y)

# %%
def plot_temps_points(begin, end, lat, lon):
    """
    Plot temperature variations to a line chart
    """
    response=temp_data=temperature_anomolies_coordinates(begin, end, lat, lon)
    z=response['results']
    x=[]
    y=[]
    for item in z:
        y.append(item['anomaly'])
        x.append(item['year'])
    plt.ylabel('Temp Variation')
    plt.xlabel('Years')
    plt.plot(x,y)

# %%
plot_temps('1880', '2015', '90210')
# Out:
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=0.5
# cache-control: no-cache
# Content-Type: application/json
# Date: Sun, 12 Apr 2015 20:52:32 GMT
# Server: nginx
# vary: Accept-Encoding
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 963
# x-varnish: 421736
# Content-Length: 6314
# Connection: Close

# %%
 def temperature_anomolies_coordinates(begin, end, lat, lon):
    """
    Coordinates
    Alternatively, you can supply the precise latitude and longitude as the location.

    HTTP REQUEST

    GET https://api.data.gov/planetary/earth/temperature/coords

    QUERY PARAMETERS

    Parameter	Type	Default	    Description
    lat	        float	n/a	        Latitude
    lon	        float	n/a	        Longitude
    begin	    int	    1880	    beginning year for date range, inclusive
    end	        int	    2014	    end year for date range, inclusive
    api_key	    string	DEMO_KEY	api.data.gov key for expanded usage
    
    EXAMPLE QUERY

    https://api.data.gov/nasa/planetary/earth/temperature/coords?lon=100.3&lat=1.6&begin=1990&end=2005&api_key=DEMO_KEY
    """
    request='https://api.data.gov/nasa/planetary/earth/temperature/coords'
    key=''
    form={'begin':  str(begin), 'end': str(end), 'lat': lat, 'lon': lon, 'api_key': key}
    query=urllib.urlencode(form)
    temp_point_request_string=urllib.urlopen(request+"?"+query)
    print(temp_point_request_string.info())
    response=json.loads(temp_point_request_string.read())
    #print(response.keys())
    #print(response.values())
    return response

# %%
x=geocode('700 Pennsylvania Dr Northwest Wshington DC')
# Out:
# Content-Type: application/json; charset=UTF-8
# Date: Sun, 12 Apr 2015 21:00:22 GMT
# Expires: Mon, 13 Apr 2015 21:00:22 GMT
# Cache-Control: public, max-age=86400
# Access-Control-Allow-Origin: *
# Server: mafe
# X-XSS-Protection: 1; mode=block
# X-Frame-Options: SAMEORIGIN
# Alternate-Protocol: 443:quic,p=0.5
# Accept-Ranges: none
# Vary: Accept-Language,Accept-Encoding
#
# Address: 700 Pennsylvania Avenue Northwest, Washington, DC 20408, USA
# {u'lat': 38.892319, u'lng': -77.022893}

# %%
temperature_anomolies_coordinates('1880','2015',x[0],x[1])
# Out:
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=0.5
# cache-control: no-cache
# Content-Type: application/json
# Date: Sun, 12 Apr 2015 21:01:19 GMT
# Server: nginx
# vary: Accept-Encoding
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 962
# x-varnish: 1068654
# Content-Length: 6282
# Connection: Close
# {u'count': 135,
#  u'results': [{u'anomaly': 0.118000001, u'year': 1880},
#   {u'anomaly': 0.224299997, u'year': 1881},
#   {u'anomaly': -0.202199996, u'year': 1882},
#   {u'anomaly': -1.28550005, u'year': 1883},
#   {u'anomaly': -0.547999978, u'year': 1884},
#   {u'anomaly': -1.755200028, u'year': 1885},
#   {u'anomaly': -0.993799984, u'year': 1886},
#   {u'anomaly': -0.687099993, u'year': 1887},
#   {u'anomaly': -1.314599991, u'year': 1888},
#   {u'anomaly': -0.0339, u'year': 1889},
#   {u'anomaly': -0.0581, u'year': 1890},
#   {u'anomaly': 0.088100001, u'year': 1891},
#   {u'anomaly': -0.559099972, u'year': 1892},
#   {u'anomaly': -0.828299999, u'year': 1893},
#   {u'anomaly': 0.468600005, u'year': 1894},
#   {u'anomaly': -0.586199999, u'year': 1895},
#   {u'anomaly': 0.121100001, u'year': 1896},
#   {u'anomaly': 0.071800001, u'year': 1897},
#   {u'anomaly': 0.530499995, u'year': 1898},
#   {u'anomaly': 0.0166, u'year': 1899},
#   {u'anomaly': 0.603100002, u'year': 1900},
#   {u'anomaly': -0.49180001, u'year': 1901},
#   {u'anomaly': -0.096199997, u'year': 1902},
#   {u'anomaly': -0.280600011, u'year': 1903},
#   {u'anomaly': -1.401600003, u'year': 1904},
#   {u'anomaly': -0.506900012, u'year': 1905},
#   {u'anomaly': 0.237100005, u'year': 1906},
#   {u'anomaly': -0.726000011, u'year': 1907},
#   {u'anomaly': 0.300300002, u'year': 1908},
#   {u'anomaly': -0.059500001, u'year': 1909},
#   {u'anomaly': -0.213100001, u'year': 1910},
#   {u'anomaly': 0.616100013, u'year': 1911},
#   {u'anomaly': -0.601000011, u'year': 1912},
#   {u'anomaly': 0.821399987, u'year': 1913},
#   {u'anomaly': -0.386299998, u'year': 1914},
#   {u'anomaly': 0.021199999, u'year': 1915},
#   {u'anomaly': -0.194600001, u'year': 1916},
#   {u'anomaly': -1.539000034, u'year': 1917},
#   {u'anomaly': -0.132200003, u'year': 1918},
#   {u'anomaly': 0.480800003, u'year': 1919},
#   {u'anomaly': -0.528500021, u'year': 1920},
#   {u'anomaly': 1.442299962, u'year': 1921},
#   {u'anomaly': 0.543099999, u'year': 1922},
#   {u'anomaly': -0.103100002, u'year': 1923},
#   {u'anomaly': -0.906599998, u'year': 1924},
#   {u'anomaly': 0.138099998, u'year': 1925},
#   {u'anomaly': -0.819400012, u'year': 1926},
#   {u'anomaly': 0.331800014, u'year': 1927},
#   {u'anomaly': -0.125200003, u'year': 1928},
#   {u'anomaly': -0.115099996, u'year': 1929},
#   {u'anomaly': 0.416799992, u'year': 1930},
#   {u'anomaly': 1.245399952, u'year': 1931},
#   {u'anomaly': 0.683200002, u'year': 1932},
#   {u'anomaly': 0.742600024, u'year': 1933},
#   {u'anomaly': -0.0266, u'year': 1934},
#   {u'anomaly': -0.197600007, u'year': 1935},
#   {u'anomaly': -0.023499999, u'year': 1936},
#   {u'anomaly': 0.178599998, u'year': 1937},
#   {u'anomaly': 0.819000006, u'year': 1938},
#   {u'anomaly': 0.505299985, u'year': 1939},
#   {u'anomaly': -0.915499985, u'year': 1940},
#   {u'anomaly': 0.5546, u'year': 1941},
#   {u'anomaly': 0.278699994, u'year': 1942},
#   {u'anomaly': -0.210999995, u'year': 1943},
#   {u'anomaly': 0.272399992, u'year': 1944},
#   {u'anomaly': 0.163499996, u'year': 1945},
#   {u'anomaly': 0.829900026, u'year': 1946},
#   {u'anomaly': -0.0117, u'year': 1947},
#   {u'anomaly': 0.203199998, u'year': 1948},
#   {u'anomaly': 1.284199953, u'year': 1949},
#   {u'anomaly': -0.127399996, u'year': 1950},
#   {u'anomaly': 0.231700003, u'year': 1951},
#   {u'anomaly': 0.729900002, u'year': 1952},
#   {u'anomaly': 1.250800014, u'year': 1953},
#   {u'anomaly': 0.516600013, u'year': 1954},
#   {u'anomaly': 0.458099991, u'year': 1955},
#   {u'anomaly': 0.071000002, u'year': 1956},
#   {u'anomaly': 0.498800009, u'year': 1957},
#   {u'anomaly': -0.765600026, u'year': 1958},
#   {u'anomaly': 0.550899982, u'year': 1959},
#   {u'anomaly': -0.320600003, u'year': 1960},
#   {u'anomaly': 0.015, u'year': 1961},
#   {u'anomaly': -0.452699989, u'year': 1962},
#   {u'anomaly': -0.675400019, u'year': 1963},
#   {u'anomaly': 0.158600003, u'year': 1964},
#   {u'anomaly': -0.146599993, u'year': 1965},
#   {u'anomaly': -0.387400001, u'year': 1966},
#   {u'anomaly': -0.506900012, u'year': 1967},
#   {u'anomaly': -0.296299994, u'year': 1968},
#   {u'anomaly': -0.320499986, u'year': 1969},
#   {u'anomaly': -0.032400001, u'year': 1970},
#   {u'anomaly': 0.139699996, u'year': 1971},
#   {u'anomaly': -0.451200008, u'year': 1972},
#   {u'anomaly': 0.850600004, u'year': 1973},
#   {u'anomaly': 0.116300002, u'year': 1974},
#   {u'anomaly': 0.540600002, u'year': 1975},
#   {u'anomaly': -0.57099998, u'year': 1976},
#   {u'anomaly': 0.063600004, u'year': 1977},
#   {u'anomaly': -0.738200009, u'year': 1978},
#   {u'anomaly': -0.250699997, u'year': 1979},
#   {u'anomaly': -0.276899993, u'year': 1980},
#   {u'anomaly': -0.173800007, u'year': 1981},
#   {u'anomaly': -0.0206, u'year': 1982},
#   {u'anomaly': 0.268099993, u'year': 1983},
#   {u'anomaly': 0.247600004, u'year': 1984},
#   {u'anomaly': 0.231399998, u'year': 1985},
#   {u'anomaly': 0.501399994, u'year': 1986},
#   {u'anomaly': 0.609300017, u'year': 1987},
#   {u'anomaly': -0.0024, u'year': 1988},
#   {u'anomaly': -0.278800011, u'year': 1989},
#   {u'anomaly': 1.434200048, u'year': 1990},
#   {u'anomaly': 1.337499976, u'year': 1991},
#   {u'anomaly': -0.193000004, u'year': 1992},
#   {u'anomaly': 0.091600001, u'year': 1993},
#   {u'anomaly': 0.200299993, u'year': 1994},
#   {u'anomaly': 0.2579, u'year': 1995},
#   {u'anomaly': -0.253800005, u'year': 1996},
#   {u'anomaly': -0.077399999, u'year': 1997},
#   {u'anomaly': 1.819200039, u'year': 1998},
#   {u'anomaly': 1.122699976, u'year': 1999},
#   {u'anomaly': 0.208900005, u'year': 2000},
#   {u'anomaly': 0.987200022, u'year': 2001},
#   {u'anomaly': 1.139000058, u'year': 2002},
#   {u'anomaly': 0.016000001, u'year': 2003},
#   {u'anomaly': 0.529299974, u'year': 2004},
#   {u'anomaly': 0.773599982, u'year': 2005},
#   {u'anomaly': 1.331099987, u'year': 2006},
#   {u'anomaly': 0.958999991, u'year': 2007},
#   {u'anomaly': 0.470400006, u'year': 2008},
#   {u'anomaly': 0.209800005, u'year': 2009},
#   {u'anomaly': 0.966000021, u'year': 2010},
#   {u'anomaly': 1.236700058, u'year': 2011},
#   {u'anomaly': 1.936300039, u'year': 2012},
#   {u'anomaly': 0.373100013, u'year': 2013},
#   {u'anomaly': -0.219600007, u'year': 2014}]}

# %%
plot_temps_points('1880','2015',x[0],x[1])
# Out:
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=0.5
# cache-control: no-cache
# Content-Type: application/json
# Date: Sun, 12 Apr 2015 21:05:10 GMT
# Server: nginx
# vary: Accept-Encoding
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 965
# x-varnish: 926313
# Content-Length: 6282
# Connection: Close

# %% [markdown]
# # Patents

# %% [raw]
# The NASA patent portfolio is available to benefit US citizens. Through partnerships and licensing agreements with industry, these patents ensure that NASA’s investments in pioneering research find secondary uses that benefit the economy, create jobs, and improve quality of life. This endpoint provides structured, searchable developer access to NASA’s patents that have been curated to support technology transfer.
#
# HTTP REQUEST
#
# GET https://api.data.gov/nasa/patents
#
# QUERY PARAMETERS
#
# Parameter	    Type	 Default	Description
# query	        string	 None	    Search text to filter results
# concept_tags	bool	 False	    Return an ordered dictionary of concepts from the patent abstract
# limit	        int	     all	    number of patents to return
# api_key	string	DEMO_KEY	        api.data.gov key for expanded usage
#
# EXAMPLE QUERY
#
# https://api.data.gov/nasa/patents/content?query=temperature&limit=5&api_key=DEMO_KEY

# %%
def patents(text, concept_tags):
    """
    The NASA patent portfolio is available to benefit US citizens. Through partnerships and licensing agreements with industry, these patents ensure that NASA’s investments in pioneering research find secondary uses that benefit the economy, create jobs, and improve quality of life. This endpoint provides structured, searchable developer access to NASA’s patents that have been curated to support technology transfer.

    HTTP REQUEST

    GET https://api.data.gov/nasa/patents

    QUERY PARAMETERS

    Parameter	    Type	 Default	Description
    query	        string	 None	    Search text to filter results
    concept_tags	bool	 False	    Return an ordered dictionary of concepts from the patent abstract
    limit	        int	     all	    number of patents to return
    api_key	string	DEMO_KEY	        api.data.gov key for expanded usage

    EXAMPLE QUERY

    https://api.data.gov/nasa/patents/content?query=temperature&limit=5&api_key=DEMO_KEY
    """
    request='https://api.data.gov/nasa/patents/content'
    key=''
    form={'query': text,'concepte_tags': concept_tags, 'api_key': key}
    query=urllib.urlencode(form)
    patent_request_string=urllib.urlopen(request+"?"+query)
    print(patent_request_string.info())
    response=json.loads(patent_request_string.read())
    #print(response.keys())
    #print(response.values())
    return response

# %%
patents('brain', 'True')
# Out:
# https://api.data.gov/nasa/patents/content?query=brain&concepte_tags=True&api_key=
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=0.5
# cache-control: no-cache
# Content-Type: application/json
# Date: Sun, 12 Apr 2015 21:19:16 GMT
# Server: nginx
# vary: Accept-Encoding
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 979
# x-varnish: 1091191
# Content-Length: 9256
# Connection: Close
# {u'count': 4,
#  u'results': [{u'_id': u'53f657e55904da2c9fc2fee2',
#    u'abstract': u'A system with multimodality instrument for tissue identification includes a     computer-controlled motor driven heuristic probe with a multisensory tip.     For neurosurgical applications, the instrument is mounted on a     stereotactic frame for the probe to penetrate the brain in a precisely     controlled fashion. The resistance of the brain tissue being penetrated is     continually monitored by a miniaturized strain gauge attached to the probe     tip. Other modality sensors may be mounted near the probe tip to provide     real-time tissue characterizations and the ability to detect the proximity     of blood vessels, thus eliminating errors normally associated with     registration of pre-operative scans, tissue swelling, elastic tissue     deformation, human judgement, etc., and rendering surgical procedures     safer, more accurate, and efficient. A neural network program adaptively     learns the information on resistance and other characteristic features of     normal brain tissue during the surgery and provides near real-time     modeling. A fuzzy logic interface to the neural network program     incorporates expert medical knowledge in the learning process.     Identification of abnormal brain tissue is determined by the detection of     change and comparison with previously learned models of abnormal brain     tissues. The operation of the instrument is controlled through a user     friendly graphical interface. Patient data is presented in a 3D     stereographics display. Acoustic feedback of selected information may     optionally be provided. Upon detection of the close proximity to blood     vessels or abnormal brain tissue, the computer-controlled motor     immediately stops probe penetration.',
#    u'category': u'health medicine and biotechnology',
#    u'center': u'ARC',
#    u'client_record_id': u'patent_ARC-14231-1',
#    u'concepts': None,
#    u'contact': {u'address': u'Mail Stop 202A-3, Moffett Field, CA 94035',
#     u'email': u'Trupti.D.Sanghani@nasa.gov',
#     u'facility': u'NASA Ames Research Center',
#     u'name': u'Trupti D. Sanghani',
#     u'office': u'Technology Partnerships Division'},
#    u'eRelations': [],
#    u'expiration_date': u'',
#    u'id': u'patent_ARC-14231-1',
#    u'innovator': [{u'company': u'NASA Ames Research Center',
#      u'fname': u'Robert',
#      u'lname': u'Mah',
#      u'mname': u'W.',
#      u'order': u'1'},
#     {u'fname': u'Stefanie', u'lname': u'Jeffrey', u'order': u'3'},
#     {u'company': u'Veteran&#8217;s Affairs Medical Center',
#      u'fname': u'Russell',
#      u'lname': u'Andrews',
#      u'mname': u'J.',
#      u'order': u'2'}],
#    u'patent_number': u'6109270',
#    u'publication': None,
#    u'reference_number': u'ARC-14231-1',
#    u'serial_number': u'09/017,519',
#    u'title': u'Multimodality instrument for tissue characterization',
#    u'trl': u'6 - Demonstration in a relevant environment'},
#   {u'_id': u'53f657e95904da2c9fc2fee4',
#    u'abstract': u'A system with multimodality instrument for tissue identification includes a     computer-controlled motor driven heuristic probe with a multisensory tip.     For neurosurgical applications, the instrument is mounted on a     stereotactic frame for the probe to penetrate the brain in a precisely     controlled fashion. The resistance of the brain tissue being penetrated is     continually monitored by a miniaturized strain gauge attached to the probe     tip. Other modality sensors may be mounted near the probe tip to provide     real-time tissue characterizations and the ability to detect the proximity     of blood vessels, thus eliminating errors normally associated with     registration of pre-operative scans, tissue swelling, elastic tissue     deformation, human judgement, etc., and rendering surgical procedures     safer, more accurate, and efficient. A neural network program adaptively     learns the information on resistance and other characteristic features of     normal brain tissue during the surgery and provides near real-time     modeling. A fuzzy logic interface to the neural network program     incorporates expert medical knowledge in the learning process.     Identification of abnormal brain tissue is determined by the detection of     change and comparison with previously learned models of abnormal brain     tissues. The operation of the instrument is controlled through a user     friendly graphical interface. Patient data is presented in a 3D     stereographics display. Acoustic feedback of selected information may     optionally be provided. Upon detection of the close proximity to blood     vessels or abnormal brain tissue, the computer-controlled motor     immediately stops probe penetration. The use of this system will make     surgical procedures safer, more accurate, and more efficient. Other     applications of this system include the detection, prognosis and treatment     of breast cancer, prostate cancer, spinal diseases, and use in general     exploratory surgery.',
#    u'category': u'health medicine and biotechnology',
#    u'center': u'ARC',
#    u'client_record_id': u'patent_ARC-14231-3',
#    u'concepts': None,
#    u'contact': {u'address': u'Mail Stop 202A-3, Moffett Field, CA 94035',
#     u'email': u'Trupti.D.Sanghani@nasa.gov',
#     u'facility': u'NASA Ames Research Center',
#     u'name': u'Trupti D. Sanghani',
#     u'office': u'Technology Partnerships Division'},
#    u'eRelations': [],
#    u'expiration_date': u'',
#    u'id': u'patent_ARC-14231-3',
#    u'innovator': [{u'company': u'NASA Ames Research Center',
#      u'fname': u'Robert',
#      u'lname': u'Mah',
#      u'mname': u'W.',
#      u'order': u'1'},
#     {u'company': u'Veteran&#8217;s Affairs Medical Center',
#      u'fname': u'Russell',
#      u'lname': u'Andrews',
#      u'mname': u'J.',
#      u'order': u'2'}],
#    u'patent_number': u'6718196',
#    u'publication': None,
#    u'reference_number': u'ARC-14231-3',
#    u'serial_number': u'09/652,299',
#    u'title': u'Multimodality instrument for tissue characterization',
#    u'trl': u'6 - Demonstration in a relevant environment'},
#   {u'_id': u'53f6589c5904da2c9fc2ff3d',
#    u'abstract': u'Changes in intracranial pressure can be measured dynamically and     non-invasively by monitoring one or more cerebrospinal fluid pulsatile     components. Pulsatile components such as systolic and diastolic blood     pressures are partially transferred to the cerebrospinal fluid by way of     blood vessels contained in the surrounding brain tissue and membrane. As     intracranial pressure varies these cerebrospinal fluid pulsatile     components also vary. Thus, intracranial pressure can be dynamically     measured. Furthermore, use of acoustics allows the measurement to be     completely non-invasive. In the preferred embodiment, phase comparison of     a reflected acoustic signal to a reference signal using a constant     frequency pulsed phase-locked-loop ultrasonic device allows the pulsatile     components to be monitored. Calibrating the device by inducing a known     change in intracranial pressure allows conversion to changes in     intracranial pressure.',
#    u'category': u'health medicine and biotechnology',
#    u'center': u'LARC',
#    u'client_record_id': u'patent_LAR-15507-1',
#    u'concepts': None,
#    u'contact': {u'address': u'MS 218, Hampton, VA 23681-2199',
#     u'email': u'Sandra.k.pretlow@nasa.gov',
#     u'facility': u'NASA Langley Research Center',
#     u'name': u'Sandra Pretlow',
#     u'office': u'Innovative Partnerships Office',
#     u'phone': u'(757) 864-2358'},
#    u'eRelations': [],
#    u'expiration_date': u'',
#    u'id': u'patent_LAR-15507-1',
#    u'innovator': [{u'company': u'NASA Langley Research Center',
#      u'fname': u'John',
#      u'lname': u'Cantrell',
#      u'mname': u'H.',
#      u'order': u'1'},
#     {u'company': u'NASA Langley Research Center',
#      u'fname': u'William',
#      u'lname': u'Yost',
#      u'mname': u'T',
#      u'order': u'2'}],
#    u'patent_number': u'6475147',
#    u'publication': None,
#    u'reference_number': u'LAR-15507-1',
#    u'serial_number': u'09/493,044',
#    u'title': u'Ultrasonic apparatus and technique to measure changes in intracranial     pressure',
#    u'trl': u'undefined'},
#   {u'_id': u'53f658255904da2c9fc2ff02',
#    u'abstract': u'fNIRS may be used in real time or near-real time to detect the mental state of individuals.  Phase measurement can be applied to drive an adaptive filter for the removal of motion artifacts in real time or near-real time.  In this manner, the application of fNIRS may be extended to practical non-laboratory environments.  For example, the mental state of an operator of a vehicle may be monitored, and alerts may be issued and/or an autopilot may be engaged when the mental state of the operator indicates that the operator is inattentive.',
#    u'category': u'health medicine and biotechnology',
#    u'center': u'GRC',
#    u'client_record_id': u'patent_LEW-18952-1',
#    u'concepts': None,
#    u'contact': {u'email': u'ttp@grc.nasa.gov',
#     u'facility': u'NASA Glenn Research Center',
#     u'office': u'Innovation Projects Office'},
#    u'eRelations': [],
#    u'expiration_date': u'',
#    u'id': u'patent_LEW-18952-1',
#    u'innovator': [{u'company': u'NASA John H. Glenn Research Center At Lewis Field',
#      u'fname': u'Angela',
#      u'lname': u'Harrivel',
#      u'mname': u'R.',
#      u'order': u'1'},
#     {u'company': u'NASA John H. Glenn Research Center At Lewis Field',
#      u'fname': u'Tristan',
#      u'lname': u'Hearn',
#      u'mname': u'A.',
#      u'order': u'2'}],
#    u'publication': [{u'title': u'Functional Near  Infrared Spectroscopy: Watching the brain in flight ',
#      u'type': u'Conference or Seminar'}],
#    u'reference_number': u'LEW-18952-1',
#    u'serial_number': u'14/278,426',
#    u'title': u'A Novel Real Time Adaptive Filter For The Reduction Of Artifacts In Functional Near Infrared Spectroscopy Signals',
#    u'trl': u'4 - Validation in laboratory environment'}]}

# %% [markdown]
# # Sounds (Beta)

# %% [raw]
# Sound exists in space. Sometimes. And NASA has released a series of space sounds via sound cloud. We have abstracted away some of the hassle in accessing these sounds, so that developers can play with the audio files. For example, a useful application would be an automatic filter to identify human voices in these audio files. For now, that would help identify content. Later, however, when we retrieve sounds from far-off planets, we can apply the filter to identify unknown human space colonies. That was a joke. Sort of.
#
# HTTP REQUEST
#
# GET https://api.data.gov/nasa/planetary/sounds
#
# QUERY PARAMETERS
#
# Parameter	Type	Default	    Description
# q	        string	None	    Search text to filter results
# limit	    int	    10	        number of tracks to return
# api_key	    string	DEMO_KEY	api.data.gov key for expanded usage
#
# EXAMPLE QUERY
#
# http://api.data.gov/nasa/planetary/sounds?q=apollo&api_key=DEMO_KEY

# %%
def sounds(text):
    """
    Sound exists in space. Sometimes. And NASA has released a series of space sounds via sound cloud. We have abstracted away some of the hassle in accessing these sounds, so that developers can play with the audio files. For example, a useful application would be an automatic filter to identify human voices in these audio files. For now, that would help identify content. Later, however, when we retrieve sounds from far-off planets, we can apply the filter to identify unknown human space colonies. That was a joke. Sort of.

    HTTP REQUEST

    GET https://api.data.gov/nasa/planetary/sounds

    QUERY PARAMETERS

    Parameter	Type	Default	    Description
    q	        string	None	    Search text to filter results
    limit	    int	    10	        number of tracks to return
    api_key	    string	DEMO_KEY	api.data.gov key for expanded usage

    EXAMPLE QUERY

    http://api.data.gov/nasa/planetary/sounds?q=apollo&api_key=DEMO_KEY
    """
    request='https://api.data.gov/nasa/planetary/sounds'
    key=''
    form={'q': text, 'api_key': key}
    query=urllib.urlencode(form)
    sound_request_string=urllib.urlopen(request+"?"+query)
    print(sound_request_string.info())
    response=json.loads(sound_request_string.read())
    #print(response.keys())
    #print(response.values())
    return response

# %%
sounds('alien')
# Out:
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=0.5
# cache-control: no-cache
# Content-Type: application/json
# Date: Sun, 12 Apr 2015 21:24:48 GMT
# Server: nginx
# vary: Accept-Encoding
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 983
# x-varnish: 650212
# Content-Length: 3535
# Connection: Close
# {u'count': 10,
#  u'results': [{u'description': u'The Voyager 1 spacecraft has experienced three "tsunami waves" in interstellar space. Listen to how these waves cause surrounding ionized matter to ring. More details on this sound can be found here: http://www.nasa.gov/jpl/nasa-voyager-tsunami-wave-still-flies-through-interstellar-space/',
#    u'download_url': u'https://api.soundcloud.com/tracks/181835738/download',
#    u'duration': 18365,
#    u'id': 181835738,
#    u'last_modified': u'2014/12/16 22:34:23 +0000',
#    u'license': u'cc-by-nc-sa',
#    u'stream_url': u'https://api.soundcloud.com/tracks/181835738/stream',
#    u'tag_list': u'Space',
#    u'title': u'Voyager 1: Three "Tsunami Waves" in Interstellar Space'},
#   {u'description': u'Courtesy of United Launch Alliance',
#    u'download_url': u'https://api.soundcloud.com/tracks/173578614/download',
#    u'duration': 30095,
#    u'id': 173578614,
#    u'last_modified': u'2014/10/24 02:16:33 +0000',
#    u'license': u'cc-by-nc',
#    u'stream_url': u'https://api.soundcloud.com/tracks/173578614/stream',
#    u'tag_list': u'space',
#    u'title': u'Delta IV: Launch'},
#   {u'description': None,
#    u'download_url': u'https://api.soundcloud.com/tracks/172463130/download',
#    u'duration': 5903,
#    u'id': 172463130,
#    u'last_modified': u'2014/10/16 19:29:13 +0000',
#    u'license': u'cc-by-nc',
#    u'stream_url': u'https://api.soundcloud.com/tracks/172463130/stream',
#    u'tag_list': u'space',
#    u'title': u'Wheel Stop'},
#   {u'description': None,
#    u'download_url': u'https://api.soundcloud.com/tracks/172463129/download',
#    u'duration': 3760,
#    u'id': 172463129,
#    u'last_modified': u'2014/10/16 19:29:12 +0000',
#    u'license': u'cc-by-nc',
#    u'stream_url': u'https://api.soundcloud.com/tracks/172463129/stream',
#    u'tag_list': u'space',
#    u'title': u'Vector Transfer'},
#   {u'description': None,
#    u'download_url': u'https://api.soundcloud.com/tracks/172463128/download',
#    u'duration': 1515,
#    u'id': 172463128,
#    u'last_modified': u'2014/10/16 19:29:12 +0000',
#    u'license': u'cc-by-nc',
#    u'stream_url': u'https://api.soundcloud.com/tracks/172463128/stream',
#    u'tag_list': u'space',
#    u'title': u'Roger Roll'},
#   {u'description': None,
#    u'download_url': u'https://api.soundcloud.com/tracks/172463126/download',
#    u'duration': 7497,
#    u'id': 172463126,
#    u'last_modified': u'2014/10/16 19:29:12 +0000',
#    u'license': u'cc-by-nc',
#    u'stream_url': u'https://api.soundcloud.com/tracks/172463126/stream',
#    u'tag_list': u'space',
#    u'title': u'On its way to Orbit'},
#   {u'description': None,
#    u'download_url': u'https://api.soundcloud.com/tracks/172463124/download',
#    u'duration': 2560,
#    u'id': 172463124,
#    u'last_modified': u'2014/10/16 19:29:12 +0000',
#    u'license': u'cc-by-nc',
#    u'stream_url': u'https://api.soundcloud.com/tracks/172463124/stream',
#    u'tag_list': u'space',
#    u'title': u'Press to ATO'},
#   {u'description': None,
#    u'download_url': u'https://api.soundcloud.com/tracks/172463122/download',
#    u'duration': 5641,
#    u'id': 172463122,
#    u'last_modified': u'2014/10/16 19:29:11 +0000',
#    u'license': u'cc-by-nc',
#    u'stream_url': u'https://api.soundcloud.com/tracks/172463122/stream',
#    u'tag_list': u'space',
#    u'title': u'Nice to be in Orbit'},
#   {u'description': None,
#    u'download_url': u'https://api.soundcloud.com/tracks/172463117/download',
#    u'duration': 3187,
#    u'id': 172463117,
#    u'last_modified': u'2014/10/16 19:29:11 +0000',
#    u'license': u'cc-by-nc',
#    u'stream_url': u'https://api.soundcloud.com/tracks/172463117/stream',
#    u'tag_list': u'space',
#    u'title': u'MECO'},
#   {u'description': None,
#    u'download_url': u'https://api.soundcloud.com/tracks/172463116/download',
#    u'duration': 2429,
#    u'id': 172463116,
#    u'last_modified': u'2014/10/16 19:29:10 +0000',
#    u'license': u'cc-by-nc',
#    u'stream_url': u'https://api.soundcloud.com/tracks/172463116/stream',
#    u'tag_list': u'space',
#    u'title': u'Lookin At It'}]}

# %%
# create a client object with your app credentials
def grab_audio(term):
    request_endpoint='https://api.soundcloud.com/tracks/'
    key=''
    form={'client_id': key}
    query=urllib.urlencode(form)
    data=sounds(term)
    results=data['results']
    print('Fetching Remote Adio and storing in Current directory.')
    for items in results:
        print(items['title'])
        print(items['tag_list'])
        print(items['stream_url'])
        print(items['license'])
        print(items['last_modified'])
        print(items['id'])
        print(items['duration'])
        print(items['download_url'])
        print(items['description'])
        print('')
        #print(items['download_url']+"?"+query)
        sound_request_string=urllib.urlopen(items['download_url']+"?"+query)
        print('')
        with open(str(items['title'])+'.mp3', 'w') as mp3:
            mp3.write(sound_request_string.read())

# %%
grab_audio('alien')

# %%
APOD('2015-04-23', 'TRUE')
# Out:
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=1
# cache-control: no-cache
# Content-Type: application/json
# Date: Fri, 24 Apr 2015 05:37:35 GMT
# Server: nginx
# vary: Accept-Encoding
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 997
# x-varnish: 2437479
# Content-Length: 1043
# Connection: Close
#
# Title: Meteor in the Milky Way
# Date: 2015-04-23
# Explanation: rth's April showers include the Lyrid Meteor Shower, observed for more than 2,000 years when the planet makes its annual passage through the dust stream of long-period Comet Thatcher. A grain of that comet's dust, moving 48 kilometers per second at an altitude of 100 kilometers or so, is swept up in this night sky view from the early hours of April 21. Flashing toward the southeastern horizon, the meteor's brilliant streak crosses the central region of the rising Milky Way. Its trail points back toward the shower's radiant in the constellation Lyra, high in the northern springtime sky and off the top of the frame. The yellowish hue of giant star Antares shines to the right of the Milky Way's bulge. Higher still is bright planet Saturn, near the right edge. Seen from Istra, Croatia, the Lyrid meteor's greenish glow reflects in the waters of the Adriatic Sea.
# URL : http://apod.nasa.gov/apod/image/1504/IMG_2999korosecMilkyMet.jpg
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-52744ce736e2> in <module>()
# ----> 1 APOD('2015-04-23', 'TRUE')
#
# <ipython-input-5-73689d6acbbd> in APOD(date, concept_tags)
#      37     #print(exif_data)
#      38     ret = {}
# ---> 39     for tag, value in exif_data.items():
#      40         decoded = TAGS.get(tag, tag)
#      41         ret[decoded] = value
#
# AttributeError: 'NoneType' object has no attribute 'items'

# %%
ls
# Out:
# 148505                          brown_reader.py*
# APOD_2014-7-31.jpg              capitolWordsAPI.py*
# APOD_2015-04-23.jpg             closest.py*
# APOD_2015-4-12.jpg              geo/
# Bhistorical-USD.csv             gmail-tools/
# Bhistorical-USD.csv.html        inaugural_Corpus.py*
# BoardGames.py*                  landsat8_2014-07-31.png
# BoardGames.pyc                  large_csv_files.py*
# BroadBand Map.ipynb             linker.py
# CobraIcon1.png                  method_man.py*
# CompletelyConfigure.ipynb       network1.diag
# Decleration_of_Human_Rights.py* network1.png
# MailApp.ipynb                   panda.py
# NASA endpoints-Copy1.ipynb      psum.py*
# NASA endpoints.ipynb            psum.pyc
# NASA_API.py*                    psum_test.py*
# NASA_API.pyc                    requestsExample.py*
# OSGEO.ipynb                     scale_interval.diag
# PICS/                           scale_interval.png
# TCP.diag                        seqdiag.diag
# TCP.png                         seqdiag.png
# TIFF/                           slither
# Tiger-BW-thumb.png              slither.py
# Tiger-BW.png                    spam_map.kml
# UDHR_graph_example.py*          state_fips_codes.csv
# actdiag.diag                    sunlightAPI.py*
# actdiag.png                     test.kml
# audio/                          test.wav
# audio-command.sh*               tmp/
# blockdiag.diag                  wordGem.py*
# blockdiag.png                   worldcitiespop.txt

# %%
APOD('2015-04-24', 'TRUE')
# Out:
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=1
# cache-control: no-cache
# Content-Type: application/json
# Date: Fri, 24 Apr 2015 05:39:39 GMT
# Server: nginx
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 996
# x-varnish: 2443479
# Content-Length: 802
# Connection: Close
#
# Title: Blue Tears and the Milky Way
# Date: 2015-04-24
# Explanation: Lapping at rocks along the shore of the Island of Nangan, Taiwan, planet Earth, waves are infused with a subtle blue light in this sea and night skyscape. Composed of a series of long exposures made on April 16 the image captures the faint glow from Noctiluca scintillans. Also known as sea sparkles or blue tears, the marine plankton's bioluminescence is stimulated by wave motion. City lights along the coast of mainland China shine beneath low clouds in the west but stars and the faint Milky Way still fill the night above. Over the horizon the galaxy's central bulge and dark rifts seem to echo the rocks and luminous waves.
# URL : http://apod.nasa.gov/apod/image/1504/RBA_BlueTears1024.jpg
# ({'ColorSpace': 65535,
#   'ExifOffset': 78,
#   'ExifVersion': '0210',
#   'FlashPixVersion': '0100',
#   'ResolutionUnit': 2,
#   'XResolution': (72, 1),
#   'YResolution': (72, 1)},
#  {u'concept_tags': True,
#   u'date': u'2015-04-24',
#   u'explanation': u"Lapping at rocks along the shore of the Island of Nangan, Taiwan, planet Earth, waves are infused with a subtle blue light in this sea and night skyscape. Composed of a series of long exposures made on April 16 the image captures the faint glow from Noctiluca scintillans. Also known as sea sparkles or blue tears, the marine plankton's bioluminescence is stimulated by wave motion. City lights along the coast of mainland China shine beneath low clouds in the west but stars and the faint Milky Way still fill the night above. Over the horizon the galaxy's central bulge and dark rifts seem to echo the rocks and luminous waves.",
#   u'title': u'Blue Tears and the Milky Way',
#   u'url': u'http://apod.nasa.gov/apod/image/1504/RBA_BlueTears1024.jpg'})

# %%
APOD('2001-09-1', 'TRUE')
# Out:
# accept-ranges: bytes
# age: 0
# alternate-protocol: 80:quic,p=1
# cache-control: no-cache
# Content-Type: application/json
# Date: Fri, 24 Apr 2015 05:41:33 GMT
# Server: nginx
# vary: Accept-Encoding
# via: 1.1 varnish-v4
# x-cache: MISS
# X-RateLimit-Limit: 1000
# X-RateLimit-Remaining: 995
# x-varnish: 2437828
# Content-Length: 1371
# Connection: Close
#
# Title: Magnetars In The Sky
# Date: 2001-09-1
# Explanation: Indicated on this infrared image of the galactic center region are positions of candidate magnetars -- believed to be the strongest magnets in the galaxy. Classified by observers as Soft Gamma Repeaters (SGRs) and Anomalous X-ray Pulsars (AXPs), these cosmic powerhouses are likely city-sized, spinning, highly-magnetized neutron stars. How strong is a magnetar's magnetic field? The Earth's magnetic field which deflects compass needles is measured to be about 1 Gauss, while the strongest fields sustainable in earthbound laboratories are about 100,000 Gauss. A magnetar's monster magnetic field is estimated to be as high as 1,000,000,000,000,000 Gauss. A magnet this strong, located at about half the distance to the Moon would easily erase your credit cards and suck pens out of your pocket. In 1998, from a distance of about 20,000 light-years, one magnetar, SGR 1900+14 generated a powerful flash of gamma-rays detected by many spacecraft. That blast of high-energy radiation is now known to have had a measurable effect on Earth's ionosphere. At the surface of the magnetar, its powerful magnetic field is thought to buckle and shift the neutron star crust generating the intense high-energy flares.
# URL : http://apod.nasa.gov/apod/image/0109/magnetars_cobeloc.jpg
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-f93af661db4d> in <module>()
# ----> 1 APOD('2001-09-1', 'TRUE')
#
# <ipython-input-5-73689d6acbbd> in APOD(date, concept_tags)
#      37     #print(exif_data)
#      38     ret = {}
# ---> 39     for tag, value in exif_data.items():
#      40         decoded = TAGS.get(tag, tag)
#      41         ret[decoded] = value
#
# AttributeError: 'NoneType' object has no attribute 'items'
