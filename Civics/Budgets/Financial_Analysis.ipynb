# %% [markdown]
# ###Datasets
#
# ####Currency Report
# Annual_Production_Fgrs_US_Currency.csv
# https://inventory.data.gov/dataset/2b1dcd52-058e-410f-b656-f35962738c4f/resource/72a33ebb-3efe-455b-9e41-0733aaed7780/download/userssharedsdfannualproductionfgrsuscurrency.csv
#
# #####Querying
# The Data API can be accessed via the following actions of the CKAN action API.
#
# Create	https://inventory.data.gov/api/action/datastore_create
# Update / Insert	https://inventory.data.gov/api/action/datastore_upsert
# Query	https://inventory.data.gov/api/action/datastore_search
# Query (via SQL)	https://inventory.data.gov/api/action/datastore_search_sql
# Querying »
# Query example (first 5 results)
# https://inventory.data.gov/api/action/datastore_search?resource_id=72a33ebb-3efe-455b-9e41-0733aaed7780&limit=5
#
# Query example (results containing 'jones')
# https://inventory.data.gov/api/action/datastore_search?resource_id=72a33ebb-3efe-455b-9e41-0733aaed7780&q=jones
#
# Query example (via SQL statement)
# https://inventory.data.gov/api/action/datastore_search_sql?sql=SELECT * from "72a33ebb-3efe-455b-9e41-0733aaed7780" WHERE title LIKE 'jones'
#
# #####Documentation
# http://docs.ckan.org/en/ckan-2.2/datastore.html
#
# ####CFPB
# Consumer Financial Protection Bureau
# http://www.consumerfinance.gov/complaintdatabase/technical-documentation/
# http://data.consumerfinance.gov/api/views
# in csv:
# http://data.consumerfinance.gov/api/views/fphp-cr5a/rows.csv
#
# **View IDs**
#
# **ID**    -    **CATEGORY**
#
# *  s6ew-h6mp    -    **Consumer complaints (all categories)**
# *  t9fg-cqmi	-    **Bank accounts or services**
# *  7zpz-7ury	-    **Credit cards**
# *  xa48-juie	-    **Credit reporting**
# *  ckyu-ku28	-    **Debt collection**
# *  uha4-cwwn	-    **Money transfers**
# *  g5qz-smft	-    **Mortgages**
# *  b239-tvpx	-    **Other financial services**
# *  6hp8-hzag	-    **Payday loans**
# *  6yuf-367p	-    **Prepaid cards**
# *  eew7-9yf2	-    **Student loans**
# *  wfbn-zkat	-    **Vehicle or other consumer loans**
#
#
# Further Request Documentation available at :
# http://dev.socrata.com/docs/endpoints.html
#
# Raw Data Download:
# http://catalog.data.gov/dataset/consumer-complaint-database/resource/e7562a8e-5a2d-466c-9142-73c9f1d245f5

# %%
mkdir ./work_output ; cd ./work_output/

# %%
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import locale
import plotly.plotly as ply
# %matplotlib inline

# %% [markdown]
# The Currency data is a csv, We can access it using SQL over the CKAN API but however the dataset is small enough that it will be more efficient to load the whole thing into Pandas.

# %%
target = 'https://inventory.data.gov/dataset/2b1dcd52-058e-410f-b656-f35962738c4f/resource/72a33ebb-3efe-455b-9e41-0733aaed7780/download/userssharedsdfannualproductionfgrsuscurrency.csv'
with open('currency.csv', 'wb') as f:
    c_data = requests.get(target)
    c_values = c_data.content
    f.write(c_values)

# %%
df = pd.DataFrame.from_csv('currency.csv')

# %%
df
# Out:
#                   $1 Bills     $2 Bills       $5 Bills      $10 Bills  \
# Fiscal Year
# FY 1980      1,939,840,000          NaN    427,520,000    495,360,000
# FY 1981      1,954,560,000          NaN    519,680,000    536,320,000
# FY 1982      2,040,320,000          NaN    614,400,000    540,160,000
# FY 1983      2,229,760,000          NaN    583,680,000    592,640,000
# FY 1984      2,771,200,000          NaN    716,800,000    812,800,000
# FY 1985      2,851,200,000          NaN    777,600,000    784,000,000
# FY 1986      3,123,200,000          NaN    844,800,000    678,000,000
# FY 1987      3,232,000,000          NaN    780,800,000    697,600,000
# FY 1988      2,960,000,000          NaN    745,600,000    652,800,000
# FY 1989      2,860,800,000          NaN    835,200,000    771,200,000
# FY 1990      3,148,800,000          NaN    912,000,000    771,200,000
# FY 1991      3,212,800,000          NaN    979,200,000    812,800,000
# ...

# %%
df.keys()
# Out:
# Index([u'$1 Bills', u'$2 Bills', u'$5 Bills', u'$10 Bills', u'$20 Bills', u'$50 Bills', u'$100 Bills'], dtype='object')

# %%
df.T.keys()
# Out:
# Index([u'FY 1980', u'FY 1981', u'FY 1982', u'FY 1983', u'FY 1984', u'FY 1985', u'FY 1986', u'FY 1987', u'FY 1988', u'FY 1989', u'FY 1990', u'FY 1991', u'FY 1992', u'FY 1993', u'FY 1994', u'FY 1995', u'FY 1996', u'FY 1997', u'FY 1998', u'FY 1999', u'FY 2000', u'FY 2001', u'FY 2002', u'FY 2003', u'FY 2004', u'FY 2005', u'FY 2006', u'FY 2007', u'FY 2008', u'FY 2009', u'FY 2010', u'FY 2011', u'FY 2012'], dtype='object')

# %% [markdown]
# ####In order to convert the comma values to integers a locale has to be specified.

# %%
locale.setlocale( locale.LC_ALL, 'en_US.UTF-8' )
# Out:
# 'en_US.UTF-8'

# %%
def remove_nans(series):
    series_conversion = []
    for i in series:
        if str(i) in ['nan','N/A', ' N/A']:
            i = 0
            series_conversion.append(i)
        else:
            series_conversion.append(locale.atoi(i))
    return series_conversion

plot = plt.figure()
plt.title('Total Printed Currency Values for 1980-2012')
plt.axis([1,32,0,9000000000])
plt.xlabel('Years')
plt.ylabel('Billions')

Ones = df['$1 Bills']
plot_ones = remove_nans(Ones)

Twos = df['$2 Bills']    
plot_twos = remove_nans(Twos)

Fives = df['$5 Bills']
plot_fives = remove_nans(Fives)
    
Tens = df['$10 Bills']
plot_tens = remove_nans(Tens)

Twenties = df['$20 Bills']
plot_twenties = remove_nans(Twenties)

Fifties = df['$50 Bills']
plot_fifties = remove_nans(Fifties)
    
Hundreds = df['$100 Bills']
plot_hundreds = remove_nans(Hundreds)

plt.xticks(range(0,32), range(1980,2013), rotation='vertical')
plt.plot(plot_ones, lw=2, color='0.75', label='Ones')
plt.plot(plot_twos, lw=2, color='m', label='Twos')
plt.plot(plot_fives, lw=2, color='c', label='Fives')
plt.plot(plot_tens, lw=2, color='g', label='Tens')
plt.plot(plot_twenties, lw=2, color='r', label='Twenties')
plt.plot(plot_fifties, lw=2, color='y', label='Fifties')
plt.plot(plot_hundreds, lw=2, color='k', label='Hundreds')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# It has never before been the case that the hundred dollar bill is the most printed denomination of U.S. currency.
# This trend I will look at.

# %% [markdown]
# If you have set up your notebook to use Plotly you can pull out the legend and add the line :
# ply.plot_mpl(plot, filename='Currency Distribuitons')
# in order to publicly post the plot.
# Mine is posted at :
# https://plot.ly/~jessembacon/269

# %%
import requests, urllib

class CFPB_Data_tool():
    
    global api_endpoint
    global formats
    global categories

    api_endpoint = 'http://data.consumerfinance.gov/api/views'
    formats = ['json', 'xml', 'csv']
    categories = {
        'Consumer complaints (all categories)':'s6ew-h6mp',
        'Bank accounts or services':'t9fg-cqmi',
        'Credit cards':'7zpz-7ury',
        'Credit reporting':'xa48-juie',
        'Debt collection':'ckyu-ku28',
        'Money transfers':'uha4-cwwn',
        'Mortgages':'g5qz-smft',
        'Other financial services':'b239-tvpx',
        'Payday loans':'6hp8-hzag',
        'Prepaid cards':'6yuf-367p',
        'Student loans':'eew7-9yf2',
        'Vehicle or other consumer loans':'wfbn-zkat',
    }
    
    def __init__(self):
        self.api_endpoint = api_endpoint
        self.formats = formats
        self.categories = categories
        
    def request_by_category(self, category, return_format):
        data_object = requests.get( api_endpoint + '/' + category + '/' + 'rows.' + return_format )
        for item in data_object.headers:
            print(item, data_object.headers[item])
        return data_object.content
    
    def Build_CFPB_DB_FILES(self):
        try:
            for category in instance.categories.keys():
                cat_var = instance.request_by_category(instance.categories[category], 'csv')
                with open('%s.csv' % category, 'wb') as f:
                    f.write(cat_var)
                    del(cat_var)
                print('wrote %s.csv' % category)
        except:
            print('Could not grab all data')
    
    def csv_to_sqlite():
        pass

# %%
instance = CFPB_Data_tool()
# !mkdir ./CFPB_DATABASE

# %%
cd ./CFPB_DATABASE/
# Out:
# /Users/jesse/Documents/dev/Projects/Python/notebooks/work_output/CFPB_DATABASE

# %%
instance.Build_CFPB_DB_FILES()
# Out:
# ('content-disposition', 'attachment; filename=Bank_Account_or_Service_Complaints.csv')
# ('content-encoding', 'gzip')
# ('transfer-encoding', 'chunked')
# ('age', '2425')
# ('server', 'nginx')
# ('last-modified', 'Wed, 16 Sep 2015 17:59:23 UTC')
# ('connection', 'keep-alive')
# ('cache-control', 'public, must-revalidate, max-age=21600')
# ('date', 'Wed, 16 Sep 2015 20:40:45 GMT')
# ('access-control-allow-origin', '*')
# ('content-type', 'text/csv; charset=utf-8')
# ('x-socrata-region', 'production')
# Wrote Bank_Accounts_or_Services.csv
# ('content-disposition', 'attachment; filename=Credit_Card_Complaints.csv')
# ('content-encoding', 'gzip')
# ('transfer-encoding', 'chunked')
# ('age', '2')
# ('server', 'nginx')
# ('last-modified', 'Wed, 16 Sep 2015 10:59:23 PDT')
# ('connection', 'keep-alive')
# ('cache-control', 'public, must-revalidate, max-age=21600')
# ('date', 'Wed, 16 Sep 2015 20:40:48 GMT')
# ('access-control-allow-origin', '*')
# ('content-type', 'text/csv; charset=utf-8')
# ...
